# %%
import meep as mp
import matplotlib.pyplot as plt
import nlopt
import numpy as np
from meep_material import lorentzfit

# %%
resolution = 100
nfreq = 100
fcen = 1.75
df = 3.3

# %%
def Material_fit(Material_data_csv=".", 
                   eps_inf=1,
                   fit_wl_min=0.38, fit_wl_max=0.72,
                   num_lorentzians=2, iteration=30
                       ):    
        # 1. 데이터 로드 및 전처리,
        data = np.genfromtxt(Material_data_csv, delimiter=",")
        wl = data[:, 0] * 1e6  # 파장 (µm),
        n_data = data[:, 1] + 1j * data[:, 2]
        eps_all = np.square(n_data) - eps_inf
    
        # 피팅 범위로 데이터 선택,
        mask = (wl >= fit_wl_min) & (wl <= fit_wl_max)
        wl_fit, eps_fit = wl[mask], eps_all[mask]
        freqs_fit = 1 / wl_fit
    
        # 2. Lorentzian 피팅 최적화,
        ps = np.zeros((iteration, 3 * num_lorentzians))
        errors = np.zeros(iteration)
        for m in range(iteration):
            p_rand = [10 ** np.random.random() for _ in range(3 * num_lorentzians)]
            ps[m, :], errors[m] = lorentzfit(p_rand, freqs_fit, eps_fit, nlopt.LD_MMA, 1e-25, 50000)
            print(f"Iteration {m:3d}, error: {errors[m]:.6f}")
        best = np.argmin(errors)
        print(f"Optimal error: {errors[best]:.6f}")
    
        # 3. 최적 파라미터로 Susceptibility 생성 및 Meep 모델 구성,
        suscept = []
        for i in range(num_lorentzians):
            freq_param = ps[best][3*i + 1]
            gamma = ps[best][3*i + 2]
            if freq_param == 0:
                sigma = ps[best][3*i + 0]
                suscept.append(mp.DrudeSusceptibility(frequency=1.0, gamma=gamma, sigma=sigma))
            else:
                sigma = ps[best][3*i + 0] / freq_param**2
                suscept.append(mp.LorentzianSusceptibility(frequency=freq_param, gamma=gamma, sigma=sigma))
    
        return eps_inf, suscept
    
sio2_data_path = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/SiO2/CSV/SiO2_palik_data.csv"
al_data_path   = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/Al_Palik/CSV/Al_palik_data.csv"
andp_data_path = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/aNDP/CSV/aNPD_PFA_data.csv"

eps_inf_sio2, suscept_sio2 = Material_fit(Material_data_csv=sio2_data_path)
eps_inf_al, suscept_al = Material_fit(Material_data_csv=al_data_path)
eps_inf_andp, suscept_andp = Material_fit(Material_data_csv=andp_data_path)
# Out:
# Iteration   0, error: 0.000009
# Iteration   1, error: 0.000005
# Iteration   2, error: 0.000004
# Iteration   3, error: 0.000026
# Iteration   4, error: 0.000011
# Iteration   5, error: 0.000010
# Iteration   6, error: 0.000006
# Iteration   7, error: 0.000014
# Iteration   8, error: 0.000018
# Iteration   9, error: 0.000043
# Iteration  10, error: 0.000040
# Iteration  11, error: 0.000029
# Iteration  12, error: 0.000018
# Iteration  13, error: 0.000046
# Iteration  14, error: 0.000011
# Iteration  15, error: 0.000023
# Iteration  16, error: 0.000007
# Iteration  17, error: 0.000012
# Iteration  18, error: 0.000010
# Iteration  19, error: 0.000010
# Iteration  20, error: 0.000280
# Iteration  21, error: 0.000011
# Iteration  22, error: 0.000007
# Iteration  23, error: 0.000017
# Iteration  24, error: 0.000030
# Iteration  25, error: 0.000040
# Iteration  26, error: 0.000300
# Iteration  27, error: 0.000623
# Iteration  28, error: 0.000012
# Iteration  29, error: 0.000081
# Optimal error: 0.000004
# Iteration   0, error: 3.217581
# Iteration   1, error: 54.483567
# Iteration   2, error: 71292.592314
# Iteration   3, error: 71292.592314
# Iteration   4, error: 64.226780
# Iteration   5, error: 54.483567
# Iteration   6, error: 3.131232
# Iteration   7, error: 71292.592314
# Iteration   8, error: 64.226780
# Iteration   9, error: 64.226780
# Iteration  10, error: 64.226780
# Iteration  11, error: 71292.592314
# Iteration  12, error: 64.226780
# Iteration  13, error: 64.226780
# Iteration  14, error: 64.226780
# Iteration  15, error: 64.226780
# Iteration  16, error: 54.483567
# Iteration  17, error: 64.226780
# Iteration  18, error: 3.131232
# Iteration  19, error: 64.226780
# Iteration  20, error: 71292.592314
# Iteration  21, error: 64.226780
# Iteration  22, error: 3.600484
# Iteration  23, error: 64.226780
# Iteration  24, error: 64.226780
# Iteration  25, error: 3.148071
# Iteration  26, error: 64.226780
# Iteration  27, error: 64.226780
# Iteration  28, error: 71292.592314
# Iteration  29, error: 71292.592314
# Optimal error: 3.131232
# Iteration   0, error: 0.028537
# Iteration   1, error: 0.028058
# Iteration   2, error: 0.028534
# Iteration   3, error: 0.028058
# Iteration   4, error: 0.029411
# Iteration   5, error: 0.028058
# Iteration   6, error: 0.028090
# Iteration   7, error: 0.028187
# Iteration   8, error: 0.032601
# Iteration   9, error: 0.028984
# Iteration  10, error: 0.028976
# Iteration  11, error: 0.028058
# Iteration  12, error: 0.028058
# Iteration  13, error: 0.028058
# Iteration  14, error: 0.028058
# Iteration  15, error: 0.028058
# Iteration  16, error: 0.029207
# Iteration  17, error: 0.028109
# Iteration  18, error: 0.028354
# Iteration  19, error: 0.042196
# Iteration  20, error: 0.028180
# Iteration  21, error: 0.028058
# Iteration  22, error: 0.028058
# Iteration  23, error: 0.028064
# Iteration  24, error: 1.067688
# Iteration  25, error: 0.048150
# Iteration  26, error: 0.028058
# Iteration  27, error: 0.031901
# Iteration  28, error: 0.028239
# Iteration  29, error: 0.028058
# Optimal error: 0.028058

# %%
### ----- Refractive index ----- ###,
Glass = mp.Medium(epsilon=eps_inf_sio2, E_susceptibilities = suscept_sio2) # SiO2 ,
aNDP = mp.Medium(epsilon=eps_inf_andp, E_susceptibilities = suscept_andp) # aNDP ,
Cathode = mp.Medium(epsilon = eps_inf_al, E_susceptibilities = suscept_al)

# Cathode = mp.perfect_electric_conductor,

CoverLayer = mp.Medium(index=1.9) # SiN ,
ITO_m = mp.Medium(index=1.8) 
Alq3 = mp.Medium(index=1.68) 
Air = mp.Medium(index=1.0) # 공기,

Glass_layer = 1.37
Cover_layer = 0.07
ITO_layer = 0.15
aNDP_layer = 0.05
Alq3_layer = 0.06
Cathode_layer = 0.3

Absorber_layer = 0.5

boundary_layers = [
    mp.PML(thickness=Absorber_layer, direction=mp.X, side=mp.Low),  # 좌측 PML,
    mp.PML(thickness=Absorber_layer, direction=mp.X, side=mp.High), # 우측 PML,
    mp.PML(thickness=Absorber_layer, direction=mp.Y, side=mp.High), # 상단 PML,
]

# %%
Cathode_center = mp.Vector3(0, -0.85, 0)
Alq3_center = mp.Vector3(0, -0.67, 0)
aNDP_center = mp.Vector3(0, -0.615, 0)
ITO_center = mp.Vector3(0, -0.515, 0)
Cover_center = mp.Vector3(0, -0.405, 0)
Glass_center = mp.Vector3(0, 0.315, 0)

# %%
geometry_fitting_Al = [
        # Cathode (하단)
        mp.Block(
            center=Cathode_center,
            size=mp.Vector3(30, Cathode_layer, 0),
            material=Cathode
        ),
        # Alq3
        mp.Block(
            center=Alq3_center,
            size=mp.Vector3(30, Alq3_layer, 0),
            material=Alq3
        ),
        # aNDP
        mp.Block(
            center=aNDP_center,
            size=mp.Vector3(30, aNDP_layer, 0),
            material=aNDP
        ),
        # ITO
        mp.Block(
            center=ITO_center,
            size=mp.Vector3(30, ITO_layer, 0),
            material=ITO_m
        ),
        # Cover layer
        mp.Block(
            center=Cover_center,
            size=mp.Vector3(30, Cover_layer, 0),
            material=CoverLayer
        ),
        # Glass (상단; (0,0,0)은 이 Glass 내부에 위치함)
        mp.Block(
            center=Glass_center,
            size=mp.Vector3(30, Glass_layer, 0),
            material=Glass
        )
]

# %%
cell_size = mp.Vector3(31, 2, 0)

# %%
source_center = mp.Vector3(0,-0.67,0)

sources = [mp.Source(
        src=mp.GaussianSource(frequency=fcen, fwidth=df),
        component=mp.Ex,
        center=source_center,
        size=mp.Vector3(0,0,0)
)]

# %%
# === 시뮬레이션 설정 === #
sim_fitting_Al = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry_fitting_Al,
    default_material=mp.Medium(index = 1),
    sources=sources,
    resolution=resolution,
)

# %%
offset = 0.01
flux_size = 0.02

# Dipole 위치
source_center = mp.Vector3(0, -0.67,0)

focus_lambda_min = 0.4
focus_lambda_max = 0.7

focus_f_min = 1/focus_lambda_max
focus_f_max = 1/focus_lambda_min

fcen_monitor = 0.5 * (focus_f_min + focus_f_max)
df_monitor = focus_f_max - focus_f_min

box_power_fitting_Al = sim_fitting_Al.add_flux(
    fcen_monitor, df_monitor, nfreq,
    mp.FluxRegion(center=source_center - mp.Vector3(offset, 0, 0),
                  size=mp.Vector3(0, flux_size),
                  # direction=mp.Y, 
                  weight=-1),
    mp.FluxRegion(center=source_center + mp.Vector3(offset, 0, 0),
                  size=mp.Vector3(0, flux_size),
                  # direction=mp.Y
                ),
    mp.FluxRegion(center=source_center - mp.Vector3(0, offset, 0),
                  size=mp.Vector3(flux_size, 0),
                  # direction=mp.Y, 
                  weight=-1),
    mp.FluxRegion(center=source_center + mp.Vector3(0, offset, 0),
                  size=mp.Vector3(flux_size, 0),
                  # direction=mp.Y
                  )
)

sim_fitting_Al.run(until = 50)

net_power_fitting_al = mp.get_fluxes(box_power_fitting_Al)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000499964 s
# Working in 2D dimensions.
# Computational cell is 31 x 2 x 0 with resolution 100
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.800955 s
# lorentzian susceptibility: frequency=9.7651, gamma=0
# lorentzian susceptibility: frequency=10.825, gamma=0
# lorentzian susceptibility: frequency=2.66127, gamma=0.205589
# lorentzian susceptibility: frequency=5.62022, gamma=0.0129246
# drude susceptibility: frequency=1, gamma=0
# lorentzian susceptibility: frequency=1.01629, gamma=0.899161
# -----------
# Meep progress: 1.6400000000000001/50.0 = 3.3% done in 4.0s, 118.1s to go
# on time step 328 (time=1.64), 0.0122068 s/step
# Meep progress: 3.315/50.0 = 6.6% done in 8.0s, 112.9s to go
# on time step 663 (time=3.315), 0.0119689 s/step
# Meep progress: 5.005/50.0 = 10.0% done in 12.0s, 108.0s to go
# on time step 1001 (time=5.005), 0.0118401 s/step
# Meep progress: 6.7/50.0 = 13.4% done in 16.0s, 103.6s to go
# on time step 1340 (time=6.7), 0.01183 s/step
# Meep progress: 8.370000000000001/50.0 = 16.7% done in 20.0s, 99.6s to go
# on time step 1674 (time=8.37), 0.0119961 s/step
# Meep progress: 10.065/50.0 = 20.1% done in 24.0s, 95.4s to go
# on time step 2013 (time=10.065), 0.0118121 s/step
# Meep progress: 11.755/50.0 = 23.5% done in 28.0s, 91.3s to go
# on time step 2351 (time=11.755), 0.0118612 s/step
# Meep progress: 13.44/50.0 = 26.9% done in 32.1s, 87.2s to go
# on time step 2688 (time=13.44), 0.0118911 s/step
# Meep progress: 15.11/50.0 = 30.2% done in 36.1s, 83.3s to go
# on time step 3022 (time=15.11), 0.0120026 s/step
# Meep progress: 16.79/50.0 = 33.6% done in 40.1s, 79.3s to go
# on time step 3358 (time=16.79), 0.011928 s/step
# Meep progress: 18.425/50.0 = 36.9% done in 44.1s, 75.5s to go
# on time step 3685 (time=18.425), 0.0122509 s/step
# Meep progress: 20.05/50.0 = 40.1% done in 48.1s, 71.8s to go
# on time step 4011 (time=20.055), 0.0123075 s/step
# Meep progress: 21.68/50.0 = 43.4% done in 52.1s, 68.0s to go
# on time step 4337 (time=21.685), 0.0123082 s/step
# Meep progress: 23.335/50.0 = 46.7% done in 56.1s, 64.1s to go
# on time step 4668 (time=23.34), 0.0121147 s/step
# Meep progress: 25.015/50.0 = 50.0% done in 60.1s, 60.0s to go
# on time step 5004 (time=25.02), 0.0119155 s/step
# Meep progress: 26.665/50.0 = 53.3% done in 64.1s, 56.1s to go
# on time step 5334 (time=26.67), 0.0121236 s/step
# Meep progress: 28.35/50.0 = 56.7% done in 68.1s, 52.0s to go
# on time step 5671 (time=28.355), 0.0118827 s/step
# Meep progress: 30.045/50.0 = 60.1% done in 72.1s, 47.9s to go
# on time step 6010 (time=30.05), 0.0118036 s/step
# Meep progress: 31.745/50.0 = 63.5% done in 76.1s, 43.8s to go
# on time step 6350 (time=31.75), 0.011792 s/step
# Meep progress: 33.45/50.0 = 66.9% done in 80.1s, 39.6s to go
# on time step 6691 (time=33.455), 0.0117421 s/step
# Meep progress: 35.1/50.0 = 70.2% done in 84.1s, 35.7s to go
# on time step 7021 (time=35.105), 0.0121529 s/step
# Meep progress: 36.76/50.0 = 73.5% done in 88.1s, 31.7s to go
# on time step 7353 (time=36.765), 0.0120531 s/step
# Meep progress: 38.4/50.0 = 76.8% done in 92.1s, 27.8s to go
# on time step 7681 (time=38.405), 0.012199 s/step
# Meep progress: 40.04/50.0 = 80.1% done in 96.2s, 23.9s to go
# on time step 8009 (time=40.045), 0.012212 s/step
# Meep progress: 41.72/50.0 = 83.4% done in 100.2s, 19.9s to go
# on time step 8345 (time=41.725), 0.0119285 s/step
# Meep progress: 43.395/50.0 = 86.8% done in 104.2s, 15.9s to go
# on time step 8680 (time=43.4), 0.0119477 s/step
# Meep progress: 45.055/50.0 = 90.1% done in 108.2s, 11.9s to go
# on time step 9013 (time=45.065), 0.0120457 s/step
# Meep progress: 46.745/50.0 = 93.5% done in 112.2s, 7.8s to go
# on time step 9351 (time=46.755), 0.0118502 s/step
# Meep progress: 48.395/50.0 = 96.8% done in 116.2s, 3.9s to go
# on time step 9681 (time=48.405), 0.0121572 s/step
# run 0 finished at t = 50.0 (10000 timesteps)

# %%
frequencies = mp.get_flux_freqs(box_power_fitting_Al)

wavelengths = [1/f for f in frequencies]

print("λ (μm) dipolepower_box (W)")
for i in range(nfreq):
    print(f"{wavelengths[i]:.4f} {net_power_fitting_al[i]:.6e}")
# Out:
# λ (μm) dipolepower_box (W)
# 0.7000 6.474378e-03
# 0.6947 6.779505e-03
# 0.6896 7.088988e-03
# 0.6844 7.409505e-03
# 0.6794 7.730623e-03
# 0.6745 8.066485e-03
# 0.6696 8.399502e-03
# 0.6647 8.750610e-03
# 0.6600 9.095976e-03
# 0.6553 9.462184e-03
# 0.6507 9.820511e-03
# 0.6462 1.020164e-02
# 0.6417 1.057368e-02
# 0.6372 1.096955e-02
# 0.6329 1.135617e-02
# 0.6286 1.176664e-02
# 0.6243 1.216877e-02
# 0.6201 1.259380e-02
# 0.6160 1.301244e-02
# 0.6119 1.345211e-02
# 0.6079 1.388829e-02
# 0.6039 1.434286e-02
# 0.6000 1.479761e-02
# 0.5961 1.526755e-02
# 0.5923 1.574186e-02
# 0.5885 1.622786e-02
# 0.5848 1.672268e-02
# 0.5811 1.722561e-02
# 0.5775 1.774176e-02
# 0.5739 1.826267e-02
# 0.5704 1.880086e-02
# 0.5669 1.934084e-02
# 0.5634 1.990151e-02
# 0.5600 2.046156e-02
# 0.5566 2.104479e-02
# 0.5533 2.162560e-02
# 0.5500 2.223087e-02
# 0.5467 2.283248e-02
# 0.5435 2.345839e-02
# 0.5404 2.407979e-02
# 0.5372 2.472367e-02
# 0.5341 2.536221e-02
# 0.5310 2.601947e-02
# 0.5280 2.667019e-02
# 0.5250 2.733384e-02
# 0.5220 2.798887e-02
# 0.5191 2.864877e-02
# 0.5162 2.929659e-02
# 0.5133 2.993895e-02
# 0.5105 3.056393e-02
# 0.5077 3.117099e-02
# 0.5049 3.175345e-02
# 0.5022 3.230390e-02
# 0.4995 3.282086e-02
# 0.4968 3.329097e-02
# 0.4941 3.371779e-02
# 0.4915 3.408347e-02
# 0.4889 3.439636e-02
# 0.4863 3.463597e-02
# 0.4838 3.481497e-02
# 0.4812 3.491218e-02
# 0.4788 3.494399e-02
# 0.4763 3.489019e-02
# 0.4738 3.476995e-02
# 0.4714 3.456530e-02
# 0.4690 3.429703e-02
# 0.4667 3.395016e-02
# 0.4643 3.354577e-02
# 0.4620 3.307211e-02
# 0.4597 3.254936e-02
# 0.4574 3.196881e-02
# 0.4552 3.134873e-02
# 0.4529 3.068358e-02
# 0.4507 2.998863e-02
# 0.4485 2.926030e-02
# 0.4464 2.851181e-02
# 0.4442 2.774103e-02
# 0.4421 2.695865e-02
# 0.4400 2.616359e-02
# 0.4379 2.536444e-02
# 0.4358 2.456056e-02
# 0.4338 2.375907e-02
# 0.4318 2.295914e-02
# 0.4298 2.216710e-02
# 0.4278 2.138139e-02
# 0.4258 2.060821e-02
# 0.4239 1.984480e-02
# 0.4219 1.909782e-02
# 0.4200 1.836294e-02
# 0.4181 1.764774e-02
# 0.4162 1.694612e-02
# 0.4143 1.626687e-02
# 0.4125 1.560206e-02
# 0.4107 1.496176e-02
# 0.4088 1.433652e-02
# 0.4070 1.373779e-02
# 0.4053 1.315417e-02
# 0.4035 1.259837e-02
# 0.4017 1.205812e-02
# 0.4000 1.154690e-02

# %%
plt.figure(figsize=(8,6))
plt.plot(wavelengths, net_power_fitting_al, '-', label='net_power_fitting_al', color = 'green')
plt.xlabel('Wavelength (μm)')
plt.ylabel('net_power_fitting_al (W)')
plt.title('net_power_fitting_al vs. Wavelength')

plt.legend()
plt.grid(True)
plt.show()

# %%
geometry_PEC = [
    # Cathode (하단)
    mp.Block(
        center=Cathode_center,
        size=mp.Vector3(30, Cathode_layer, 0),
        material=mp.perfect_electric_conductor
    ),
    # Alq3
    mp.Block(
        center=Alq3_center,
        size=mp.Vector3(30, Alq3_layer, 0),
        material=Alq3
    ),
    # aNDP
    mp.Block(
        center=aNDP_center,
        size=mp.Vector3(30, aNDP_layer, 0),
        material=aNDP
    ),
    # ITO
    mp.Block(
        center=ITO_center,
        size=mp.Vector3(30, ITO_layer, 0),
        material=ITO_m
    ),
    # Cover layer
    mp.Block(
        center=Cover_center,
        size=mp.Vector3(30, Cover_layer, 0),
        material=CoverLayer
    ),
    # Glass (상단; (0,0,0)은 이 Glass 내부에 위치함)
    mp.Block(
        center=Glass_center,
        size=mp.Vector3(30, Glass_layer, 0),
        material=Glass
    )
]

# === 시뮬레이션 설정 === #
sim_with_PEC = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry_PEC,
    default_material=mp.Medium(index = 1),
    sources=sources,
    resolution=resolution,
)

offset = 0.01
flux_size = 0.02

# Dipole 위치
source_center = mp.Vector3(0, -0.67,0)

focus_lambda_min = 0.4
focus_lambda_max = 0.7

focus_f_min = 1/focus_lambda_max
focus_f_max = 1/focus_lambda_min

fcen_monitor = 0.5 * (focus_f_min + focus_f_max)
df_monitor = focus_f_max - focus_f_min

box_PEC = sim_with_PEC.add_flux(
    fcen_monitor, df_monitor, nfreq,
    mp.FluxRegion(center=source_center - mp.Vector3(offset, 0, 0),
                  size=mp.Vector3(0, flux_size),
                  # direction=mp.Y, 
                  weight=-1),
    mp.FluxRegion(center=source_center + mp.Vector3(offset, 0, 0),
                  size=mp.Vector3(0, flux_size),
                  # direction=mp.Y
                ),
    mp.FluxRegion(center=source_center - mp.Vector3(0, offset, 0),
                  size=mp.Vector3(flux_size, 0),
                  # direction=mp.Y, 
                  weight=-1),
    mp.FluxRegion(center=source_center + mp.Vector3(0, offset, 0),
                  size=mp.Vector3(flux_size, 0),
                  # direction=mp.Y
                  )
)

sim_with_PEC.run(until = 50)

net_power_with_PEC = mp.get_fluxes(box_PEC)

frequencies = mp.get_flux_freqs(box_PEC)

wavelengths = [1/f for f in frequencies]

print("λ (μm) dipolepower_box (W)")
for i in range(nfreq):
    print(f"{frequencies[i]:.4f}  {net_power_with_PEC[i]:.6e}")

plt.figure(figsize=(8,6))
plt.plot(wavelengths, net_power_with_PEC, '-', label='net_power_with_PEC', color = 'green')
plt.xlabel('Wavelength (μm)')
plt.ylabel('net_power_with_PEC (W)')
plt.title('net_power_with_PEC vs. Wavelength')
# plt.ylim(-4, 14)  # y축 최소값: -4, 최대값: 14
# plt.xlim([0.4, 0.7])
plt.legend()
plt.grid(True)
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000340939 s
# Working in 2D dimensions.
# Computational cell is 31 x 2 x 0 with resolution 100
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.786283 s
# lorentzian susceptibility: frequency=9.7651, gamma=0
# lorentzian susceptibility: frequency=10.825, gamma=0
# lorentzian susceptibility: frequency=2.66127, gamma=0.205589
# lorentzian susceptibility: frequency=5.62022, gamma=0.0129246
# -----------
# Meep progress: 2.16/50.0 = 4.3% done in 4.0s, 88.8s to go
# on time step 432 (time=2.16), 0.00927995 s/step
# Meep progress: 4.33/50.0 = 8.7% done in 8.0s, 84.5s to go
# on time step 866 (time=4.33), 0.00922295 s/step
# Meep progress: 6.5600000000000005/50.0 = 13.1% done in 12.0s, 79.6s to go
# on time step 1312 (time=6.56), 0.00898314 s/step
# Meep progress: 8.81/50.0 = 17.6% done in 16.0s, 74.9s to go
# on time step 1762 (time=8.81), 0.00890457 s/step
# Meep progress: 11.05/50.0 = 22.1% done in 20.0s, 70.6s to go
# on time step 2210 (time=11.05), 0.00894652 s/step
# Meep progress: 13.265/50.0 = 26.5% done in 24.0s, 66.6s to go
# on time step 2653 (time=13.265), 0.00903596 s/step
# Meep progress: 15.47/50.0 = 30.9% done in 28.0s, 62.6s to go
# on time step 3094 (time=15.47), 0.0090861 s/step
# Meep progress: 17.675/50.0 = 35.4% done in 32.0s, 58.6s to go
# on time step 3535 (time=17.675), 0.00907415 s/step
# Meep progress: 19.895/50.0 = 39.8% done in 36.1s, 54.6s to go
# on time step 3979 (time=19.895), 0.00901432 s/step
# Meep progress: 22.125/50.0 = 44.2% done in 40.1s, 50.5s to go
# on time step 4425 (time=22.125), 0.00897041 s/step
# Meep progress: 24.36/50.0 = 48.7% done in 44.1s, 46.4s to go
# on time step 4872 (time=24.36), 0.00895015 s/step
# Meep progress: 26.6/50.0 = 53.2% done in 48.1s, 42.3s to go
# on time step 5320 (time=26.6), 0.00893966 s/step
# Meep progress: 28.84/50.0 = 57.7% done in 52.1s, 38.2s to go
# on time step 5768 (time=28.84), 0.00893404 s/step
# Meep progress: 31.065/50.0 = 62.1% done in 56.1s, 34.2s to go
# on time step 6214 (time=31.07), 0.00898925 s/step
# Meep progress: 33.25/50.0 = 66.5% done in 60.1s, 30.3s to go
# on time step 6651 (time=33.255), 0.00915775 s/step
# Meep progress: 35.47/50.0 = 70.9% done in 64.1s, 26.2s to go
# on time step 7095 (time=35.475), 0.0090189 s/step
# Meep progress: 37.695/50.0 = 75.4% done in 68.1s, 22.2s to go
# on time step 7540 (time=37.7), 0.00900664 s/step
# Meep progress: 39.925000000000004/50.0 = 79.9% done in 72.1s, 18.2s to go
# on time step 7986 (time=39.93), 0.00896963 s/step
# Meep progress: 42.160000000000004/50.0 = 84.3% done in 76.1s, 14.1s to go
# on time step 8433 (time=42.165), 0.00895164 s/step
# Meep progress: 44.4/50.0 = 88.8% done in 80.1s, 10.1s to go
# on time step 8881 (time=44.405), 0.00893455 s/step
# Meep progress: 46.655/50.0 = 93.3% done in 84.1s, 6.0s to go
# on time step 9332 (time=46.66), 0.00888376 s/step
# Meep progress: 48.885/50.0 = 97.8% done in 88.1s, 2.0s to go
# on time step 9778 (time=48.89), 0.00898421 s/step
# run 0 finished at t = 50.0 (10000 timesteps)
# λ (μm) dipolepower_box (W)
# 1.4286  2.841184e-03
# 1.4394  2.973718e-03
# 1.4502  3.128489e-03
# 1.4610  3.263525e-03
# 1.4719  3.424780e-03
# 1.4827  3.562370e-03
# 1.4935  3.729847e-03
# 1.5043  3.870282e-03
# 1.5152  4.043705e-03
# 1.5260  4.187493e-03
# 1.5368  4.366573e-03
# 1.5476  4.514412e-03
# 1.5584  4.698864e-03
# 1.5693  4.851602e-03
# 1.5801  5.041178e-03
# 1.5909  5.199779e-03
# 1.6017  5.394302e-03
# 1.6126  5.559804e-03
# 1.6234  5.759243e-03
# 1.6342  5.932729e-03
# 1.6450  6.137513e-03
# 1.6558  6.318194e-03
# 1.6667  6.527161e-03
# 1.6775  6.720363e-03
# 1.6883  6.935291e-03
# 1.6991  7.139349e-03
# 1.7100  7.360737e-03
# 1.7208  7.576795e-03
# 1.7316  7.805606e-03
# 1.7424  8.034560e-03
# 1.7532  8.271997e-03
# 1.7641  8.514633e-03
# 1.7749  8.762083e-03
# 1.7857  9.019090e-03
# 1.7965  9.278049e-03
# 1.8074  9.549998e-03
# 1.8182  9.821965e-03
# 1.8290  1.010927e-02
# 1.8398  1.039559e-02
# 1.8506  1.069841e-02
# 1.8615  1.100011e-02
# 1.8723  1.131822e-02
# 1.8831  1.163571e-02
# 1.8939  1.196830e-02
# 1.9048  1.230109e-02
# 1.9156  1.264645e-02
# 1.9264  1.299274e-02
# 1.9372  1.334790e-02
# 1.9481  1.370417e-02
# 1.9589  1.406445e-02
# 1.9697  1.442500e-02
# 1.9805  1.478360e-02
# 1.9913  1.514023e-02
# 2.0022  1.548789e-02
# 2.0130  1.582961e-02
# 2.0238  1.615455e-02
# 2.0346  1.646790e-02
# 2.0455  1.675625e-02
# 2.0563  1.702602e-02
# 2.0671  1.726277e-02
# 2.0779  1.747335e-02
# 2.0887  1.764397e-02
# 2.0996  1.778117e-02
# 2.1104  1.787342e-02
# 2.1212  1.792644e-02
# 2.1320  1.793224e-02
# 2.1429  1.789529e-02
# 2.1537  1.781192e-02
# 2.1645  1.768502e-02
# 2.1753  1.751543e-02
# 2.1861  1.730419e-02
# 2.1970  1.705623e-02
# 2.2078  1.677096e-02
# 2.2186  1.645655e-02
# 2.2294  1.610991e-02
# 2.2403  1.574237e-02
# 2.2511  1.534922e-02
# 2.2619  1.494104e-02
# 2.2727  1.451492e-02
# 2.2835  1.408208e-02
# 2.2944  1.363638e-02
# 2.3052  1.318957e-02
# 2.3160  1.273568e-02
# 2.3268  1.228501e-02
# 2.3377  1.183238e-02
# 2.3485  1.138612e-02
# 2.3593  1.094233e-02
# 2.3701  1.050703e-02
# 2.3810  1.007789e-02
# 2.3918  9.658556e-03
# 2.4026  9.248400e-03
# 2.4134  8.848785e-03
# 2.4242  8.460692e-03
# 2.4351  8.083528e-03
# 2.4459  7.719620e-03
# 2.4567  7.366836e-03
# 2.4675  7.028520e-03
# 2.4784  6.701609e-03
# 2.4892  6.389841e-03
# 2.5000  6.089747e-03

# %%
import numpy as np

# CSV 파일 불러오기
data = np.genfromtxt("dipole_power.csv", delimiter=",", skip_header=1)

# 데이터 분리
wavelengths = data[:, 0]
source_power = data[:, 1]

# 슬라이싱: 0.5μm ≤ λ ≤ 1.0μm
# mask = (wavelengths >= 0) & (wavelengths <= 10)
wavelength_sliced = wavelengths
power_sliced = source_power

# 결과 출력
print("슬라이싱된 wavelength:", wavelength_sliced)
print("슬라이싱된 power:", power_sliced)
# Out:
# 슬라이싱된 wavelength: [0.7        0.69473684 0.68955224 0.68444444 0.67941176 0.67445255
#  0.66956522 0.6647482  0.66       0.65531915 0.65070423 0.64615385
#  0.64166667 0.63724138 0.63287671 0.62857143 0.62432432 0.62013423
#  0.616      0.61192053 0.60789474 0.60392157 0.6        0.59612903
#  0.59230769 0.58853503 0.58481013 0.58113208 0.5775     0.57391304
#  0.57037037 0.56687117 0.56341463 0.56       0.55662651 0.55329341
#  0.55       0.54674556 0.54352941 0.54035088 0.5372093  0.53410405
#  0.53103448 0.528      0.525      0.5220339  0.51910112 0.51620112
#  0.51333333 0.51049724 0.50769231 0.50491803 0.50217391 0.49945946
#  0.49677419 0.49411765 0.49148936 0.48888889 0.48631579 0.48376963
#  0.48125    0.47875648 0.47628866 0.47384615 0.47142857 0.46903553
#  0.46666667 0.46432161 0.462      0.45970149 0.45742574 0.45517241
#  0.45294118 0.45073171 0.44854369 0.44637681 0.44423077 0.44210526
#  0.44       0.43791469 0.43584906 0.43380282 0.4317757  0.42976744
#  0.42777778 0.42580645 0.42385321 0.42191781 0.42       0.41809955
#  0.41621622 0.41434978 0.4125     0.41066667 0.40884956 0.40704846
#  0.40526316 0.40349345 0.40173913 0.4       ]
# 슬라이싱된 power: [0.00974608 0.01022019 0.0107057  0.0112023  0.01171012 0.01222924
#  0.01275924 0.01329905 0.01384728 0.01440285 0.01496523 0.01553431
#  0.01610976 0.01669064 0.01727537 0.01786222 0.01844992 0.01903782
#  0.01962556 0.02021243 0.02079707 0.02137751 0.02195189 0.02251891
#  0.0230779  0.02362838 0.02416942 0.02469934 0.02521612 0.02571796
#  0.02620376 0.02667306 0.0271254  0.02755979 0.02797456 0.02836785
#  0.02873825 0.02908512 0.02940833 0.02970765 0.02998224 0.0302307
#  0.03045163 0.03064423 0.03080848 0.03094473 0.03105311 0.03113309
#  0.03118375 0.03120435 0.03119483 0.03115584 0.03108826 0.03099258
#  0.03086872 0.03071632 0.03053533 0.03032645 0.03009091 0.02983001
#  0.02954459 0.02923495 0.02890127 0.02854412 0.02816477 0.02776488
#  0.02734597 0.02690908 0.02645477 0.02598361 0.02549663 0.0249954
#  0.02448173 0.02395715 0.02342271 0.02287907 0.02232699 0.02176768
#  0.02120275 0.02063392 0.0200625  0.01948936 0.01891509 0.01834045
#  0.01776659 0.01719496 0.01662692 0.01606344 0.01550508 0.01495225
#  0.01440555 0.01386593 0.01333446 0.01281209 0.01229935 0.01179648
#  0.01130363 0.01082118 0.01034975 0.00989005]

# %%
import numpy as np
import matplotlib.pyplot as plt

# 파일은: 2열짜리 [lambda(m), Y] 형식
dipolepower = np.loadtxt("dipolepower.txt", delimiter=',')  # 쉼표 구분자가 아닌 경우 제거해도 됨

lambda_m = dipolepower[:, 0]  # 1열: wavelength in meters
Y = dipolepower[:, 1]         # 2열: normalized power

# 2. 단위 변환: meter → micrometer
lambda_um = lambda_m * 1e6

# 3. 슬라이싱: x 범위 0.4 ~ 0.7 μm
mask = (lambda_um >= 0.4) & (lambda_um <= 0.7)
lambda_sliced = lambda_um[mask]
Y_sliced = Y[mask]

# %%
import matplotlib.pyplot as plt

dp_fitting_al = net_power_fitting_al / source_power
dp_PEC = net_power_with_PEC / source_power

plt.figure(figsize=(8, 5))

# plot 순서
plt.plot(lambda_sliced, Y_sliced, label='from Lumerical FDTD', color='green')
plt.plot(wavelengths, dp_fitting_al, label='with fitting Al', color='red')
plt.plot(wavelengths, dp_PEC, label='with PEC', color='blue')

# 축 레이블 (굵게 + 크기 조정)
plt.xlabel("Wavelength (μm)", fontsize=12, fontweight='bold')
plt.ylabel("dp = net_power / source_power", fontsize=12, fontweight='bold')

# 제목 (굵게 + 크기 조정)
plt.title("Normalized Dipole Radiation Power", fontsize=12, fontweight='bold')

# 눈금 폰트 크기 조정
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# 범례 (폰트 크기 조정 + 굵게)
plt.legend(fontsize=12, frameon=True,)

# 기타 설정
plt.grid(True)
plt.tight_layout()
# plt.ylim([0, 1.5])
plt.xlim([0.4, 0.7])
plt.show()
