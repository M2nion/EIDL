# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import nlopt
from meep_material import lorentzfit

# %%
resolution = 100
nfreq = 100

fcen = 1.75
df = 3.3

# %%
def Material_fit(Material_data_csv=".", 
                   eps_inf=1,
                   fit_wl_min=0.38, fit_wl_max=0.72,
                   num_lorentzians=2, iteration=30
                   ):    

    # 1. 데이터 로드 및 전처리
    data = np.genfromtxt(Material_data_csv, delimiter=",")
    wl = data[:, 0] * 1e6  # 파장 (µm)
    n_data = data[:, 1] + 1j * data[:, 2]
    eps_all = np.square(n_data) - eps_inf

    # 피팅 범위로 데이터 선택
    mask = (wl >= fit_wl_min) & (wl <= fit_wl_max)
    wl_fit, eps_fit = wl[mask], eps_all[mask]
    freqs_fit = 1 / wl_fit

    # 2. Lorentzian 피팅 최적화
    ps = np.zeros((iteration, 3 * num_lorentzians))
    errors = np.zeros(iteration)
    for m in range(iteration):
        p_rand = [10 ** np.random.random() for _ in range(3 * num_lorentzians)]
        ps[m, :], errors[m] = lorentzfit(p_rand, freqs_fit, eps_fit, nlopt.LD_MMA, 1e-25, 50000)
        print(f"Iteration {m:3d}, error: {errors[m]:.6f}")
    best = np.argmin(errors)
    print(f"Optimal error: {errors[best]:.6f}")

    # 3. 최적 파라미터로 Susceptibility 생성 및 Meep 모델 구성
    suscept = []
    for i in range(num_lorentzians):
        freq_param = ps[best][3*i + 1]
        gamma = ps[best][3*i + 2]
        if freq_param == 0:
            sigma = ps[best][3*i + 0]
            suscept.append(mp.DrudeSusceptibility(frequency=1.0, gamma=gamma, sigma=sigma))
        else:
            sigma = ps[best][3*i + 0] / freq_param**2
            suscept.append(mp.LorentzianSusceptibility(frequency=freq_param, gamma=gamma, sigma=sigma))

    return eps_inf, suscept

sio2_data_path = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/SiO2/CSV/SiO2_palik_data.csv"
al_data_path   = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/Al_Palik/CSV/Al_palik_data.csv"
andp_data_path = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/aNDP/CSV/aNPD_PFA_data.csv"

eps_inf_sio2, suscept_sio2 = Material_fit(Material_data_csv=sio2_data_path)
eps_inf_al, suscept_al = Material_fit(Material_data_csv=al_data_path)
eps_inf_andp, suscept_andp = Material_fit(Material_data_csv=andp_data_path)
# Out:
# Iteration   0, error: 0.000011
# Iteration   1, error: 0.000008
# Iteration   2, error: 0.000011
# Iteration   3, error: 0.000047
# Iteration   4, error: 0.000012
# Iteration   5, error: 0.000012
# Iteration   6, error: 0.000122
# Iteration   7, error: 0.000021
# Iteration   8, error: 0.000010
# Iteration   9, error: 0.000008
# Iteration  10, error: 0.000055
# Iteration  11, error: 0.000011
# Iteration  12, error: 0.000023
# Iteration  13, error: 0.000111
# Iteration  14, error: 0.000014
# Iteration  15, error: 0.000026
# Iteration  16, error: 0.000011
# Iteration  17, error: 0.000015
# Iteration  18, error: 0.000026
# Iteration  19, error: 0.000010
# Iteration  20, error: 0.000012
# Iteration  21, error: 0.000018
# Iteration  22, error: 0.000023
# Iteration  23, error: 0.000009
# Iteration  24, error: 0.000020
# Iteration  25, error: 0.000007
# Iteration  26, error: 0.000011
# Iteration  27, error: 0.000011
# Iteration  28, error: 0.000013
# Iteration  29, error: 0.000012
# Optimal error: 0.000007
# Iteration   0, error: 64.226780
# Iteration   1, error: 64.226780
# Iteration   2, error: 64.226780
# Iteration   3, error: 64.226780
# Iteration   4, error: 71292.592314
# Iteration   5, error: 64.226780
# Iteration   6, error: 3.131232
# Iteration   7, error: 71292.592314
# Iteration   8, error: 71292.592314
# Iteration   9, error: 54.483567
# Iteration  10, error: 64.226780
# Iteration  11, error: 64.226780
# Iteration  12, error: 71292.592314
# Iteration  13, error: 64.226780
# Iteration  14, error: 54.483567
# Iteration  15, error: 63938.469340
# Iteration  16, error: 64.226780
# Iteration  17, error: 64.226780
# Iteration  18, error: 54.483567
# Iteration  19, error: 64.226780
# Iteration  20, error: 54.483567
# Iteration  21, error: 64.226780
# Iteration  22, error: 71292.592314
# Iteration  23, error: 64.226780
# Iteration  24, error: 54.483567
# Iteration  25, error: 71292.592314
# Iteration  26, error: 3.149582
# Iteration  27, error: 64.226780
# Iteration  28, error: 64.226780
# Iteration  29, error: 64.226780
# Optimal error: 3.131232
# Iteration   0, error: 0.028818
# Iteration   1, error: 0.028058
# Iteration   2, error: 0.028058
# Iteration   3, error: 0.028109
# Iteration   4, error: 0.028363
# Iteration   5, error: 0.028058
# Iteration   6, error: 0.028058
# Iteration   7, error: 0.032414
# Iteration   8, error: 0.028058
# Iteration   9, error: 0.028058
# Iteration  10, error: 0.064846
# Iteration  11, error: 0.028074
# Iteration  12, error: 0.028058
# Iteration  13, error: 0.028058
# Iteration  14, error: 0.028058
# Iteration  15, error: 0.028058
# Iteration  16, error: 0.029698
# Iteration  17, error: 0.028058
# Iteration  18, error: 0.028058
# Iteration  19, error: 0.035636
# Iteration  20, error: 0.028058
# Iteration  21, error: 0.028407
# Iteration  22, error: 0.028450
# Iteration  23, error: 0.028058
# Iteration  24, error: 0.028058
# Iteration  25, error: 0.028058
# Iteration  26, error: 0.028058
# Iteration  27, error: 0.038621
# Iteration  28, error: 0.028058
# Iteration  29, error: 0.029207
# Optimal error: 0.028058

# %%
### ----- Refractive index ----- ###
Glass = mp.Medium(epsilon=eps_inf_sio2, E_susceptibilities = suscept_sio2) # SiO2 
aNDP = mp.Medium(epsilon=eps_inf_andp, E_susceptibilities = suscept_andp) # aNDP 
Cathode = mp.Medium(epsilon = eps_inf_al, E_susceptibilities = suscept_al)

# Cathode = mp.perfect_electric_conductor

CoverLayer = mp.Medium(index=1.9) # SiN 
ITO_m = mp.Medium(index=1.8) 
Alq3 = mp.Medium(index=1.68) 
Air = mp.Medium(index=1.0) # 공기

# %%
Glass_layer = 1.37
Cover_layer = 0.07
ITO_layer = 0.15
aNDP_layer = 0.05
Alq3_layer = 0.06
Cathode_layer = 0.3

# %%
Absorber_layer = 0.5

boundary_layers = [
    mp.Absorber(thickness=Absorber_layer, direction=mp.X, side=mp.Low),  # 좌측 Absorber
    mp.Absorber(thickness=Absorber_layer, direction=mp.X, side=mp.High), # 우측 Absorber
    mp.Absorber(thickness=Absorber_layer, direction=mp.Y, side=mp.High), # 상단 Absorber
    
]

# %%
Cathode_center = mp.Vector3(0, -0.85, 0)
Alq3_center = mp.Vector3(0, -0.67, 0)
aNDP_center = mp.Vector3(0, -0.615, 0)
ITO_center = mp.Vector3(0, -0.515, 0)
Cover_center = mp.Vector3(0, -0.405, 0)
Glass_center = mp.Vector3(0, 0.315, 0)

# %%
geometry = [
    # Cathode (하단)
    mp.Block(
        center=Cathode_center,
        size=mp.Vector3(30, Cathode_layer, 0),
        material=Cathode
    ),
    # Alq3
    mp.Block(
        center=Alq3_center,
        size=mp.Vector3(30, Alq3_layer, 0),
        material=Alq3
    ),
    # aNDP
    mp.Block(
        center=aNDP_center,
        size=mp.Vector3(30, aNDP_layer, 0),
        material=aNDP
    ),
    # ITO
    mp.Block(
        center=ITO_center,
        size=mp.Vector3(30, ITO_layer, 0),
        material=ITO_m
    ),
    # Cover layer
    mp.Block(
        center=Cover_center,
        size=mp.Vector3(30, Cover_layer, 0),
        material=CoverLayer
    ),
    # Glass (상단; (0,0,0)은 이 Glass 내부에 위치함)
    mp.Block(
        center=Glass_center,
        size=mp.Vector3(30, Glass_layer, 0),
        material=Glass
    )
]

# %%
cell_size = mp.Vector3(31, 2, 0)

# %%
source_center = mp.Vector3(0,-0.67,0)

sources = [mp.Source(
    src=mp.GaussianSource(frequency=fcen, fwidth=df),
    component=mp.Ex,
    center=source_center,
    size=mp.Vector3(0,0,0)
)]

# %%
# === 시뮬레이션 설정 === #
sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    default_material=mp.Medium(index = 1),
    sources=sources,
    resolution=resolution,
)

# %%
fig = plt.figure(dpi=200)
ax = plt.gca()
sim.plot2D(
    # output_plane=mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(2, 2, 0)),
    # eps_parameters={'cmap': 'coolwarm', 'alpha': 0.8},   # 투명도와 컬러맵
    # ax=ax
)

layer_boundaries = [
    -1.00,  # bottom of Cathode
    -0.70,  # Cathode-Alq3
    -0.64,  # Alq3-aNDP
    -0.59,  # aNDP-ITO
    -0.44,  # ITO-Cover
    -0.37,  # Cover-Glass
    1.005   # top of Glass
]

for y in layer_boundaries:
     ax.axhline(y=y, color='white', linestyle='--', linewidth=0.8)

# === 옵션 ===
plt.title("OLED Structure with Layer Boundaries")
plt.tight_layout()
plt.show()
# Out:
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %% [markdown]
# # near to far 각도 부여하는 방법에는 문제가 없다

# %% [markdown]
# 가우시안에 대한 필드 분포 뽑기

# %%
offset = 0.01
flux_size = 0.02

# Dipole 위치
source_center = mp.Vector3(0, -0.67,0)

focus_lambda_min = 0.4
focus_lambda_max = 0.7

focus_f_min = 1/focus_lambda_max
focus_f_max = 1/focus_lambda_min

fcen_monitor = 0.5 * (focus_f_min + focus_f_max)
df_monitor = focus_f_max - focus_f_min

# 박스 4면
x1 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux x1
    mp.FluxRegion(
        center=source_center - mp.Vector3(offset, 0,0),
        size=mp.Vector3(0,flux_size, 0),
        # direction=mp.Y,
        weight=-1
    ),
)

x2 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux x2
    mp.FluxRegion(
        center=source_center + mp.Vector3(offset, 0,0),
        size=mp.Vector3(0,flux_size, 0),
        # direction=mp.Y
    ),
)

y1 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux y1
    mp.FluxRegion(
        center=source_center - mp.Vector3(0, offset, 0),
        size=mp.Vector3(flux_size, 0),
        # direction=mp.Y,
        weight=-1
    ),
)

y2 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux y2
    mp.FluxRegion(
        center=source_center + mp.Vector3(0, offset, 0),
        size=mp.Vector3(flux_size, 0),
        # direction=mp.Y
    ),
)

# %%
offset = 0.01
flux_size = 0.02

# Dipole 위치
source_center = mp.Vector3(0, -0.67,0)

focus_lambda_min = 0.4
focus_lambda_max = 0.7

focus_f_min = 1/focus_lambda_max
focus_f_max = 1/focus_lambda_min

fcen_monitor = 0.5 * (focus_f_min + focus_f_max)
df_monitor = focus_f_max - focus_f_min

box_power = sim.add_flux(
    fcen_monitor, df_monitor, nfreq,
    mp.FluxRegion(center=source_center - mp.Vector3(offset, 0, 0),
                  size=mp.Vector3(0, flux_size),
                  # direction=mp.Y, 
                  weight=-1),
    mp.FluxRegion(center=source_center + mp.Vector3(offset, 0, 0),
                  size=mp.Vector3(0, flux_size),
                  # direction=mp.Y
                ),
    mp.FluxRegion(center=source_center - mp.Vector3(0, offset, 0),
                  size=mp.Vector3(flux_size, 0),
                  # direction=mp.Y, 
                  weight=-1),
    mp.FluxRegion(center=source_center + mp.Vector3(0, offset, 0),
                  size=mp.Vector3(flux_size, 0),
                  # direction=mp.Y
                  )
)

# %%
# center와 size를 사용해 Volume 객체 생성
vol = mp.Volume(center=mp.Vector3(0, -0.67, 0), size=mp.Vector3(2, 2, 0))
fig = plt.figure(dpi=200)
ax = plt.gca()

# 그 volume을 사용해서 2D 시각화
sim.plot2D(
    output_plane=mp.Volume(center=mp.Vector3(0,-0.67,0), size=mp.Vector3(0.1, 0.1, 0)),
    eps_parameters={'cmap': 'coolwarm', 'alpha': 0.8},   # 투명도와 컬러맵
    ax=ax
)
plt.show()
# Out:
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# /home/min/miniconda3/envs/mp/lib/python3.8/site-packages/meep/visualization.py:284: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(

# %%
#sim.run(until=50)
sim.run(until_after_sources=mp.stop_when_fields_decayed(100, mp.Ex, mp.Vector3(0,0,0), 1e-3))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 2D dimensions.
# Computational cell is 31 x 2 x 0 with resolution 100
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.809375 s
# time for set_conductivity = 0.0256832 s
# time for set_conductivity = 0.025624 s
# time for set_conductivity = 0.0266609 s
# time for set_conductivity = 0.027041 s
# time for set_conductivity = 0.0271471 s
# time for set_conductivity = 0.026932 s
# drude susceptibility: frequency=1, gamma=6.5785
# lorentzian susceptibility: frequency=10.5656, gamma=0
# lorentzian susceptibility: frequency=5.62022, gamma=0.0129248
# lorentzian susceptibility: frequency=2.66127, gamma=0.205589
# -----------
# on time step 211 (time=1.055), 0.0189845 s/step
# on time step 549 (time=2.745), 0.0118552 s/step
# on time step 898 (time=4.49), 0.0114693 s/step
# on time step 1243 (time=6.215), 0.0116055 s/step
# on time step 1597 (time=7.985), 0.0113126 s/step
# on time step 1956 (time=9.78), 0.0111455 s/step
# on time step 2308 (time=11.54), 0.0113694 s/step
# on time step 2654 (time=13.27), 0.0115689 s/step
# on time step 2876 (time=14.38), 0.0180566 s/step
# on time step 3221 (time=16.105), 0.0116076 s/step
# on time step 3567 (time=17.835), 0.0115764 s/step
# on time step 3928 (time=19.64), 0.011113 s/step
# on time step 4290 (time=21.45), 0.0110582 s/step
# on time step 4649 (time=23.245), 0.0111643 s/step
# on time step 5007 (time=25.035), 0.0111842 s/step
# on time step 5363 (time=26.815), 0.0112598 s/step
# on time step 5715 (time=28.575), 0.0154275 s/step
# on time step 6060 (time=30.3), 0.0116159 s/step
# on time step 6408 (time=32.04), 0.0115191 s/step
# on time step 6767 (time=33.835), 0.0111676 s/step
# on time step 7132 (time=35.66), 0.0109635 s/step
# on time step 7490 (time=37.45), 0.0111784 s/step
# on time step 7844 (time=39.22), 0.0113265 s/step
# on time step 8198 (time=40.99), 0.011318 s/step
# on time step 8551 (time=42.755), 0.0113335 s/step
# on time step 8776 (time=43.88), 0.0178053 s/step
# on time step 9127 (time=45.635), 0.0114286 s/step
# on time step 9485 (time=47.425), 0.0111851 s/step
# on time step 9844 (time=49.22), 0.0111612 s/step
# on time step 10211 (time=51.055), 0.010904 s/step
# on time step 10574 (time=52.87), 0.0110223 s/step
# on time step 10932 (time=54.66), 0.0111754 s/step
# on time step 11290 (time=56.45), 0.0112023 s/step
# on time step 11509 (time=57.545), 0.0182682 s/step
# on time step 11850 (time=59.25), 0.0117501 s/step
# on time step 12201 (time=61.005), 0.0114047 s/step
# on time step 12563 (time=62.815), 0.0110629 s/step
# on time step 12923 (time=64.615), 0.0111254 s/step
# on time step 13300 (time=66.5), 0.0106296 s/step
# on time step 13660 (time=68.3), 0.0111204 s/step
# on time step 14017 (time=70.085), 0.011229 s/step
# on time step 14328 (time=71.64), 0.0161542 s/step
# on time step 14665 (time=73.325), 0.0118889 s/step
# on time step 15021 (time=75.105), 0.0112611 s/step
# on time step 15389 (time=76.945), 0.0108964 s/step
# on time step 15756 (time=78.78), 0.010925 s/step
# on time step 16113 (time=80.565), 0.0112072 s/step
# on time step 16471 (time=82.355), 0.0111821 s/step
# on time step 16831 (time=84.155), 0.0111228 s/step
# on time step 17191 (time=85.955), 0.0111306 s/step
# on time step 17405 (time=87.025), 0.0187263 s/step
# on time step 17755 (time=88.775), 0.0114398 s/step
# on time step 18116 (time=90.58), 0.0111107 s/step
# on time step 18483 (time=92.415), 0.0109124 s/step
# on time step 18842 (time=94.21), 0.0111426 s/step
# on time step 19197 (time=95.985), 0.011271 s/step
# on time step 19553 (time=97.765), 0.0112582 s/step
# on time step 19908 (time=99.54), 0.011275 s/step
# field decay(t = 100.005): 0.47292781928786337 / 0.47292781928786337 = 1.0
# on time step 20125 (time=100.625), 0.0184894 s/step
# on time step 20464 (time=102.32), 0.0118005 s/step
# on time step 20820 (time=104.1), 0.011269 s/step
# on time step 21186 (time=105.93), 0.01094 s/step
# on time step 21543 (time=107.715), 0.0112151 s/step
# on time step 21895 (time=109.475), 0.0113848 s/step
# on time step 22247 (time=111.235), 0.0113663 s/step
# on time step 22603 (time=113.015), 0.0112504 s/step
# on time step 22954 (time=114.77), 0.0114113 s/step
# on time step 23166 (time=115.83), 0.0188914 s/step
# on time step 23514 (time=117.57), 0.0114958 s/step
# on time step 23875 (time=119.375), 0.0111106 s/step
# on time step 24232 (time=121.16), 0.0112058 s/step
# on time step 24594 (time=122.97), 0.0110572 s/step
# on time step 24960 (time=124.8), 0.0109409 s/step
# on time step 25313 (time=126.565), 0.0113379 s/step
# on time step 25665 (time=128.325), 0.0113709 s/step
# on time step 25878 (time=129.39), 0.0188118 s/step
# on time step 26224 (time=131.12), 0.0115733 s/step
# on time step 26578 (time=132.89), 0.0113014 s/step
# on time step 26936 (time=134.68), 0.0111927 s/step
# on time step 27291 (time=136.455), 0.0112715 s/step
# on time step 27645 (time=138.225), 0.0113223 s/step
# on time step 28001 (time=140.005), 0.0112547 s/step
# on time step 28354 (time=141.77), 0.011336 s/step
# on time step 28697 (time=143.485), 0.0116641 s/step
# on time step 28914 (time=144.57), 0.0184467 s/step
# on time step 29273 (time=146.365), 0.0111532 s/step
# on time step 29640 (time=148.2), 0.0109071 s/step
# on time step 30005 (time=150.025), 0.0109592 s/step
# on time step 30367 (time=151.835), 0.0110577 s/step
# on time step 30727 (time=153.635), 0.0111312 s/step
# on time step 31083 (time=155.415), 0.011264 s/step
# on time step 31438 (time=157.19), 0.0112708 s/step
# on time step 31648 (time=158.24), 0.0190656 s/step
# on time step 32000 (time=160), 0.0113774 s/step
# on time step 32362 (time=161.81), 0.0110628 s/step
# on time step 32731 (time=163.655), 0.0108592 s/step
# on time step 33098 (time=165.49), 0.0109229 s/step
# on time step 33459 (time=167.295), 0.0110986 s/step
# on time step 33814 (time=169.07), 0.0112778 s/step
# on time step 34165 (time=170.825), 0.0114113 s/step
# on time step 34506 (time=172.53), 0.0117353 s/step
# on time step 34727 (time=173.635), 0.0181379 s/step
# on time step 35081 (time=175.405), 0.0113118 s/step
# on time step 35438 (time=177.19), 0.0112258 s/step
# on time step 35797 (time=178.985), 0.0111464 s/step
# on time step 36155 (time=180.775), 0.0111876 s/step
# on time step 36513 (time=182.565), 0.0111983 s/step
# on time step 36868 (time=184.34), 0.011286 s/step
# on time step 37215 (time=186.075), 0.0115532 s/step
# on time step 37429 (time=187.145), 0.0187473 s/step
# on time step 37782 (time=188.91), 0.0113409 s/step
# on time step 38150 (time=190.75), 0.0108756 s/step
# on time step 38516 (time=192.58), 0.0109326 s/step
# on time step 38876 (time=194.38), 0.0111216 s/step
# on time step 39229 (time=196.145), 0.0113372 s/step
# on time step 39575 (time=197.875), 0.0115656 s/step
# on time step 39920 (time=199.6), 0.0116107 s/step
# field decay(t = 200.005): 3.4162140196895525e-08 / 0.47292781928786337 = 7.223542114383758e-08
# run 0 finished at t = 200.005 (40001 timesteps)

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import os
import imageio

# 저장 폴더 설정
frame_dir = "frames"
os.makedirs(frame_dir, exist_ok=True)


# 필드 시각화 함수
def save_frame(sim):
    eps_data = sim.get_array(center=mp.Vector3(), size=cell_size, component=mp.Dielectric)
    field_data = sim.get_array(center=mp.Vector3(), size=cell_size, component=mp.Ex)

    plt.figure(figsize=(20, 5))
    plt.imshow(np.rot90(field_data), cmap='RdBu', extent=[-cell_size.x/2, cell_size.x/2, -cell_size.y/2, cell_size.y/2], interpolation='spline36',  vmin = -1, vmax = 1)
    plt.colorbar(label='Ex')
    plt.title(f"t = {sim.meep_time():.2f}")
    plt.xlabel("x (μm)")
    plt.ylabel("y (μm)")
    plt.tight_layout()
    
    frame_path = os.path.join(frame_dir, f"frame_{sim.meep_time():.2f}.png")
    plt.savefig(frame_path)
    plt.close()

# 시뮬레이션 실행 + 프레임 저장
sim.run(mp.at_every(1.0, save_frame),  # 1 time unit마다 저장
        until_after_sources=mp.stop_when_fields_decayed(100, mp.Ex, mp.Vector3(0,-0.67), 1e-3))

# 이미지들을 GIF로 변환
with imageio.get_writer("radiation.gif", mode="I", duration=0.2) as writer:
    for filename in sorted(os.listdir(frame_dir)):
        if filename.endswith(".png"):
            image = imageio.imread(os.path.join(frame_dir, filename))
            writer.append_data(image)

print("✅ radiation.gif 생성 완료!")
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.00272e-05 s
# Working in 2D dimensions.
# Computational cell is 31 x 2 x 0 with resolution 100
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.79153 s
# time for set_conductivity = 0.0252249 s
# time for set_conductivity = 0.0259862 s
# time for set_conductivity = 0.025213 s
# time for set_conductivity = 0.0255721 s
# time for set_conductivity = 0.0254021 s
# time for set_conductivity = 0.025547 s
# drude susceptibility: frequency=1, gamma=6.5785
# lorentzian susceptibility: frequency=10.5656, gamma=0
# lorentzian susceptibility: frequency=5.62022, gamma=0.0129248
# lorentzian susceptibility: frequency=2.66127, gamma=0.205589
# -----------
# on time step 289 (time=1.445), 0.0138529 s/step
# on time step 594 (time=2.97), 0.0131505 s/step
# on time step 883 (time=4.415), 0.0138511 s/step
# on time step 1200 (time=6), 0.0135686 s/step
# on time step 1507 (time=7.535), 0.0130321 s/step
# on time step 1800 (time=9), 0.0138255 s/step
# on time step 2001 (time=10.005), 0.0199081 s/step
# on time step 2317 (time=11.585), 0.0126718 s/step
# on time step 2600 (time=13), 0.0148147 s/step
# on time step 2935 (time=14.675), 0.0119453 s/step
# on time step 3232 (time=16.16), 0.0134816 s/step
# on time step 3544 (time=17.72), 0.0128391 s/step
# on time step 3829 (time=19.145), 0.0140697 s/step
# on time step 4135 (time=20.675), 0.013087 s/step
# on time step 4397 (time=21.985), 0.0187539 s/step
# on time step 4670 (time=23.35), 0.0146705 s/step
# on time step 4974 (time=24.87), 0.0131673 s/step
# on time step 5282 (time=26.41), 0.0129916 s/step
# on time step 5600 (time=28), 0.0128672 s/step
# on time step 5922 (time=29.61), 0.0124402 s/step
# on time step 6200 (time=31), 0.0145089 s/step
# on time step 6494 (time=32.47), 0.013627 s/step
# on time step 6788 (time=33.94), 0.0136244 s/step
# on time step 6953 (time=34.765), 0.0242872 s/step
# on time step 7211 (time=36.055), 0.0155235 s/step
# on time step 7515 (time=37.575), 0.0131657 s/step
# on time step 7800 (time=39), 0.0144584 s/step
# on time step 8119 (time=40.595), 0.0125474 s/step
# on time step 8408 (time=42.04), 0.0138846 s/step
# on time step 8705 (time=43.525), 0.0134711 s/step
# on time step 9000 (time=45), 0.0142357 s/step
# on time step 9200 (time=46), 0.0216264 s/step
# on time step 9493 (time=47.465), 0.0136527 s/step
# on time step 9800 (time=49), 0.0138391 s/step
# on time step 10115 (time=50.575), 0.0127192 s/step
# on time step 10404 (time=52.02), 0.0138707 s/step
# on time step 10725 (time=53.625), 0.0124623 s/step
# on time step 11013 (time=55.065), 0.0139164 s/step
# on time step 11325 (time=56.625), 0.0128459 s/step
# on time step 11565 (time=57.825), 0.0197417 s/step
# on time step 11843 (time=59.215), 0.0143947 s/step
# on time step 12152 (time=60.76), 0.0129771 s/step
# on time step 12453 (time=62.265), 0.0133048 s/step
# on time step 12747 (time=63.735), 0.0136181 s/step
# on time step 13023 (time=65.115), 0.0145056 s/step
# on time step 13334 (time=66.67), 0.0128683 s/step
# on time step 13613 (time=68.065), 0.0143533 s/step
# on time step 13920 (time=69.6), 0.0130312 s/step
# on time step 14094 (time=70.47), 0.0230068 s/step
# on time step 14392 (time=71.96), 0.013457 s/step
# on time step 14680 (time=73.4), 0.0138901 s/step
# on time step 14967 (time=74.835), 0.0139416 s/step
# on time step 15253 (time=76.265), 0.0139939 s/step
# on time step 15559 (time=77.795), 0.0130902 s/step
# on time step 15841 (time=79.205), 0.0141875 s/step
# on time step 16146 (time=80.73), 0.0131402 s/step
# on time step 16328 (time=81.64), 0.0220353 s/step
# on time step 16600 (time=83), 0.0147654 s/step
# on time step 16914 (time=84.57), 0.0127728 s/step
# on time step 17208 (time=86.04), 0.013623 s/step
# on time step 17521 (time=87.605), 0.012795 s/step
# on time step 17800 (time=89), 0.0144594 s/step
# on time step 18067 (time=90.335), 0.0150224 s/step
# on time step 18369 (time=91.845), 0.0132494 s/step
# on time step 18609 (time=93.045), 0.0208502 s/step
# on time step 18910 (time=94.55), 0.0133105 s/step
# on time step 19200 (time=96), 0.0138067 s/step
# on time step 19508 (time=97.54), 0.0130126 s/step
# on time step 19800 (time=99), 0.0141161 s/step
# field decay(t = 100.005): 0.47292781928786337 / 0.47292781928786337 = 1.0
# on time step 20106 (time=100.53), 0.0130983 s/step
# on time step 20400 (time=102), 0.0149141 s/step
# on time step 20709 (time=103.545), 0.0129742 s/step
# on time step 20994 (time=104.97), 0.0182656 s/step
# on time step 21271 (time=106.355), 0.0144713 s/step
# on time step 21573 (time=107.865), 0.0132532 s/step
# on time step 21850 (time=109.25), 0.014464 s/step
# on time step 22155 (time=110.775), 0.0131262 s/step
# on time step 22434 (time=112.17), 0.0143436 s/step
# on time step 22745 (time=113.725), 0.012863 s/step
# on time step 23034 (time=115.17), 0.0138678 s/step
# on time step 23335 (time=116.675), 0.0133245 s/step
# on time step 23529 (time=117.645), 0.0206574 s/step
# on time step 23819 (time=119.095), 0.0138088 s/step
# on time step 24134 (time=120.67), 0.0127181 s/step
# on time step 24427 (time=122.135), 0.0136641 s/step
# on time step 24739 (time=123.695), 0.0128522 s/step
# on time step 25008 (time=125.04), 0.0148893 s/step
# on time step 25307 (time=126.535), 0.0134114 s/step
# on time step 25600 (time=128), 0.0143514 s/step
# on time step 25800 (time=129), 0.0209516 s/step
# on time step 26104 (time=130.52), 0.0131747 s/step
# on time step 26400 (time=132), 0.0143383 s/step
# on time step 26710 (time=133.55), 0.0129154 s/step
# on time step 27000 (time=135), 0.0142568 s/step
# on time step 27301 (time=136.505), 0.0133242 s/step
# on time step 27600 (time=138), 0.0144944 s/step
# on time step 27902 (time=139.51), 0.0132833 s/step
# on time step 28089 (time=140.445), 0.0214482 s/step
# on time step 28395 (time=141.975), 0.0130936 s/step
# on time step 28672 (time=143.36), 0.0144648 s/step
# on time step 28978 (time=144.89), 0.013086 s/step
# on time step 29253 (time=146.265), 0.0145865 s/step
# on time step 29547 (time=147.735), 0.0136448 s/step
# on time step 29811 (time=149.055), 0.0151622 s/step
# on time step 30095 (time=150.475), 0.0141177 s/step
# on time step 30388 (time=151.94), 0.0181374 s/step
# on time step 30665 (time=153.325), 0.0144511 s/step
# on time step 30973 (time=154.865), 0.0130014 s/step
# on time step 31256 (time=156.28), 0.0141864 s/step
# on time step 31558 (time=157.79), 0.0132584 s/step
# on time step 31840 (time=159.2), 0.0141866 s/step
# on time step 32134 (time=160.67), 0.0136175 s/step
# on time step 32409 (time=162.045), 0.0145745 s/step
# on time step 32712 (time=163.56), 0.0132435 s/step
# on time step 32897 (time=164.485), 0.0216496 s/step
# on time step 33197 (time=165.985), 0.0133556 s/step
# on time step 33473 (time=167.365), 0.0145232 s/step
# on time step 33770 (time=168.85), 0.013477 s/step
# on time step 34047 (time=170.235), 0.0144534 s/step
# on time step 34340 (time=171.7), 0.0136539 s/step
# on time step 34616 (time=173.08), 0.0145059 s/step
# on time step 34914 (time=174.57), 0.0134511 s/step
# on time step 35102 (time=175.51), 0.0213253 s/step
# on time step 35400 (time=177), 0.0139948 s/step
# on time step 35710 (time=178.55), 0.0129424 s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 30
#      27     plt.close()
#      29 # 시뮬레이션 실행 + 프레임 저장
# ---> 30 sim.run(mp.at_every(1.0, save_frame),  # 1 time unit마다 저장
#      31         until_after_sources=mp.stop_when_fields_decayed(100, mp.Ex, mp.Vector3(), 1e-3))
#      33 # 이미지들을 GIF로 변환
#      34 with imageio.get_writer("radiation.gif", mode="I", duration=0.2) as writer:
#
# File ~/miniconda3/envs/mp/lib/python3.8/site-packages/meep/simulation.py:4534, in Simulation.run(self, *step_funcs, **kwargs)
#    4531     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4533 if until_after_sources is not None:
# -> 4534     self._run_sources_until(until_after_sources, step_funcs)
#    4535 elif until is not None:
#    4536     self._run_until(until, step_funcs)
#
# File ~/miniconda3/envs/mp/lib/python3.8/site-packages/meep/simulation.py:2874, in Simulation._run_sources_until(self, cond, step_funcs)
#    2870             return cond[i](sim) and sim.round_time() >= ts
#    2872         new_conds.append(f)
# -> 2874 self._run_until(new_conds, step_funcs)
#
# File ~/miniconda3/envs/mp/lib/python3.8/site-packages/meep/simulation.py:2832, in Simulation._run_until(self, cond, step_funcs)
#    2830     for func in step_funcs:
#    2831         _eval_step_func(self, func, "step")
# -> 2832     self.fields.step()
#    2834 # Translating the recursive scheme version of run-until into an iterative version
#    2835 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2836 # be the same as scheme.
#    2837 for func in step_funcs:
#
# File ~/miniconda3/envs/mp/lib/python3.8/site-packages/meep/__init__.py:3041, in fields.step(self)
#    3040 def step(self):
# -> 3041     return _meep.fields_step(self)
#
# KeyboardInterrupt:

# %%
# net_power = np.array(mp.get_fluxes(x1))+np.array(mp.get_fluxes(x2))+np.array(mp.get_fluxes(y1))+np.array(mp.get_fluxes(y2))
net_power = np.square(net_power)

# %%
sim.run(until = 50)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 2D dimensions.
# Computational cell is 31 x 2 x 0 with resolution 100
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.839077 s
# time for set_conductivity = 0.0254149 s
# time for set_conductivity = 0.025686 s
# time for set_conductivity = 0.0268521 s
# time for set_conductivity = 0.0263829 s
# time for set_conductivity = 0.0261948 s
# time for set_conductivity = 0.0256989 s
# lorentzian susceptibility: frequency=10.902, gamma=0
# lorentzian susceptibility: frequency=7.72929, gamma=0
# lorentzian susceptibility: frequency=2.66127, gamma=0.205589
# lorentzian susceptibility: frequency=5.62022, gamma=0.0129247
# lorentzian susceptibility: frequency=1.01629, gamma=0.899161
# drude susceptibility: frequency=1, gamma=0
# -----------
# Meep progress: 1.03/50.0 = 2.1% done in 4.0s, 190.5s to go
# on time step 206 (time=1.03), 0.0194505 s/step
# Meep progress: 2.11/50.0 = 4.2% done in 8.0s, 181.8s to go
# on time step 422 (time=2.11), 0.0185291 s/step
# Meep progress: 3.19/50.0 = 6.4% done in 12.0s, 176.3s to go
# on time step 638 (time=3.19), 0.0185387 s/step
# Meep progress: 3.895/50.0 = 7.8% done in 16.0s, 189.6s to go
# on time step 779 (time=3.895), 0.028404 s/step
# Meep progress: 4.99/50.0 = 10.0% done in 20.0s, 180.6s to go
# on time step 998 (time=4.99), 0.0182775 s/step
# Meep progress: 6.085/50.0 = 12.2% done in 24.0s, 173.4s to go
# on time step 1217 (time=6.085), 0.0183083 s/step
# Meep progress: 7.2/50.0 = 14.4% done in 28.0s, 166.7s to go
# on time step 1440 (time=7.2), 0.0179695 s/step
# Meep progress: 8.3/50.0 = 16.6% done in 32.0s, 161.0s to go
# on time step 1660 (time=8.3), 0.0182048 s/step
# Meep progress: 9.405/50.0 = 18.8% done in 36.1s, 155.7s to go
# on time step 1881 (time=9.405), 0.0181687 s/step
# Meep progress: 10.52/50.0 = 21.0% done in 40.1s, 150.4s to go
# on time step 2104 (time=10.52), 0.0179876 s/step
# Meep progress: 11.615/50.0 = 23.2% done in 44.1s, 145.7s to go
# on time step 2323 (time=11.615), 0.0182654 s/step
# Meep progress: 12.34/50.0 = 24.7% done in 48.1s, 146.7s to go
# on time step 2469 (time=12.345), 0.0275083 s/step
# Meep progress: 13.435/50.0 = 26.9% done in 52.1s, 141.7s to go
# on time step 2688 (time=13.44), 0.0182779 s/step
# Meep progress: 14.530000000000001/50.0 = 29.1% done in 56.1s, 136.9s to go
# on time step 2907 (time=14.535), 0.0183182 s/step
# Meep progress: 15.655000000000001/50.0 = 31.3% done in 60.1s, 131.8s to go
# on time step 3132 (time=15.66), 0.0178169 s/step
# Meep progress: 16.77/50.0 = 33.5% done in 64.1s, 127.0s to go
# on time step 3355 (time=16.775), 0.0179549 s/step
# Meep progress: 17.885/50.0 = 35.8% done in 68.1s, 122.3s to go
# on time step 3578 (time=17.89), 0.0179863 s/step
# Meep progress: 19.005/50.0 = 38.0% done in 72.1s, 117.6s to go
# on time step 3802 (time=19.01), 0.0179042 s/step
# Meep progress: 20.12/50.0 = 40.2% done in 76.1s, 113.1s to go
# on time step 4025 (time=20.125), 0.0179815 s/step
# Meep progress: 21.145/50.0 = 42.3% done in 81.2s, 110.8s to go
# on time step 4229 (time=21.145), 0.024708 s/step
# Meep progress: 22.285/50.0 = 44.6% done in 85.2s, 106.0s to go
# on time step 4457 (time=22.285), 0.0176185 s/step
# Meep progress: 23.405/50.0 = 46.8% done in 89.2s, 101.4s to go
# on time step 4681 (time=23.405), 0.0178695 s/step
# Meep progress: 24.515/50.0 = 49.0% done in 93.2s, 96.9s to go
# on time step 4903 (time=24.515), 0.0180371 s/step
# Meep progress: 25.635/50.0 = 51.3% done in 97.2s, 92.4s to go
# on time step 5127 (time=25.635), 0.0178853 s/step
# Meep progress: 26.75/50.0 = 53.5% done in 101.2s, 88.0s to go
# on time step 5350 (time=26.75), 0.0179781 s/step
# Meep progress: 27.865000000000002/50.0 = 55.7% done in 105.2s, 83.6s to go
# on time step 5573 (time=27.865), 0.0179601 s/step
# Meep progress: 28.990000000000002/50.0 = 58.0% done in 109.3s, 79.2s to go
# on time step 5798 (time=28.99), 0.0178195 s/step
# Meep progress: 30.135/50.0 = 60.3% done in 113.3s, 74.7s to go
# on time step 6028 (time=30.14), 0.0174671 s/step
# Meep progress: 30.8/50.0 = 61.6% done in 117.3s, 73.1s to go
# on time step 6161 (time=30.805), 0.0301468 s/step
# Meep progress: 31.915/50.0 = 63.8% done in 121.3s, 68.7s to go
# on time step 6384 (time=31.92), 0.0179662 s/step
# Meep progress: 33.025/50.0 = 66.0% done in 125.3s, 64.4s to go
# on time step 6606 (time=33.03), 0.0180497 s/step
# Meep progress: 34.145/50.0 = 68.3% done in 129.3s, 60.0s to go
# on time step 6830 (time=34.15), 0.017868 s/step
# Meep progress: 35.27/50.0 = 70.5% done in 133.3s, 55.7s to go
# on time step 7055 (time=35.275), 0.017848 s/step
# Meep progress: 36.39/50.0 = 72.8% done in 137.3s, 51.4s to go
# on time step 7279 (time=36.395), 0.0178875 s/step
# Meep progress: 37.515/50.0 = 75.0% done in 141.3s, 47.0s to go
# on time step 7504 (time=37.52), 0.0178345 s/step
# Meep progress: 38.56/50.0 = 77.1% done in 145.3s, 43.1s to go
# on time step 7713 (time=38.565), 0.0191546 s/step
# Meep progress: 39.325/50.0 = 78.7% done in 149.3s, 40.5s to go
# on time step 7866 (time=39.33), 0.0262339 s/step
# Meep progress: 40.44/50.0 = 80.9% done in 153.3s, 36.3s to go
# on time step 8089 (time=40.445), 0.0179783 s/step
# Meep progress: 41.550000000000004/50.0 = 83.1% done in 157.4s, 32.0s to go
# on time step 8311 (time=41.555), 0.0181043 s/step
# Meep progress: 42.67/50.0 = 85.3% done in 161.4s, 27.7s to go
# on time step 8535 (time=42.675), 0.0179041 s/step
# Meep progress: 43.800000000000004/50.0 = 87.6% done in 165.4s, 23.4s to go
# on time step 8761 (time=43.805), 0.0177518 s/step
# Meep progress: 44.910000000000004/50.0 = 89.8% done in 169.4s, 19.2s to go
# on time step 8983 (time=44.915), 0.018023 s/step
# Meep progress: 46.02/50.0 = 92.0% done in 173.4s, 15.0s to go
# on time step 9205 (time=46.025), 0.0180805 s/step
# Meep progress: 47.125/50.0 = 94.2% done in 177.4s, 10.8s to go
# on time step 9426 (time=47.13), 0.0181174 s/step
# Meep progress: 48.08/50.0 = 96.2% done in 182.3s, 7.3s to go
# on time step 9616 (time=48.08), 0.0254159 s/step
# Meep progress: 49.195/50.0 = 98.4% done in 186.3s, 3.0s to go
# on time step 9839 (time=49.195), 0.0179792 s/step
# run 0 finished at t = 50.0 (10000 timesteps)

# %%
net_power_fitting_al = mp.get_fluxes(box_power)

# %% [markdown]
# ## Air에서의 far field E field 뽑는걸 이번주 목표로 -> Meep air far field
#
# ### Meep에서 air, sio2

# %%
frequencies = mp.get_flux_freqs(x1)

wavelengths = [1/f for f in frequencies]

print("λ (μm)\t\tdipolepower_box (W)")
for i in range(nfreq):
    print(f"{frequencies[i]:.4f}\t\t{net_power[i]:.6e}")
# Out:
# λ (μm)		dipolepower_box (W)
# 1.4286		6.490496e-03
# 1.4394		6.783806e-03
# 1.4502		7.101633e-03
# 1.4610		7.407199e-03
# 1.4719		7.736956e-03
# 1.4827		8.056556e-03
# 1.4935		8.398611e-03
# 1.5043		8.734267e-03
# 1.5152		9.089061e-03
# 1.5260		9.442660e-03
# 1.5368		9.810461e-03
# 1.5476		1.018344e-02
# 1.5584		1.056418e-02
# 1.5693		1.095730e-02
# 1.5801		1.135055e-02
# 1.5909		1.176388e-02
# 1.6017		1.216896e-02
# 1.6126		1.260197e-02
# 1.6234		1.301824e-02
# 1.6342		1.347013e-02
# 1.6450		1.389728e-02
# 1.6558		1.436732e-02
# 1.6667		1.480576e-02
# 1.6775		1.529357e-02
# 1.6883		1.574461e-02
# 1.6991		1.625041e-02
# 1.7100		1.671626e-02
# 1.7208		1.724086e-02
# 1.7316		1.772446e-02
# 1.7424		1.826910e-02
# 1.7532		1.877370e-02
# 1.7641		1.933969e-02
# 1.7749		1.986831e-02
# 1.7857		2.045659e-02
# 1.7965		2.101138e-02
# 1.8074		2.162198e-02
# 1.8182		2.220359e-02
# 1.8290		2.283518e-02
# 1.8398		2.344230e-02
# 1.8506		2.409188e-02
# 1.8615		2.472086e-02
# 1.8723		2.538345e-02
# 1.8831		2.602811e-02
# 1.8939		2.669681e-02
# 1.9048		2.734863e-02
# 1.9156		2.801459e-02
# 1.9264		2.866256e-02
# 1.9372		2.931474e-02
# 1.9481		2.994518e-02
# 1.9589		3.056996e-02
# 1.9697		3.116618e-02
# 1.9805		3.174690e-02
# 1.9913		3.228897e-02
# 2.0022		3.280575e-02
# 2.0130		3.327077e-02
# 2.0238		3.370111e-02
# 2.0346		3.406459e-02
# 2.0455		3.438528e-02
# 2.0563		3.462379e-02
# 2.0671		3.481399e-02
# 2.0779		3.490866e-02
# 2.0887		3.495345e-02
# 2.0996		3.489337e-02
# 2.1104		3.478650e-02
# 2.1212		3.457068e-02
# 2.1320		3.431563e-02
# 2.1429		3.395299e-02
# 2.1537		3.356196e-02
# 2.1645		3.306939e-02
# 2.1753		3.256075e-02
# 2.1861		3.196006e-02
# 2.1970		3.135527e-02
# 2.2078		3.067050e-02
# 2.2186		2.999184e-02
# 2.2294		2.924571e-02
# 2.2403		2.851365e-02
# 2.2511		2.772768e-02
# 2.2619		2.696068e-02
# 2.2727		2.615343e-02
# 2.2835		2.536729e-02
# 2.2944		2.455445e-02
# 2.3052		2.376247e-02
# 2.3160		2.295699e-02
# 2.3268		2.217021e-02
# 2.3377		2.138254e-02
# 2.3485		2.061002e-02
# 2.3593		1.984837e-02
# 2.3701		1.909752e-02
# 2.3810		1.836817e-02
# 2.3918		1.764492e-02
# 2.4026		1.695248e-02
# 2.4134		1.626154e-02
# 2.4242		1.560922e-02
# 2.4351		1.495432e-02
# 2.4459		1.434443e-02
# 2.4567		1.372883e-02
# 2.4675		1.316269e-02
# 2.4784		1.258858e-02
# 2.4892		1.206718e-02
# 2.5000		1.153687e-02

# %%
plt.figure(figsize=(8,6))
plt.plot(wavelengths, net_power, '-', label='dipolepower_box', color = 'green')
plt.xlabel('Wavelength (μm)')
plt.ylabel('dipolepower_box (W)')
plt.title('dipolepower_box vs. Wavelength')
# plt.ylim(-4, 14)  # y축 최소값: -4, 최대값: 14
# plt.xlim([0.4, 0.7])
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# CSV 파일 불러오기
data = np.genfromtxt("dipole_power.csv", delimiter=",", skip_header=1)

# 데이터 분리
wavelengths = data[:, 0]
source_power = data[:, 1]

# 슬라이싱: 0.5μm ≤ λ ≤ 1.0μm
# mask = (wavelengths >= 0) & (wavelengths <= 10)
wavelength_sliced = wavelengths
power_sliced = source_power

# 결과 출력
print("슬라이싱된 wavelength:", wavelength_sliced)
print("슬라이싱된 power:", power_sliced)
# Out:
# 슬라이싱된 wavelength: [0.7        0.69473684 0.68955224 0.68444444 0.67941176 0.67445255
#  0.66956522 0.6647482  0.66       0.65531915 0.65070423 0.64615385
#  0.64166667 0.63724138 0.63287671 0.62857143 0.62432432 0.62013423
#  0.616      0.61192053 0.60789474 0.60392157 0.6        0.59612903
#  0.59230769 0.58853503 0.58481013 0.58113208 0.5775     0.57391304
#  0.57037037 0.56687117 0.56341463 0.56       0.55662651 0.55329341
#  0.55       0.54674556 0.54352941 0.54035088 0.5372093  0.53410405
#  0.53103448 0.528      0.525      0.5220339  0.51910112 0.51620112
#  0.51333333 0.51049724 0.50769231 0.50491803 0.50217391 0.49945946
#  0.49677419 0.49411765 0.49148936 0.48888889 0.48631579 0.48376963
#  0.48125    0.47875648 0.47628866 0.47384615 0.47142857 0.46903553
#  0.46666667 0.46432161 0.462      0.45970149 0.45742574 0.45517241
#  0.45294118 0.45073171 0.44854369 0.44637681 0.44423077 0.44210526
#  0.44       0.43791469 0.43584906 0.43380282 0.4317757  0.42976744
#  0.42777778 0.42580645 0.42385321 0.42191781 0.42       0.41809955
#  0.41621622 0.41434978 0.4125     0.41066667 0.40884956 0.40704846
#  0.40526316 0.40349345 0.40173913 0.4       ]
# 슬라이싱된 power: [0.00974608 0.01022019 0.0107057  0.0112023  0.01171012 0.01222924
#  0.01275924 0.01329905 0.01384728 0.01440285 0.01496523 0.01553431
#  0.01610976 0.01669064 0.01727537 0.01786222 0.01844992 0.01903782
#  0.01962556 0.02021243 0.02079707 0.02137751 0.02195189 0.02251891
#  0.0230779  0.02362838 0.02416942 0.02469934 0.02521612 0.02571796
#  0.02620376 0.02667306 0.0271254  0.02755979 0.02797456 0.02836785
#  0.02873825 0.02908512 0.02940833 0.02970765 0.02998224 0.0302307
#  0.03045163 0.03064423 0.03080848 0.03094473 0.03105311 0.03113309
#  0.03118375 0.03120435 0.03119483 0.03115584 0.03108826 0.03099258
#  0.03086872 0.03071632 0.03053533 0.03032645 0.03009091 0.02983001
#  0.02954459 0.02923495 0.02890127 0.02854412 0.02816477 0.02776488
#  0.02734597 0.02690908 0.02645477 0.02598361 0.02549663 0.0249954
#  0.02448173 0.02395715 0.02342271 0.02287907 0.02232699 0.02176768
#  0.02120275 0.02063392 0.0200625  0.01948936 0.01891509 0.01834045
#  0.01776659 0.01719496 0.01662692 0.01606344 0.01550508 0.01495225
#  0.01440555 0.01386593 0.01333446 0.01281209 0.01229935 0.01179648
#  0.01130363 0.01082118 0.01034975 0.00989005]

# %%
dp_fitting_al = net_power_fitting_al / source_power
# dp_PEC = net_power_PEC / source_power

# 5. Plot
plt.figure(figsize=(8, 5))

plt.plot(wavelengths, dp_fitting_al,  label='with fitting Al', color='red')
# plt.plot(wavelengths, dp_PEC,  label='with PEC', color='blue')


plt.xlabel("Wavelength (μm)")
plt.ylabel("dp = net_power / source_power")
plt.title("Normalized Dipole Radiation Power")
plt.grid(True)
plt.legend()
plt.tight_layout()
# plt.yscale("log")

plt.ylim([0, 1.5])
plt.xlim([0.4, 0.7])
plt.show()

# %% [markdown]
# sim.add_flux(...) → Fourier-transformed field 데이터를 누적 시작
#
# sim.get_fluxes(flux_obj) → 누적된 데이터를 바탕으로 power 계산
#
# sim.get_dft_array(...) → 실제 E, H field의 Fourier transformed 값을 배열로 받을 수 있음

# %% [markdown]
# → 파장이 길어질수록 source dipole의 방사효율은 줄어들지만, 시스템은 에너지를 더 잘 전달함 → dp 증가.
