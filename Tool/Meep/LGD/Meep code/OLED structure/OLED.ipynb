# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import nlopt
from meep_material import lorentzfit

# %%
resolution = 100
nfreq = 100

fcen = 1.75
df = 3.3

# %%
def Material_fit(Material_data_csv=".", 
                   eps_inf=1,
                   fit_wl_min=0.38, fit_wl_max=0.72,
                   num_lorentzians=2, iteration=30
                   ):    

    # 1. 데이터 로드 및 전처리
    data = np.genfromtxt(Material_data_csv, delimiter=",")
    wl = data[:, 0] * 1e6  # 파장 (µm)
    n_data = data[:, 1] + 1j * data[:, 2]
    eps_all = np.square(n_data) - eps_inf

    # 피팅 범위로 데이터 선택
    mask = (wl >= fit_wl_min) & (wl <= fit_wl_max)
    wl_fit, eps_fit = wl[mask], eps_all[mask]
    freqs_fit = 1 / wl_fit

    # 2. Lorentzian 피팅 최적화
    ps = np.zeros((iteration, 3 * num_lorentzians))
    errors = np.zeros(iteration)
    for m in range(iteration):
        p_rand = [10 ** np.random.random() for _ in range(3 * num_lorentzians)]
        ps[m, :], errors[m] = lorentzfit(p_rand, freqs_fit, eps_fit, nlopt.LD_MMA, 1e-25, 50000)
        print(f"Iteration {m:3d}, error: {errors[m]:.6f}")
    best = np.argmin(errors)
    print(f"Optimal error: {errors[best]:.6f}")

    # 3. 최적 파라미터로 Susceptibility 생성 및 Meep 모델 구성
    suscept = []
    for i in range(num_lorentzians):
        freq_param = ps[best][3*i + 1]
        gamma = ps[best][3*i + 2]
        if freq_param == 0:
            sigma = ps[best][3*i + 0]
            suscept.append(mp.DrudeSusceptibility(frequency=1.0, gamma=gamma, sigma=sigma))
        else:
            sigma = ps[best][3*i + 0] / freq_param**2
            suscept.append(mp.LorentzianSusceptibility(frequency=freq_param, gamma=gamma, sigma=sigma))

    return eps_inf, suscept

sio2_data_path = "/mp/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/SiO2/CSV/SiO2_palik_data.csv"
# al_data_path   = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/Al_Palik/CSV/Al_palik_data.csv"
andp_data_path = "/mp/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/aNDP/CSV/aNPD_PFA_data.csv"

eps_inf_sio2, suscept_sio2 = Material_fit(Material_data_csv=sio2_data_path)
# eps_inf_al, suscept_al = Material_fit(Material_data_csv=al_data_path)
eps_inf_andp, suscept_andp = Material_fit(Material_data_csv=andp_data_path)
# Out:
# Iteration   0, error: 0.000007
# Iteration   1, error: 0.000014
# Iteration   2, error: 0.000184
# Iteration   3, error: 0.000043
# Iteration   4, error: 0.000007
# Iteration   5, error: 0.000013
# Iteration   6, error: 0.000024
# Iteration   7, error: 0.000020
# Iteration   8, error: 0.000057
# Iteration   9, error: 0.000006
# Iteration  10, error: 0.000018
# Iteration  11, error: 0.000031
# Iteration  12, error: 0.000006
# Iteration  13, error: 0.000015
# Iteration  14, error: 0.000010
# Iteration  15, error: 0.000177
# Iteration  16, error: 0.000009
# Iteration  17, error: 0.000004
# Iteration  18, error: 0.000012
# Iteration  19, error: 0.002291
# Iteration  20, error: 0.000004
# Iteration  21, error: 0.000009
# Iteration  22, error: 0.000005
# Iteration  23, error: 0.000007
# Iteration  24, error: 0.000036
# Iteration  25, error: 0.000018
# Iteration  26, error: 0.000013
# Iteration  27, error: 0.000011
# Iteration  28, error: 0.000006
# Iteration  29, error: 0.000112
# Optimal error: 0.000004
# Iteration   0, error: 0.028058
# Iteration   1, error: 0.028058
# Iteration   2, error: 0.028750
# Iteration   3, error: 0.028058
# Iteration   4, error: 0.028242
# Iteration   5, error: 0.030748
# Iteration   6, error: 0.031395
# Iteration   7, error: 0.028058
# Iteration   8, error: 0.028957
# Iteration   9, error: 0.028058
# Iteration  10, error: 0.028845
# Iteration  11, error: 0.031907
# Iteration  12, error: 0.028320
# Iteration  13, error: 0.035364
# Iteration  14, error: 0.028058
# Iteration  15, error: 0.034929
# Iteration  16, error: 0.031644
# Iteration  17, error: 0.028058
# Iteration  18, error: 1.067688
# Iteration  19, error: 0.030005
# Iteration  20, error: 0.028058
# Iteration  21, error: 0.029652
# Iteration  22, error: 0.028058
# Iteration  23, error: 0.028184
# Iteration  24, error: 0.028100
# Iteration  25, error: 0.028058
# Iteration  26, error: 0.028058
# Iteration  27, error: 0.028070
# Iteration  28, error: 0.032796
# Iteration  29, error: 0.028058
# Optimal error: 0.028058

# %%
### ----- Refractive index ----- ###
Glass = mp.Medium(epsilon=eps_inf_sio2, E_susceptibilities = suscept_sio2) # SiO2 
aNDP = mp.Medium(epsilon=eps_inf_andp, E_susceptibilities = suscept_andp) # aNDP 
Cathode = mp.perfect_electric_conductor

CoverLayer = mp.Medium(index=1.9) # SiN 
ITO_m = mp.Medium(index=1.8) 
Alq3 = mp.Medium(index=1.68) 
Air = mp.Medium(index=1.0) # 공기

# %%
Glass_layer = 1.37
Cover_layer = 0.07
ITO_layer = 0.15
aNDP_layer = 0.05
Alq3_layer = 0.06
Cathode_layer = 0.3

# %%
Absorber_layer = 0.5

boundary_layers = [
    mp.Absorber(thickness=Absorber_layer, direction=mp.X, side=mp.Low),  # 좌측 Absorber
    mp.Absorber(thickness=Absorber_layer, direction=mp.X, side=mp.High), # 우측 Absorber
    mp.Absorber(thickness=Absorber_layer, direction=mp.Y, side=mp.High), # 상단 Absorber
    
]

# %%
Cathode_center = mp.Vector3(0, -0.85, 0)
Alq3_center = mp.Vector3(0, -0.67, 0)
aNDP_center = mp.Vector3(0, -0.615, 0)
ITO_center = mp.Vector3(0, -0.515, 0)
Cover_center = mp.Vector3(0, -0.405, 0)
Glass_center = mp.Vector3(0, 0.315, 0)

# %%
geometry = [
    # Cathode (하단)
    mp.Block(
        center=Cathode_center,
        size=mp.Vector3(30, Cathode_layer, 0),
        material=Cathode
    ),
    # Alq3
    mp.Block(
        center=Alq3_center,
        size=mp.Vector3(30, Alq3_layer, 0),
        material=Alq3
    ),
    # aNDP
    mp.Block(
        center=aNDP_center,
        size=mp.Vector3(30, aNDP_layer, 0),
        material=aNDP
    ),
    # ITO
    mp.Block(
        center=ITO_center,
        size=mp.Vector3(30, ITO_layer, 0),
        material=ITO_m
    ),
    # Cover layer
    mp.Block(
        center=Cover_center,
        size=mp.Vector3(30, Cover_layer, 0),
        material=CoverLayer
    ),
    # Glass (상단; (0,0,0)은 이 Glass 내부에 위치함)
    mp.Block(
        center=Glass_center,
        size=mp.Vector3(30, Glass_layer, 0),
        material=Glass
    )
]

# %%
cell_size = mp.Vector3(31, 2, 0)

# %%
source_center = mp.Vector3(0,-0.67,0)

sources = [mp.Source(
    src=mp.GaussianSource(frequency=fcen, fwidth=df),
    component=mp.Ex,
    center=source_center,
    size=mp.Vector3(0,0,0)
)]

# %%
# === 시뮬레이션 설정 === #
sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
)

# %%
fig = plt.figure(dpi=200)
ax = plt.gca()
sim.plot2D(
    # output_plane=mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(2, 2, 0)),
    # eps_parameters={'cmap': 'coolwarm', 'alpha': 0.8},   # 투명도와 컬러맵
    # ax=ax
)

layer_boundaries = [
    -1.00,  # bottom of Cathode
    -0.70,  # Cathode-Alq3
    -0.64,  # Alq3-aNDP
    -0.59,  # aNDP-ITO
    -0.44,  # ITO-Cover
    -0.37,  # Cover-Glass
    1.005   # top of Glass
]

for y in layer_boundaries:
     ax.axhline(y=y, color='white', linestyle='--', linewidth=0.8)

# === 옵션 ===
plt.title("OLED Structure with Layer Boundaries")
plt.tight_layout()
plt.show()
# Out:
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %% [markdown]
# # near to far 각도 부여하는 방법에는 문제가 없다

# %% [markdown]
# 가우시안에 대한 필드 분포 뽑기

# %%
offset = 0.01
flux_size = 0.02

# Dipole 위치
source_center = mp.Vector3(0, -0.67,0)

focus_lambda_min = 0.4
focus_lambda_max = 0.7

focus_f_min = 1/focus_lambda_max
focus_f_max = 1/focus_lambda_min

fcen_monitor = 0.5 * (focus_f_min + focus_f_max)
df_monitor = focus_f_max - focus_f_min

# 박스 4면
x1 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux x1
    mp.FluxRegion(
        center=source_center - mp.Vector3(offset, 0,0),
        size=mp.Vector3(0,flux_size, 0),
        # direction=mp.Y,
        weight=-1
    ),
)

x2 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux x2
    mp.FluxRegion(
        center=source_center + mp.Vector3(offset, 0,0),
        size=mp.Vector3(0,flux_size, 0),
        # direction=mp.Y
    ),
)

y1 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux y1
    mp.FluxRegion(
        center=source_center - mp.Vector3(0, offset, 0),
        size=mp.Vector3(flux_size, 0),
        # direction=mp.Y,
        weight=-1
    ),
)

y2 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux y2
    mp.FluxRegion(
        center=source_center + mp.Vector3(0, offset, 0),
        size=mp.Vector3(flux_size, 0),
        # direction=mp.Y
    ),
)

# %%
# center와 size를 사용해 Volume 객체 생성
vol = mp.Volume(center=mp.Vector3(0, -0.67, 0), size=mp.Vector3(2, 2, 0))
fig = plt.figure(dpi=200)
ax = plt.gca()

# 그 volume을 사용해서 2D 시각화
sim.plot2D(
    output_plane=mp.Volume(center=mp.Vector3(0,-0.67,0), size=mp.Vector3(0.1, 0.1, 0)),
    eps_parameters={'cmap': 'coolwarm', 'alpha': 0.8},   # 투명도와 컬러맵
    ax=ax
)
plt.show()
# Out:
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
sim.run(until=50)
# Out:
# Meep progress: 1.52/50.0 = 3.0% done in 4.0s, 127.6s to go
# on time step 304 (time=1.52), 0.0131584 s/step
# Meep progress: 3.08/50.0 = 6.2% done in 8.0s, 122.0s to go
# on time step 616 (time=3.08), 0.0128487 s/step
# Meep progress: 4.615/50.0 = 9.2% done in 12.0s, 118.1s to go
# on time step 923 (time=4.615), 0.0130386 s/step
# Meep progress: 6.140000000000001/50.0 = 12.3% done in 16.0s, 114.5s to go
# on time step 1228 (time=6.14), 0.0131537 s/step
# Meep progress: 7.66/50.0 = 15.3% done in 20.0s, 110.8s to go
# on time step 1532 (time=7.66), 0.0131936 s/step
# Meep progress: 9.17/50.0 = 18.3% done in 24.0s, 107.1s to go
# on time step 1834 (time=9.17), 0.013271 s/step
# Meep progress: 10.68/50.0 = 21.4% done in 28.1s, 103.3s to go
# on time step 2136 (time=10.68), 0.0132804 s/step
# Meep progress: 12.200000000000001/50.0 = 24.4% done in 32.1s, 99.4s to go
# on time step 2440 (time=12.2), 0.0131952 s/step
# Meep progress: 13.700000000000001/50.0 = 27.4% done in 36.1s, 95.6s to go
# on time step 2740 (time=13.7), 0.0133344 s/step
# Meep progress: 15.200000000000001/50.0 = 30.4% done in 40.1s, 91.7s to go
# on time step 3040 (time=15.2), 0.0133423 s/step
# Meep progress: 16.72/50.0 = 33.4% done in 44.1s, 87.7s to go
# on time step 3344 (time=16.72), 0.0131875 s/step
# Meep progress: 18.240000000000002/50.0 = 36.5% done in 48.1s, 83.7s to go
# on time step 3648 (time=18.24), 0.0131793 s/step
# Meep progress: 19.755/50.0 = 39.5% done in 52.1s, 79.8s to go
# on time step 3951 (time=19.755), 0.0132185 s/step
# Meep progress: 21.27/50.0 = 42.5% done in 56.1s, 75.8s to go
# on time step 4254 (time=21.27), 0.0132172 s/step
# Meep progress: 22.79/50.0 = 45.6% done in 60.1s, 71.8s to go
# on time step 4558 (time=22.79), 0.0131623 s/step
# Meep progress: 24.305/50.0 = 48.6% done in 64.1s, 67.8s to go
# on time step 4861 (time=24.305), 0.0132431 s/step
# Meep progress: 25.805/50.0 = 51.6% done in 68.1s, 63.9s to go
# on time step 5161 (time=25.805), 0.0133352 s/step
# Meep progress: 27.32/50.0 = 54.6% done in 72.1s, 59.9s to go
# on time step 5464 (time=27.32), 0.0132266 s/step
# Meep progress: 28.830000000000002/50.0 = 57.7% done in 76.1s, 55.9s to go
# on time step 5766 (time=28.83), 0.0132731 s/step
# Meep progress: 30.335/50.0 = 60.7% done in 80.1s, 52.0s to go
# on time step 6067 (time=30.335), 0.0133128 s/step
# Meep progress: 31.84/50.0 = 63.7% done in 84.2s, 48.0s to go
# on time step 6368 (time=31.84), 0.0133283 s/step
# Meep progress: 33.35/50.0 = 66.7% done in 88.2s, 44.0s to go
# on time step 6670 (time=33.35), 0.0132616 s/step
# Meep progress: 34.85/50.0 = 69.7% done in 92.2s, 40.1s to go
# on time step 6970 (time=34.85), 0.0133426 s/step
# Meep progress: 36.36/50.0 = 72.7% done in 96.2s, 36.1s to go
# on time step 7272 (time=36.36), 0.0132797 s/step
# Meep progress: 37.855000000000004/50.0 = 75.7% done in 100.2s, 32.1s to go
# on time step 7571 (time=37.855), 0.0133884 s/step
# Meep progress: 39.36/50.0 = 78.7% done in 104.2s, 28.2s to go
# on time step 7872 (time=39.36), 0.0133059 s/step
# Meep progress: 40.89/50.0 = 81.8% done in 108.2s, 24.1s to go
# on time step 8178 (time=40.89), 0.0130931 s/step
# Meep progress: 42.4/50.0 = 84.8% done in 112.2s, 20.1s to go
# on time step 8480 (time=42.4), 0.0132626 s/step
# Meep progress: 43.92/50.0 = 87.8% done in 116.2s, 16.1s to go
# on time step 8784 (time=43.92), 0.0131654 s/step
# Meep progress: 45.43/50.0 = 90.9% done in 120.2s, 12.1s to go
# on time step 9086 (time=45.43), 0.0132767 s/step
# Meep progress: 46.95/50.0 = 93.9% done in 124.2s, 8.1s to go
# on time step 9390 (time=46.95), 0.0131943 s/step
# Meep progress: 48.46/50.0 = 96.9% done in 128.2s, 4.1s to go
# on time step 9692 (time=48.46), 0.013286 s/step
# Meep progress: 49.97/50.0 = 99.9% done in 132.2s, 0.1s to go
# on time step 9994 (time=49.97), 0.0132708 s/step
# run 0 finished at t = 50.0 (10000 timesteps)

# %%
net_power = np.array(mp.get_fluxes(x1))+np.array(mp.get_fluxes(x2))+np.array(mp.get_fluxes(y1))+np.array(mp.get_fluxes(y2))
# net_power = np.square(net_power)

# %% [markdown]
# ## Air에서의 far field E field 뽑는걸 이번주 목표로 -> Meep air far field
#
# ### Meep에서 air, sio2

# %%
frequencies = mp.get_flux_freqs(x1)

wavelengths = [1/f for f in frequencies]

print("λ (μm)\t\tdipolepower_box (W)")
for i in range(nfreq):
    print(f"{frequencies[i]:.4f}\t\t{net_power[i]:.6e}")
# Out:
# λ (μm)		dipolepower_box (W)
# 1.4286		2.841315e-03
# 1.4394		2.990610e-03
# 1.4502		3.126384e-03
# 1.4610		3.277625e-03
# 1.4719		3.418425e-03
# 1.4827		3.571665e-03
# 1.4935		3.718471e-03
# 1.5043		3.874212e-03
# 1.5152		4.028076e-03
# 1.5260		4.187053e-03
# 1.5368		4.348833e-03
# 1.5476		4.511810e-03
# 1.5584		4.681966e-03
# 1.5693		4.849591e-03
# 1.5801		5.028090e-03
# 1.5909		5.200843e-03
# 1.6017		5.387185e-03
# 1.6126		5.565425e-03
# 1.6234		5.758810e-03
# 1.6342		5.942989e-03
# 1.6450		6.142709e-03
# 1.6558		6.330918e-03
# 1.6667		6.536078e-03
# 1.6775		6.733804e-03
# 1.6883		6.944106e-03
# 1.6991		7.150300e-03
# 1.7100		7.366299e-03
# 1.7208		7.582803e-03
# 1.7316		7.805559e-03
# 1.7424		8.034436e-03
# 1.7532		8.265506e-03
# 1.7641		8.508870e-03
# 1.7749		8.750101e-03
# 1.7857		9.009849e-03
# 1.7965		9.263099e-03
# 1.8074		9.540623e-03
# 1.8182		9.807471e-03
# 1.8290		1.010342e-02
# 1.8398		1.038490e-02
# 1.8506		1.069901e-02
# 1.8615		1.099544e-02
# 1.8723		1.132649e-02
# 1.8831		1.163738e-02
# 1.8939		1.198324e-02
# 1.9048		1.230726e-02
# 1.9156		1.266498e-02
# 1.9264		1.299991e-02
# 1.9372		1.336573e-02
# 1.9481		1.370833e-02
# 1.9589		1.407745e-02
# 1.9697		1.442303e-02
# 1.9805		1.478922e-02
# 1.9913		1.513114e-02
# 2.0022		1.548615e-02
# 2.0130		1.581505e-02
# 2.0238		1.614802e-02
# 2.0346		1.645163e-02
# 2.0455		1.674907e-02
# 2.0563		1.701243e-02
# 2.0671		1.725891e-02
# 2.0779		1.746574e-02
# 2.0887		1.764565e-02
# 2.0996		1.778042e-02
# 2.1104		1.788032e-02
# 2.1212		1.793090e-02
# 2.1320		1.794193e-02
# 2.1429		1.790174e-02
# 2.1537		1.782121e-02
# 2.1645		1.769021e-02
# 2.1753		1.752182e-02
# 2.1861		1.730609e-02
# 2.1970		1.705880e-02
# 2.2078		1.676925e-02
# 2.2186		1.645598e-02
# 2.2294		1.610558e-02
# 2.2403		1.574039e-02
# 2.2511		1.534364e-02
# 2.2619		1.493876e-02
# 2.2727		1.451009e-02
# 2.2835		1.408122e-02
# 2.2944		1.363272e-02
# 2.3052		1.319050e-02
# 2.3160		1.273334e-02
# 2.3268		1.228752e-02
# 2.3377		1.183102e-02
# 2.3485		1.138963e-02
# 2.3593		1.094141e-02
# 2.3701		1.051083e-02
# 2.3810		1.007692e-02
# 2.3918		9.662099e-03
# 2.4026		9.247091e-03
# 2.4134		8.851734e-03
# 2.4242		8.458994e-03
# 2.4351		8.085778e-03
# 2.4459		7.717665e-03
# 2.4567		7.368447e-03
# 2.4675		7.026530e-03
# 2.4784		6.702722e-03
# 2.4892		6.388048e-03
# 2.5000		6.090510e-03

# %%
plt.figure(figsize=(8,6))
plt.plot(wavelengths, net_power, '-', label='dipolepower_box', color = 'green')
plt.xlabel('Wavelength (μm)')
plt.ylabel('dipolepower_box (W)')
plt.title('dipolepower_box vs. Wavelength')
# plt.ylim(-4, 14)  # y축 최소값: -4, 최대값: 14
# plt.xlim([0.4, 0.7])
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# CSV 파일 불러오기
data = np.genfromtxt("dipole_power.csv", delimiter=",", skip_header=1)

# 데이터 분리
wavelengths = data[:, 0]
source_power = data[:, 1]

# 슬라이싱: 0.5μm ≤ λ ≤ 1.0μm
# mask = (wavelengths >= 0) & (wavelengths <= 10)
wavelength_sliced = wavelengths
power_sliced = source_power

# 결과 출력
print("슬라이싱된 wavelength:", wavelength_sliced)
print("슬라이싱된 power:", power_sliced)
# Out:
# 슬라이싱된 wavelength: [0.7        0.69473684 0.68955224 0.68444444 0.67941176 0.67445255
#  0.66956522 0.6647482  0.66       0.65531915 0.65070423 0.64615385
#  0.64166667 0.63724138 0.63287671 0.62857143 0.62432432 0.62013423
#  0.616      0.61192053 0.60789474 0.60392157 0.6        0.59612903
#  0.59230769 0.58853503 0.58481013 0.58113208 0.5775     0.57391304
#  0.57037037 0.56687117 0.56341463 0.56       0.55662651 0.55329341
#  0.55       0.54674556 0.54352941 0.54035088 0.5372093  0.53410405
#  0.53103448 0.528      0.525      0.5220339  0.51910112 0.51620112
#  0.51333333 0.51049724 0.50769231 0.50491803 0.50217391 0.49945946
#  0.49677419 0.49411765 0.49148936 0.48888889 0.48631579 0.48376963
#  0.48125    0.47875648 0.47628866 0.47384615 0.47142857 0.46903553
#  0.46666667 0.46432161 0.462      0.45970149 0.45742574 0.45517241
#  0.45294118 0.45073171 0.44854369 0.44637681 0.44423077 0.44210526
#  0.44       0.43791469 0.43584906 0.43380282 0.4317757  0.42976744
#  0.42777778 0.42580645 0.42385321 0.42191781 0.42       0.41809955
#  0.41621622 0.41434978 0.4125     0.41066667 0.40884956 0.40704846
#  0.40526316 0.40349345 0.40173913 0.4       ]
# 슬라이싱된 power: [0.00974608 0.01022019 0.0107057  0.0112023  0.01171012 0.01222924
#  0.01275924 0.01329905 0.01384728 0.01440285 0.01496523 0.01553431
#  0.01610976 0.01669064 0.01727537 0.01786222 0.01844992 0.01903782
#  0.01962556 0.02021243 0.02079707 0.02137751 0.02195189 0.02251891
#  0.0230779  0.02362838 0.02416942 0.02469934 0.02521612 0.02571796
#  0.02620376 0.02667306 0.0271254  0.02755979 0.02797456 0.02836785
#  0.02873825 0.02908512 0.02940833 0.02970765 0.02998224 0.0302307
#  0.03045163 0.03064423 0.03080848 0.03094473 0.03105311 0.03113309
#  0.03118375 0.03120435 0.03119483 0.03115584 0.03108826 0.03099258
#  0.03086872 0.03071632 0.03053533 0.03032645 0.03009091 0.02983001
#  0.02954459 0.02923495 0.02890127 0.02854412 0.02816477 0.02776488
#  0.02734597 0.02690908 0.02645477 0.02598361 0.02549663 0.0249954
#  0.02448173 0.02395715 0.02342271 0.02287907 0.02232699 0.02176768
#  0.02120275 0.02063392 0.0200625  0.01948936 0.01891509 0.01834045
#  0.01776659 0.01719496 0.01662692 0.01606344 0.01550508 0.01495225
#  0.01440555 0.01386593 0.01333446 0.01281209 0.01229935 0.01179648
#  0.01130363 0.01082118 0.01034975 0.00989005]

# %%
dp = net_power / source_power

# 5. Plot
plt.figure(figsize=(8, 5))
# plt.plot(wavelengths, source_power, '-', label='Homogeneous dipole power', )
plt.plot(wavelengths, dp,  label='Normalized pipole power (dp)', color='blue')
# plt.plot(wavelengths, net_power, '-', label='Dipolepower_box', color = 'green')

plt.xlabel("Wavelength (μm)")
plt.ylabel("dp = net_power / source_power")
plt.title("Normalized Dipole Radiation Power")
plt.grid(True)
plt.legend()
plt.tight_layout()
# plt.yscale("log")

plt.ylim([0, 1.5])
plt.xlim([0.4, 0.7])
plt.show()

# %% [markdown]
# sim.add_flux(...) → Fourier-transformed field 데이터를 누적 시작
#
# sim.get_fluxes(flux_obj) → 누적된 데이터를 바탕으로 power 계산
#
# sim.get_dft_array(...) → 실제 E, H field의 Fourier transformed 값을 배열로 받을 수 있음

# %% [markdown]
# → 파장이 길어질수록 source dipole의 방사효율은 줄어들지만, 시스템은 에너지를 더 잘 전달함 → dp 증가.
