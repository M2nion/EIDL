# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import nlopt
from meep_material import lorentzfit

# %%
resolution = 100
nfreq = 100

fcen = 1.75
df = 3.3

# %%
def Material_fit(Material_data_csv=".", 
                   eps_inf=1,
                   fit_wl_min=0.38, fit_wl_max=0.72,
                   num_lorentzians=2, iteration=30
                   ):    

    # 1. 데이터 로드 및 전처리
    data = np.genfromtxt(Material_data_csv, delimiter=",")
    wl = data[:, 0] * 1e6  # 파장 (µm)
    n_data = data[:, 1] + 1j * data[:, 2]
    eps_all = np.square(n_data) - eps_inf

    # 피팅 범위로 데이터 선택
    mask = (wl >= fit_wl_min) & (wl <= fit_wl_max)
    wl_fit, eps_fit = wl[mask], eps_all[mask]
    freqs_fit = 1 / wl_fit

    # 2. Lorentzian 피팅 최적화
    ps = np.zeros((iteration, 3 * num_lorentzians))
    errors = np.zeros(iteration)
    for m in range(iteration):
        p_rand = [10 ** np.random.random() for _ in range(3 * num_lorentzians)]
        ps[m, :], errors[m] = lorentzfit(p_rand, freqs_fit, eps_fit, nlopt.LD_MMA, 1e-25, 50000)
        print(f"Iteration {m:3d}, error: {errors[m]:.6f}")
    best = np.argmin(errors)
    print(f"Optimal error: {errors[best]:.6f}")

    # 3. 최적 파라미터로 Susceptibility 생성 및 Meep 모델 구성
    suscept = []
    for i in range(num_lorentzians):
        freq_param = ps[best][3*i + 1]
        gamma = ps[best][3*i + 2]
        if freq_param == 0:
            sigma = ps[best][3*i + 0]
            suscept.append(mp.DrudeSusceptibility(frequency=1.0, gamma=gamma, sigma=sigma))
        else:
            sigma = ps[best][3*i + 0] / freq_param**2
            suscept.append(mp.LorentzianSusceptibility(frequency=freq_param, gamma=gamma, sigma=sigma))

    return eps_inf, suscept

sio2_data_path = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/SiO2/CSV/SiO2_palik_data.csv"
al_data_path   = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/Al_Palik/CSV/Al_palik_data.csv"
andp_data_path = "/home/min/EIDL/Tool/Meep/LGD/Material CSV/Al_Palik/Data/CSV file/aNDP/CSV/aNPD_PFA_data.csv"

eps_inf_sio2, suscept_sio2 = Material_fit(Material_data_csv=sio2_data_path)
eps_inf_al, suscept_al = Material_fit(Material_data_csv=al_data_path)
eps_inf_andp, suscept_andp = Material_fit(Material_data_csv=andp_data_path)
# Out:
# Iteration   0, error: 0.000070
# Iteration   1, error: 0.000003
# Iteration   2, error: 0.000018
# Iteration   3, error: 0.000017
# Iteration   4, error: 0.000015
# Iteration   5, error: 0.000023
# Iteration   6, error: 0.000019
# Iteration   7, error: 0.000012
# Iteration   8, error: 0.000017
# Iteration   9, error: 0.000011
# Iteration  10, error: 0.000009
# Iteration  11, error: 0.000330
# Iteration  12, error: 0.000017
# Iteration  13, error: 0.000007
# Iteration  14, error: 0.000060
# Iteration  15, error: 0.000078
# Iteration  16, error: 0.000013
# Iteration  17, error: 0.000016
# Iteration  18, error: 0.000018
# Iteration  19, error: 0.000007
# Iteration  20, error: 0.000012
# Iteration  21, error: 0.000020
# Iteration  22, error: 0.000020
# Iteration  23, error: 0.000011
# Iteration  24, error: 0.000008
# Iteration  25, error: 0.000337
# Iteration  26, error: 0.000004
# Iteration  27, error: 0.000063
# Iteration  28, error: 0.000010
# Iteration  29, error: 0.000010
# Optimal error: 0.000003
# Iteration   0, error: 64.226780
# Iteration   1, error: 64.226780
# Iteration   2, error: 54.483567
# Iteration   3, error: 64.226780
# Iteration   4, error: 64.226780
# Iteration   5, error: 54.483567
# Iteration   6, error: 71292.592314
# Iteration   7, error: 71292.592314
# Iteration   8, error: 54.483567
# Iteration   9, error: 64.226780
# Iteration  10, error: 54.483567
# Iteration  11, error: 3.131232
# Iteration  12, error: 64.226780
# Iteration  13, error: 64.226780
# Iteration  14, error: 71292.592314
# Iteration  15, error: 54.483567
# Iteration  16, error: 71292.592314
# Iteration  17, error: 3.875835
# Iteration  18, error: 54.483567
# Iteration  19, error: 71292.592314
# Iteration  20, error: 54.483567
# Iteration  21, error: 64.226780
# Iteration  22, error: 64.226780
# Iteration  23, error: 64.226780
# Iteration  24, error: 64.226780
# Iteration  25, error: 54.483567
# Iteration  26, error: 64.226780
# Iteration  27, error: 54.483567
# Iteration  28, error: 64.226780
# Iteration  29, error: 64.226780
# Optimal error: 3.131232
# Iteration   0, error: 0.032077
# Iteration   1, error: 0.032957
# Iteration   2, error: 0.028058
# Iteration   3, error: 0.028382
# Iteration   4, error: 0.028344
# Iteration   5, error: 0.028058
# Iteration   6, error: 0.028058
# Iteration   7, error: 0.028058
# Iteration   8, error: 0.029448
# Iteration   9, error: 0.036768
# Iteration  10, error: 0.028058
# Iteration  11, error: 0.029197
# Iteration  12, error: 0.028058
# Iteration  13, error: 0.028058
# Iteration  14, error: 0.033692
# Iteration  15, error: 0.032057
# Iteration  16, error: 0.028058
# Iteration  17, error: 0.029359
# Iteration  18, error: 0.033304
# Iteration  19, error: 0.028058
# Iteration  20, error: 0.029389
# Iteration  21, error: 0.028058
# Iteration  22, error: 0.030909
# Iteration  23, error: 0.028058
# Iteration  24, error: 0.028058
# Iteration  25, error: 0.028058
# Iteration  26, error: 0.028111
# Iteration  27, error: 0.028058
# Iteration  28, error: 0.033037
# Iteration  29, error: 0.031124
# Optimal error: 0.028058

# %%
Glass = mp.Medium(epsilon=eps_inf_sio2, E_susceptibilities = suscept_sio2) # SiO2 
aNDP = mp.Medium(epsilon=eps_inf_andp, E_susceptibilities = suscept_andp) # aNDP 
Cathode = mp.Medium(epsilon=eps_inf_al, E_susceptibilities = suscept_al) # Al

### ----- Refractive index ----- ###
CoverLayer = mp.Medium(index=1.9) # SiN 
ITO_m = mp.Medium(index=1.8) 
Alq3 = mp.Medium(index=1.68) 
Air = mp.Medium(index=1.0) # 공기

# %%
Glass_layer = 1.37
Cover_layer = 0.07
ITO_layer = 0.15
aNDP_layer = 0.05
Alq3_layer = 0.06
Cathode_layer = 0.3

# %%
pml_layer = 0.3

boundary_layers = [
    mp.PML(thickness=pml_layer, direction=mp.X, side=mp.Low),  # 좌측 PML
    mp.PML(thickness=pml_layer, direction=mp.X, side=mp.High), # 우측 PML
    mp.PML(thickness=pml_layer, direction=mp.Y, side=mp.High), # 상단 PML
    
]

# %%
Cathode_center = mp.Vector3(0, -0.85, 0)
Alq3_center = mp.Vector3(0, -0.67, 0)
aNDP_center = mp.Vector3(0, -0.615, 0)
ITO_center = mp.Vector3(0, -0.515, 0)
Cover_center = mp.Vector3(0, -0.405, 0)
Glass_center = mp.Vector3(0, 0.315, 0)

# %%
geometry = [
    # Cathode (하단)
    mp.Block(
        center=Cathode_center,
        size=mp.Vector3(30, Cathode_layer, 0),
        material=Cathode
    ),
    # Alq3
    mp.Block(
        center=Alq3_center,
        size=mp.Vector3(30, Alq3_layer, 0),
        material=Alq3
    ),
    # aNDP
    mp.Block(
        center=aNDP_center,
        size=mp.Vector3(30, aNDP_layer, 0),
        material=aNDP
    ),
    # ITO
    mp.Block(
        center=ITO_center,
        size=mp.Vector3(30, ITO_layer, 0),
        material=ITO_m
    ),
    # Cover layer
    mp.Block(
        center=Cover_center,
        size=mp.Vector3(30, Cover_layer, 0),
        material=CoverLayer
    ),
    # Glass (상단; (0,0,0)은 이 Glass 내부에 위치함)
    mp.Block(
        center=Glass_center,
        size=mp.Vector3(30, Glass_layer, 0),
        material=Glass
    )
]

# %%
cell_size = mp.Vector3(30, 2, 0)

# %%
source_center = mp.Vector3(0,-0.67,0)

sources = [mp.Source(
    src=mp.GaussianSource(frequency=fcen, fwidth=df),
    component=mp.Ex,
    center=source_center,
    size=mp.Vector3(0,0,0)
)]

# %%
# === 시뮬레이션 설정 === #
sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
)

# %%
fig = plt.figure(dpi=200)
ax = plt.gca()
sim.plot2D(
    output_plane=mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(2, 2, 0)),
    eps_parameters={'cmap': 'coolwarm', 'alpha': 0.8},   # 투명도와 컬러맵
    ax=ax
)

layer_boundaries = [
    -1.00,  # bottom of Cathode
    -0.70,  # Cathode-Alq3
    -0.64,  # Alq3-aNDP
    -0.59,  # aNDP-ITO
    -0.44,  # ITO-Cover
    -0.37,  # Cover-Glass
    1.005   # top of Glass
]

for y in layer_boundaries:
     ax.axhline(y=y, color='white', linestyle='--', linewidth=0.8)

# === 옵션 ===
plt.title("OLED Structure with Layer Boundaries")
plt.tight_layout()
plt.show()
# Out:
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %% [markdown]
# # near to far 각도 부여하는 방법에는 문제가 없다

# %% [markdown]
# 가우시안에 대한 필드 분포 뽑기

# %%
offset = 0.01
flux_size = 0.02

# Dipole 위치
source_center = mp.Vector3(0, -0.67,0)

focus_lambda_min = 0.4
focus_lambda_max = 0.7

focus_f_min = 1/focus_lambda_max
focus_f_max = 1/focus_lambda_min

fcen_monitor = 0.5 * (focus_f_min + focus_f_max)
df_monitor = focus_f_max - focus_f_min

# 박스 4면
x1 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux x1
    mp.FluxRegion(
        center=source_center - mp.Vector3(offset, 0,0),
        size=mp.Vector3(0,flux_size, 0),
        # direction=mp.Y,
        weight=-1
    ),
)

x2 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux x2
    mp.FluxRegion(
        center=source_center + mp.Vector3(offset, 0,0),
        size=mp.Vector3(0,flux_size, 0),
        # direction=mp.Y
    ),
)

y1 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux y1
    mp.FluxRegion(
        center=source_center - mp.Vector3(0, offset, 0),
        size=mp.Vector3(flux_size, 0),
        # direction=mp.Y,
        weight=-1
    ),
)

y2 = sim.add_flux(
    fcen_monitor, df_monitor, nfreq, 
    # flux y2
    mp.FluxRegion(
        center=source_center + mp.Vector3(0, offset, 0),
        size=mp.Vector3(flux_size, 0),
        # direction=mp.Y
    ),
)

# %%
# center와 size를 사용해 Volume 객체 생성
vol = mp.Volume(center=mp.Vector3(0, -0.67, 0), size=mp.Vector3(2, 2, 0))
fig = plt.figure(dpi=200)
ax = plt.gca()

# 그 volume을 사용해서 2D 시각화
sim.plot2D(
    output_plane=mp.Volume(center=mp.Vector3(0,-0.67,0), size=mp.Vector3(0.1, 0.1, 0)),
    eps_parameters={'cmap': 'coolwarm', 'alpha': 0.8},   # 투명도와 컬러맵
    ax=ax
)
plt.show()
# Out:
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# /home/min/miniconda3/envs/mp/lib/python3.8/site-packages/meep/visualization.py:284: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(

# %%
sim.run(until=50)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000546932 s
# Working in 2D dimensions.
# Computational cell is 30 x 2 x 0 with resolution 100
#      block, center = (0,-0.85,0)
#           size (30,0.3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.67,0)
#           size (30,0.06,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (30,0.05,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.515,0)
#           size (30,0.15,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (30,0.07,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.315,0)
#           size (30,1.37,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.852653 s
# lorentzian susceptibility: frequency=10.4638, gamma=0
# lorentzian susceptibility: frequency=10.6033, gamma=0
# lorentzian susceptibility: frequency=2.66127, gamma=0.205589
# lorentzian susceptibility: frequency=5.62022, gamma=0.0129248
# lorentzian susceptibility: frequency=1.01629, gamma=0.899161
# drude susceptibility: frequency=1, gamma=0
# -----------
# Meep progress: 1.09/50.0 = 2.2% done in 4.0s, 179.8s to go
# on time step 218 (time=1.09), 0.0183837 s/step
# Meep progress: 2.17/50.0 = 4.3% done in 8.0s, 176.5s to go
# on time step 435 (time=2.175), 0.0185044 s/step
# Meep progress: 3.345/50.0 = 6.7% done in 12.0s, 167.8s to go
# on time step 669 (time=3.345), 0.0171176 s/step
# Meep progress: 4.315/50.0 = 8.6% done in 16.0s, 169.9s to go
# on time step 863 (time=4.315), 0.0207154 s/step
# Meep progress: 5.42/50.0 = 10.8% done in 20.1s, 165.1s to go
# on time step 1084 (time=5.42), 0.0181809 s/step
# Meep progress: 6.315/50.0 = 12.6% done in 24.1s, 166.6s to go
# on time step 1263 (time=6.315), 0.0224026 s/step
# Meep progress: 7.4750000000000005/50.0 = 15.0% done in 28.1s, 159.8s to go
# on time step 1495 (time=7.475), 0.0172629 s/step
# Meep progress: 8.620000000000001/50.0 = 17.2% done in 32.1s, 154.1s to go
# on time step 1724 (time=8.62), 0.0175411 s/step
# Meep progress: 9.8/50.0 = 19.6% done in 36.1s, 148.1s to go
# on time step 1960 (time=9.8), 0.01699 s/step
# Meep progress: 10.955/50.0 = 21.9% done in 40.1s, 143.0s to go
# on time step 2191 (time=10.955), 0.0173755 s/step
# Meep progress: 12.095/50.0 = 24.2% done in 44.1s, 138.3s to go
# on time step 2419 (time=12.095), 0.0175593 s/step
# Meep progress: 13.15/50.0 = 26.3% done in 48.1s, 134.9s to go
# on time step 2630 (time=13.15), 0.0189656 s/step
# Meep progress: 14.280000000000001/50.0 = 28.6% done in 52.1s, 130.4s to go
# on time step 2856 (time=14.28), 0.0177726 s/step
# Meep progress: 15.205/50.0 = 30.4% done in 56.2s, 128.5s to go
# on time step 3041 (time=15.205), 0.0216404 s/step
# Meep progress: 16.37/50.0 = 32.7% done in 60.2s, 123.6s to go
# on time step 3274 (time=16.37), 0.0171948 s/step
# Meep progress: 17.48/50.0 = 35.0% done in 64.2s, 119.4s to go
# on time step 3496 (time=17.48), 0.0180338 s/step
# Meep progress: 18.650000000000002/50.0 = 37.3% done in 68.2s, 114.6s to go
# on time step 3730 (time=18.65), 0.0171046 s/step
# Meep progress: 19.795/50.0 = 39.6% done in 72.2s, 110.1s to go
# on time step 3959 (time=19.795), 0.0175187 s/step
# Meep progress: 20.97/50.0 = 41.9% done in 76.2s, 105.5s to go
# on time step 4194 (time=20.97), 0.0170521 s/step
# Meep progress: 22.14/50.0 = 44.3% done in 80.2s, 100.9s to go
# on time step 4428 (time=22.14), 0.0171581 s/step
# Meep progress: 23.32/50.0 = 46.6% done in 84.2s, 96.3s to go
# on time step 4664 (time=23.32), 0.0169734 s/step
# Meep progress: 24.47/50.0 = 48.9% done in 88.2s, 92.0s to go
# on time step 4894 (time=24.47), 0.0173977 s/step
# Meep progress: 25.645/50.0 = 51.3% done in 92.2s, 87.6s to go
# on time step 5129 (time=25.645), 0.0170808 s/step
# Meep progress: 26.815/50.0 = 53.6% done in 96.2s, 83.2s to go
# on time step 5363 (time=26.815), 0.0171269 s/step
# Meep progress: 28.005/50.0 = 56.0% done in 100.3s, 78.7s to go
# on time step 5601 (time=28.005), 0.0168722 s/step
# Meep progress: 28.855/50.0 = 57.7% done in 104.3s, 76.4s to go
# on time step 5771 (time=28.855), 0.0235372 s/step
# Meep progress: 30.075/50.0 = 60.1% done in 108.3s, 71.7s to go
# on time step 6015 (time=30.075), 0.0164212 s/step
# Meep progress: 31.220000000000002/50.0 = 62.4% done in 112.3s, 67.5s to go
# on time step 6244 (time=31.22), 0.0175195 s/step
# Meep progress: 32.405/50.0 = 64.8% done in 116.3s, 63.1s to go
# on time step 6481 (time=32.405), 0.0168779 s/step
# Meep progress: 33.56/50.0 = 67.1% done in 120.3s, 58.9s to go
# on time step 6712 (time=33.56), 0.0173587 s/step
# Meep progress: 34.765/50.0 = 69.5% done in 124.3s, 54.5s to go
# on time step 6953 (time=34.765), 0.0166182 s/step
# Meep progress: 35.915/50.0 = 71.8% done in 128.3s, 50.3s to go
# on time step 7183 (time=35.915), 0.0174342 s/step
# Meep progress: 37.11/50.0 = 74.2% done in 132.3s, 46.0s to go
# on time step 7422 (time=37.11), 0.0167537 s/step
# Meep progress: 38.045/50.0 = 76.1% done in 136.3s, 42.8s to go
# on time step 7609 (time=38.045), 0.0214053 s/step
# Meep progress: 39.24/50.0 = 78.5% done in 140.3s, 38.5s to go
# on time step 7848 (time=39.24), 0.0167893 s/step
# Meep progress: 40.4/50.0 = 80.8% done in 144.3s, 34.3s to go
# on time step 8080 (time=40.4), 0.0172844 s/step
# Meep progress: 41.6/50.0 = 83.2% done in 148.3s, 30.0s to go
# on time step 8320 (time=41.6), 0.016687 s/step
# Meep progress: 42.74/50.0 = 85.5% done in 152.3s, 25.9s to go
# on time step 8548 (time=42.74), 0.0175581 s/step
# Meep progress: 43.92/50.0 = 87.8% done in 156.3s, 21.6s to go
# on time step 8785 (time=43.925), 0.0169468 s/step
# Meep progress: 45.08/50.0 = 90.2% done in 160.4s, 17.5s to go
# on time step 9016 (time=45.08), 0.0173194 s/step
# Meep progress: 46.275/50.0 = 92.5% done in 164.4s, 13.2s to go
# on time step 9255 (time=46.275), 0.0167987 s/step
# Meep progress: 47.375/50.0 = 94.8% done in 168.9s, 9.4s to go
# on time step 9475 (time=47.375), 0.0207578 s/step
# Meep progress: 48.56/50.0 = 97.1% done in 172.9s, 5.1s to go
# on time step 9712 (time=48.56), 0.0168802 s/step
# Meep progress: 49.725/50.0 = 99.5% done in 177.0s, 1.0s to go
# on time step 9945 (time=49.725), 0.0172012 s/step
# run 0 finished at t = 50.0 (10000 timesteps)

# %%
net_power = np.array(mp.get_fluxes(x1))+np.array(mp.get_fluxes(x2))+np.array(mp.get_fluxes(y1))+np.array(mp.get_fluxes(y2))
# net_power = np.square(net_power)

# %% [markdown]
# ## Air에서의 far field E field 뽑는걸 이번주 목표로 -> Meep air far field
#
# ### Meep에서 air, sio2

# %%
frequencies = mp.get_flux_freqs(x1)

wavelengths = [1/f for f in frequencies]

print("λ (μm)\t\tdipolepower_box (W)")
for i in range(nfreq):
    print(f"{frequencies[i]:.4f}\t\t{net_power[i]:.6e}")
# Out:
# λ (μm)		dipolepower_box (W)
# 1.4286		6.474160e-03
# 1.4394		6.779185e-03
# 1.4502		7.089762e-03
# 1.4610		7.408192e-03
# 1.4719		7.732386e-03
# 1.4827		8.064221e-03
# 1.4935		8.402182e-03
# 1.5043		8.747505e-03
# 1.5152		9.099435e-03
# 1.5260		9.458410e-03
# 1.5368		9.824551e-03
# 1.5476		1.019742e-02
# 1.5584		1.057806e-02
# 1.5693		1.096516e-02
# 1.5801		1.136060e-02
# 1.5909		1.176235e-02
# 1.6017		1.217297e-02
# 1.6126		1.258988e-02
# 1.6234		1.301613e-02
# 1.6342		1.344883e-02
# 1.6450		1.389122e-02
# 1.6558		1.434043e-02
# 1.6667		1.479960e-02
# 1.6775		1.526613e-02
# 1.6883		1.574278e-02
# 1.6991		1.622754e-02
# 1.7100		1.672247e-02
# 1.7208		1.722639e-02
# 1.7316		1.774048e-02
# 1.7424		1.826449e-02
# 1.7532		1.879860e-02
# 1.7641		1.934355e-02
# 1.7749		1.989846e-02
# 1.7857		2.046496e-02
# 1.7965		2.104118e-02
# 1.8074		2.162943e-02
# 1.8182		2.222696e-02
# 1.8290		2.283646e-02
# 1.8398		2.345445e-02
# 1.8506		2.408363e-02
# 1.8615		2.471996e-02
# 1.8723		2.536564e-02
# 1.8831		2.601624e-02
# 1.8939		2.667300e-02
# 1.9048		2.733127e-02
# 1.9156		2.799089e-02
# 1.9264		2.864703e-02
# 1.9372		2.929774e-02
# 1.9481		2.993810e-02
# 1.9589		3.056420e-02
# 1.9697		3.117107e-02
# 1.9805		3.175289e-02
# 1.9913		3.230486e-02
# 2.0022		3.281959e-02
# 2.0130		3.329270e-02
# 2.0238		3.371595e-02
# 2.0346		3.408581e-02
# 2.0455		3.439412e-02
# 2.0563		3.463870e-02
# 2.0671		3.481249e-02
# 2.0779		3.491510e-02
# 2.0887		3.494144e-02
# 2.0996		3.489309e-02
# 2.1104		3.476749e-02
# 2.1212		3.456803e-02
# 2.1320		3.429482e-02
# 2.1429		3.395260e-02
# 2.1537		3.354392e-02
# 2.1645		3.307420e-02
# 2.1753		3.254792e-02
# 2.1861		3.197052e-02
# 2.1970		3.134773e-02
# 2.2078		3.068490e-02
# 2.2186		2.998801e-02
# 2.2294		2.926127e-02
# 2.2403		2.851148e-02
# 2.2511		2.774171e-02
# 2.2619		2.695851e-02
# 2.2727		2.616405e-02
# 2.2835		2.536437e-02
# 2.2944		2.456090e-02
# 2.3052		2.375895e-02
# 2.3160		2.295945e-02
# 2.3268		2.216684e-02
# 2.3377		2.138178e-02
# 2.3485		2.060774e-02
# 2.3593		1.984535e-02
# 2.3701		1.909709e-02
# 2.3810		1.836371e-02
# 2.3918		1.764673e-02
# 2.4026		1.694714e-02
# 2.4134		1.626559e-02
# 2.4242		1.560332e-02
# 2.4351		1.496025e-02
# 2.4459		1.433798e-02
# 2.4567		1.373600e-02
# 2.4675		1.315579e-02
# 2.4784		1.259649e-02
# 2.4892		1.205986e-02
# 2.5000		1.154495e-02

# %%
plt.figure(figsize=(8,6))
plt.plot(wavelengths, net_power, '-', label='dipolepower_box', color = 'green')
plt.xlabel('Wavelength (μm)')
plt.ylabel('dipolepower_box (W)')
plt.title('dipolepower_box vs. Wavelength')
# plt.ylim(-4, 14)  # y축 최소값: -4, 최대값: 14
# plt.xlim([0.4, 0.7])
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# CSV 파일 불러오기
data = np.genfromtxt("dipole_power.csv", delimiter=",", skip_header=1)

# 데이터 분리
wavelengths = data[:, 0]
source_power = data[:, 1]

# 슬라이싱: 0.5μm ≤ λ ≤ 1.0μm
# mask = (wavelengths >= 0) & (wavelengths <= 10)
wavelength_sliced = wavelengths
power_sliced = source_power

# 결과 출력
print("슬라이싱된 wavelength:", wavelength_sliced)
print("슬라이싱된 power:", power_sliced)
# Out:
# 슬라이싱된 wavelength: [0.7        0.69473684 0.68955224 0.68444444 0.67941176 0.67445255
#  0.66956522 0.6647482  0.66       0.65531915 0.65070423 0.64615385
#  0.64166667 0.63724138 0.63287671 0.62857143 0.62432432 0.62013423
#  0.616      0.61192053 0.60789474 0.60392157 0.6        0.59612903
#  0.59230769 0.58853503 0.58481013 0.58113208 0.5775     0.57391304
#  0.57037037 0.56687117 0.56341463 0.56       0.55662651 0.55329341
#  0.55       0.54674556 0.54352941 0.54035088 0.5372093  0.53410405
#  0.53103448 0.528      0.525      0.5220339  0.51910112 0.51620112
#  0.51333333 0.51049724 0.50769231 0.50491803 0.50217391 0.49945946
#  0.49677419 0.49411765 0.49148936 0.48888889 0.48631579 0.48376963
#  0.48125    0.47875648 0.47628866 0.47384615 0.47142857 0.46903553
#  0.46666667 0.46432161 0.462      0.45970149 0.45742574 0.45517241
#  0.45294118 0.45073171 0.44854369 0.44637681 0.44423077 0.44210526
#  0.44       0.43791469 0.43584906 0.43380282 0.4317757  0.42976744
#  0.42777778 0.42580645 0.42385321 0.42191781 0.42       0.41809955
#  0.41621622 0.41434978 0.4125     0.41066667 0.40884956 0.40704846
#  0.40526316 0.40349345 0.40173913 0.4       ]
# 슬라이싱된 power: [0.00974608 0.01022019 0.0107057  0.0112023  0.01171012 0.01222924
#  0.01275924 0.01329905 0.01384728 0.01440285 0.01496523 0.01553431
#  0.01610976 0.01669064 0.01727537 0.01786222 0.01844992 0.01903782
#  0.01962556 0.02021243 0.02079707 0.02137751 0.02195189 0.02251891
#  0.0230779  0.02362838 0.02416942 0.02469934 0.02521612 0.02571796
#  0.02620376 0.02667306 0.0271254  0.02755979 0.02797456 0.02836785
#  0.02873825 0.02908512 0.02940833 0.02970765 0.02998224 0.0302307
#  0.03045163 0.03064423 0.03080848 0.03094473 0.03105311 0.03113309
#  0.03118375 0.03120435 0.03119483 0.03115584 0.03108826 0.03099258
#  0.03086872 0.03071632 0.03053533 0.03032645 0.03009091 0.02983001
#  0.02954459 0.02923495 0.02890127 0.02854412 0.02816477 0.02776488
#  0.02734597 0.02690908 0.02645477 0.02598361 0.02549663 0.0249954
#  0.02448173 0.02395715 0.02342271 0.02287907 0.02232699 0.02176768
#  0.02120275 0.02063392 0.0200625  0.01948936 0.01891509 0.01834045
#  0.01776659 0.01719496 0.01662692 0.01606344 0.01550508 0.01495225
#  0.01440555 0.01386593 0.01333446 0.01281209 0.01229935 0.01179648
#  0.01130363 0.01082118 0.01034975 0.00989005]

# %%
dp = net_power / source_power

# 5. Plot
plt.figure(figsize=(8, 5))
# plt.plot(wavelengths, source_power, '-', label='Homogeneous dipole power', )
plt.plot(wavelengths, dp,  label='Normalized pipole power (dp)', color='blue')
# plt.plot(wavelengths, net_power, '-', label='Dipolepower_box', color = 'green')

plt.xlabel("Wavelength (μm)")
plt.ylabel("dp = net_power / source_power")
plt.title("Normalized Dipole Radiation Power")
plt.grid(True)
plt.legend()
plt.tight_layout()
# plt.yscale("log")

plt.ylim([0, 1.5])
plt.xlim([0.4, 0.7])
plt.show()

# %% [markdown]
# sim.add_flux(...) → Fourier-transformed field 데이터를 누적 시작
#
# sim.get_fluxes(flux_obj) → 누적된 데이터를 바탕으로 power 계산
#
# sim.get_dft_array(...) → 실제 E, H field의 Fourier transformed 값을 배열로 받을 수 있음

# %% [markdown]
# → 파장이 길어질수록 source dipole의 방사효율은 줄어들지만, 시스템은 에너지를 더 잘 전달함 → dp 증가.
