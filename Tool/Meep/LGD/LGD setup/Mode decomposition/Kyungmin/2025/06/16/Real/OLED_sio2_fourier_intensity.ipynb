# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
import math

from meep.materials import Ag

# %%
lambda_min = 0.4       # 최소 파장 (µm)
lambda_max = 0.7       # 최대 파장 (µm)
fmin = 1/lambda_max    # 최소 주파수
fmax = 1/lambda_min    # 최대 주파수
fcen = 0.5*(fmin+fmax) # 중앙 주파수
df = fmax-fmin         # 주파수 대역폭

resolution = 50        # 시뮬레이션 해상도
nfreq = 1             # 추출할 주파수 개수
design_region_resolution = 50

# %%
tag_bot         = 0.5
tag_side        = 4
tsio2           = 4
tdesignregion   = 1
monitor_position = 1 / fcen
monitor_blank   = 1 / fcen * 0.1

tpml = 0.4

width_ag = 0.2
width_sio2 = 2

width_bot_ag = width_ag+width_sio2+width_ag

design_region_width = round(width_bot_ag, 3)
design_region_height = 1

Sx = tpml+width_bot_ag+tpml
Sy = tag_bot+tag_side+tdesignregion+monitor_position+monitor_blank+tpml

SiO2 = mp.Medium(index = 1.45)
TiO2 = mp.Medium(index = 2.6)

Nx = int(design_region_resolution * design_region_width) + 1
Ny = int(design_region_resolution * design_region_height) + 1

y_bottom = -Sy/2
center_y_ag = y_bottom + tag_bot / 2
center_y_sio2 = y_bottom + tag_bot + tsio2 / 2
center_y_design = y_bottom + tag_bot + tsio2 + design_region_height / 2
center_y_monitor_position = y_bottom + tag_bot + tsio2 + design_region_height + 1/fcen
center_y_source_position = y_bottom + tag_bot + 1/fcen 
center_Ag_x_position = design_region_width/2-width_ag/2 #+ tpml/2

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny), TiO2, SiO2,  grid_type="U_MEAN")

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


boundary_layers = [mp.Absorber(tpml,direction=mp.X),
                   mp.PML(tpml,direction=mp.Y,side=mp.High)]

# %%
cell_size = mp.Vector3(Sx, Sy)
geometry = [
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_bot_ag, tag_bot, 0),
        center=mp.Vector3(0, center_y_ag, 0)
    ),
    mp.Block(
        material=SiO2,
        size=mp.Vector3(width_sio2, tsio2, 0),
        center=mp.Vector3(0, center_y_sio2, 0)
    ),
    mp.Block(
        material=design_variables,
        size=mp.Vector3(design_region_width, design_region_height, 0),
        center=mp.Vector3(0, center_y_design, 0)
    ),

    ######### Side metal ########## 
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(-center_Ag_x_position, center_y_sio2, 0)
    ),
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(center_Ag_x_position, center_y_sio2, 0)
    ),
]

# %%
src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True)

sources = mp.Source(
            src,
            component=mp.Ez,
            center=mp.Vector3(
                0,
                center_y_source_position,  # Alq3 층의 중간 높이
                0
            )
        )


sim = mp.Simulation(
    resolution=resolution,
    sources=[sources],
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    default_material=mp.Medium(index = 1),
    extra_materials=[Ag]
)

# %%
offset = 0.01
flux_size = 0.02

input_flux = sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
# dft_fields = sim.add_dft_fields([mp.Ez], fcen, 0, 1, 
#                                     center = mp.Vector3(0, center_y_monitor_position),
#                                     size = mp.Vector3(2*1/fcen,0,0), 
#                                     yee_gri=True)

# %%
sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# sim.run(until=10)
# sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
sim.plot2D()
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000237942 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.063148 s
# time for set_conductivity = 0.00200391 s
# time for set_conductivity = 0.00258994 s
# time for set_conductivity = 0.00227499 s
# time for set_conductivity = 0.00221801 s
# time for set_conductivity = 0.002213 s
# time for set_conductivity = 0.00225997 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.6009124373349221 / 35.86940732217567 = 0.01675278411872219
# field decay(t = 90.03): 0.2632202409285167 / 35.86940732217567 = 0.007338293564883776
# field decay(t = 120.04): 0.16244911625938363 / 35.86940732217567 = 0.004528904389199432
# on time step 14516 (time=145.16), 0.000275566 s/step
# field decay(t = 150.05): 0.08156655423702402 / 35.86940732217567 = 0.002273986673501484
# field decay(t = 180.06): 0.03438519580198319 / 35.86940732217567 = 0.0009586217997174743
# run 0 finished at t = 180.06 (18006 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# array([17.0813335])

# %%
sim.plot2D(fields = mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# array([17.0813335])

# %%
minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

def mapping(x, eta, beta):

    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_width,
        design_region_height,
        design_region_resolution,
    )

    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)

    projected_field = (
        npa.fliplr(projected_field) + projected_field
    ) / 2  # up-down symmetry

    # interpolate to actual materials
    return projected_field.flatten()

# %%
monitor_position, monitor_size = mp.Vector3(0, center_y_monitor_position), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=[fcen],
    maximum_run_time=100,
)

np.random.seed(0)
rho_vector = np.random.rand(Nx * Ny)
opt.update_design([mapping(rho_vector, eta_i, 1e3)])

opt.plot2D(True)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append(np.real(f0))

    plt.figure()
    ax = plt.gca()
    opt.plot2D(
        False,
        ax=ax,
        plot_sources_flag=False,
        plot_monitors_flag=False,
        plot_boundaries_flag=False,
    )
    circ = Circle((2, 2), minimum_length / 2)
    ax.add_patch(circ)
    ax.axis("off")
    plt.show()

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %%
evaluation_history = []
cur_iter = [0]
numevl = 0

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0 = []
    dJ_du = []

    global numevl

    f0_i, dJ_du_i = opt([mapping(v, eta_i, beta)])
    
    f0.append(f0_i.flatten())
    dJ_du.append(dJ_du_i)
        
        
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append([np.max(np.real(f0))])

    numevl += 1
    cur_iter[0] = cur_iter[0] + 1

    print("First FoM: {}".format(evaluation_history[0]))
    # print("Current f0 values: " + ", ".join(["f0_{}: {}".format(i, np.real(f0[i])) for i in range(n_dipole)]))

    return np.mean(f0)  # return the sum of the objective function values

# %%
algorithm = nlopt.LD_MMA
n = Nx * Ny  # number of parameters

# Initial guess
x = np.ones((n,)) * 0.5

# lower and upper bounds
lb = np.zeros((Nx * Ny,))
ub = np.ones((Nx * Ny,))

cur_beta = 4
beta_scale = 1.5
num_betas = 8
update_factor = 10
ftol = 1e-5

for iters in range(num_betas):
    solver = nlopt.opt(algorithm, n)
    solver.set_lower_bounds(lb)
    solver.set_upper_bounds(ub)
    solver.set_max_objective(lambda a, g: f(a, g, cur_beta))
    solver.set_maxeval(update_factor)
    solver.set_ftol_rel(ftol)
    x[:] = solver.optimize(x)
    cur_beta = cur_beta * beta_scale
# Out:
# Current iteration: 1
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 5.10216e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057225 s
# time for set_conductivity = 0.00209117 s
# time for set_conductivity = 0.00254416 s
# time for set_conductivity = 0.00262785 s
# time for set_conductivity = 0.00209403 s
# time for set_conductivity = 0.00207186 s
# time for set_conductivity = 0.00209117 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 162 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 163 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 2
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058625 s
# time for set_conductivity = 0.0021379 s
# time for set_conductivity = 0.002177 s
# time for set_conductivity = 0.00214601 s
# time for set_conductivity = 0.00217319 s
# time for set_conductivity = 0.00213504 s
# time for set_conductivity = 0.00213099 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 164 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 165 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 3
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.41074e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057673 s
# time for set_conductivity = 0.00210285 s
# time for set_conductivity = 0.00219584 s
# time for set_conductivity = 0.00242209 s
# time for set_conductivity = 0.0021112 s
# time for set_conductivity = 0.00224304 s
# time for set_conductivity = 0.00208402 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 166 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 167 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 4
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057708 s
# time for set_conductivity = 0.00210285 s
# time for set_conductivity = 0.0021441 s
# time for set_conductivity = 0.0023191 s
# time for set_conductivity = 0.00236607 s
# time for set_conductivity = 0.00233507 s
# time for set_conductivity = 0.00209188 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 168 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 169 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 5
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058162 s
# time for set_conductivity = 0.00216293 s
# time for set_conductivity = 0.00217485 s
# time for set_conductivity = 0.00242805 s
# time for set_conductivity = 0.00250483 s
# time for set_conductivity = 0.0024581 s
# time for set_conductivity = 0.00246596 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 170 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 171 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 6
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.059238 s
# time for set_conductivity = 0.00215507 s
# time for set_conductivity = 0.00241208 s
# time for set_conductivity = 0.00245309 s
# time for set_conductivity = 0.00221395 s
# time for set_conductivity = 0.00219798 s
# time for set_conductivity = 0.00219893 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 172 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 173 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 7
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0599551 s
# time for set_conductivity = 0.00217986 s
# time for set_conductivity = 0.00216889 s
# time for set_conductivity = 0.00216699 s
# time for set_conductivity = 0.00251198 s
# time for set_conductivity = 0.00247097 s
# time for set_conductivity = 0.00215387 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 174 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 175 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 8
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0595851 s
# time for set_conductivity = 0.00214982 s
# time for set_conductivity = 0.00216603 s
# time for set_conductivity = 0.00219393 s
# time for set_conductivity = 0.00244594 s
# time for set_conductivity = 0.00261092 s
# time for set_conductivity = 0.00261998 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 176 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 177 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 9
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0578082 s
# time for set_conductivity = 0.00211883 s
# time for set_conductivity = 0.00208998 s
# time for set_conductivity = 0.0021019 s
# time for set_conductivity = 0.00234985 s
# time for set_conductivity = 0.00273395 s
# time for set_conductivity = 0.00272107 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 178 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 179 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 10
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058363 s
# time for set_conductivity = 0.00231099 s
# time for set_conductivity = 0.00249982 s
# time for set_conductivity = 0.00214696 s
# time for set_conductivity = 0.00224996 s
# time for set_conductivity = 0.00213504 s
# time for set_conductivity = 0.00212884 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 180 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 181 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 11
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.19481e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0586159 s
# time for set_conductivity = 0.0021739 s
# time for set_conductivity = 0.00214195 s
# time for set_conductivity = 0.00213695 s
# time for set_conductivity = 0.00242591 s
# time for set_conductivity = 0.00213385 s
# time for set_conductivity = 0.00216293 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 182 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 183 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 12
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058955 s
# time for set_conductivity = 0.00212812 s
# time for set_conductivity = 0.00270987 s
# time for set_conductivity = 0.00214219 s
# time for set_conductivity = 0.00246906 s
# time for set_conductivity = 0.00246692 s
# time for set_conductivity = 0.00210905 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 184 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 185 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 13
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0595119 s
# time for set_conductivity = 0.00215983 s
# time for set_conductivity = 0.00215507 s
# time for set_conductivity = 0.00215197 s
# time for set_conductivity = 0.00242305 s
# time for set_conductivity = 0.00240898 s
# time for set_conductivity = 0.00212097 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 186 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 187 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 14
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0587211 s
# time for set_conductivity = 0.00216198 s
# time for set_conductivity = 0.00218797 s
# time for set_conductivity = 0.00214696 s
# time for set_conductivity = 0.00220203 s
# time for set_conductivity = 0.00214911 s
# time for set_conductivity = 0.00241303 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 188 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 189 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 15
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.31402e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057781 s
# time for set_conductivity = 0.00208497 s
# time for set_conductivity = 0.00214887 s
# time for set_conductivity = 0.00210595 s
# time for set_conductivity = 0.00234818 s
# time for set_conductivity = 0.00232911 s
# time for set_conductivity = 0.00208378 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 190 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 191 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 16
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058681 s
# time for set_conductivity = 0.00216317 s
# time for set_conductivity = 0.00216103 s
# time for set_conductivity = 0.00237298 s
# time for set_conductivity = 0.00219893 s
# time for set_conductivity = 0.00212502 s
# time for set_conductivity = 0.00213814 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 192 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 193 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 17
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0590179 s
# time for set_conductivity = 0.00214791 s
# time for set_conductivity = 0.00267601 s
# time for set_conductivity = 0.0021739 s
# time for set_conductivity = 0.00221992 s
# time for set_conductivity = 0.00267196 s
# time for set_conductivity = 0.00220084 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 194 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 195 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 18
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0582919 s
# time for set_conductivity = 0.002141 s
# time for set_conductivity = 0.00294805 s
# time for set_conductivity = 0.00251222 s
# time for set_conductivity = 0.00215101 s
# time for set_conductivity = 0.00212812 s
# time for set_conductivity = 0.00213814 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 196 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 9843 (time=98.43), 0.000406412 s/step
# run 197 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 19
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0595388 s
# time for set_conductivity = 0.00215197 s
# time for set_conductivity = 0.00249314 s
# time for set_conductivity = 0.002666 s
# time for set_conductivity = 0.00261211 s
# time for set_conductivity = 0.0024581 s
# time for set_conductivity = 0.00216508 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 198 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 199 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 20
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0583072 s
# time for set_conductivity = 0.0021441 s
# time for set_conductivity = 0.00212598 s
# time for set_conductivity = 0.00258422 s
# time for set_conductivity = 0.00218296 s
# time for set_conductivity = 0.00212598 s
# time for set_conductivity = 0.00225401 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 200 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 201 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 21
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058562 s
# time for set_conductivity = 0.00214195 s
# time for set_conductivity = 0.00267911 s
# time for set_conductivity = 0.00230002 s
# time for set_conductivity = 0.00241399 s
# time for set_conductivity = 0.00217199 s
# time for set_conductivity = 0.00216413 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 202 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 203 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 22
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0587189 s
# time for set_conductivity = 0.00223613 s
# time for set_conductivity = 0.002316 s
# time for set_conductivity = 0.00213194 s
# time for set_conductivity = 0.00212193 s
# time for set_conductivity = 0.00210285 s
# time for set_conductivity = 0.00234604 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 9269 (time=92.69), 0.000431594 s/step
# run 204 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 205 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 23
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.059459 s
# time for set_conductivity = 0.0025351 s
# time for set_conductivity = 0.00215101 s
# time for set_conductivity = 0.00212288 s
# time for set_conductivity = 0.00246286 s
# time for set_conductivity = 0.00244498 s
# time for set_conductivity = 0.00241208 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 206 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 207 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 24
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057934 s
# time for set_conductivity = 0.0021019 s
# time for set_conductivity = 0.00261807 s
# time for set_conductivity = 0.00265908 s
# time for set_conductivity = 0.00231814 s
# time for set_conductivity = 0.00210595 s
# time for set_conductivity = 0.00210786 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 208 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 209 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 25
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.059731 s
# time for set_conductivity = 0.00215006 s
# time for set_conductivity = 0.00220203 s
# time for set_conductivity = 0.00214314 s
# time for set_conductivity = 0.00237393 s
# time for set_conductivity = 0.00239515 s
# time for set_conductivity = 0.00261497 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 210 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 211 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 26
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.19481e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0590532 s
# time for set_conductivity = 0.00215197 s
# time for set_conductivity = 0.00268912 s
# time for set_conductivity = 0.00214291 s
# time for set_conductivity = 0.00250101 s
# time for set_conductivity = 0.00250602 s
# time for set_conductivity = 0.00213003 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 212 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 213 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 27
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.69685e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0585999 s
# time for set_conductivity = 0.00215912 s
# time for set_conductivity = 0.00220084 s
# time for set_conductivity = 0.00263596 s
# time for set_conductivity = 0.00216198 s
# time for set_conductivity = 0.00213099 s
# time for set_conductivity = 0.00244093 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# ...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.059309 s
# time for set_conductivity = 0.00216889 s
# time for set_conductivity = 0.00219703 s
# time for set_conductivity = 0.00220013 s
# time for set_conductivity = 0.00216293 s
# time for set_conductivity = 0.00221705 s
# time for set_conductivity = 0.0022099 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 304 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 305 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 73
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.21865e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0591171 s
# time for set_conductivity = 0.00216603 s
# time for set_conductivity = 0.00218487 s
# time for set_conductivity = 0.00221491 s
# time for set_conductivity = 0.00218201 s
# time for set_conductivity = 0.00242186 s
# time for set_conductivity = 0.00217986 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 306 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 307 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 74
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0581639 s
# time for set_conductivity = 0.00215602 s
# time for set_conductivity = 0.00216484 s
# time for set_conductivity = 0.00214219 s
# time for set_conductivity = 0.00215507 s
# time for set_conductivity = 0.00212693 s
# time for set_conductivity = 0.00261688 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 308 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 309 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 75
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0583251 s
# time for set_conductivity = 0.00213003 s
# time for set_conductivity = 0.00251698 s
# time for set_conductivity = 0.0024631 s
# time for set_conductivity = 0.0024538 s
# time for set_conductivity = 0.00254297 s
# time for set_conductivity = 0.00218391 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 310 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 311 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 76
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0579181 s
# time for set_conductivity = 0.0021112 s
# time for set_conductivity = 0.00211787 s
# time for set_conductivity = 0.00228691 s
# time for set_conductivity = 0.0022862 s
# time for set_conductivity = 0.00225806 s
# time for set_conductivity = 0.00210905 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 312 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 313 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 77
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058785 s
# time for set_conductivity = 0.0021801 s
# time for set_conductivity = 0.00216484 s
# time for set_conductivity = 0.00216293 s
# time for set_conductivity = 0.00273085 s
# time for set_conductivity = 0.00215101 s
# time for set_conductivity = 0.00213099 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 314 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 315 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 78
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.056886 s
# time for set_conductivity = 0.00205684 s
# time for set_conductivity = 0.00210619 s
# time for set_conductivity = 0.00266099 s
# time for set_conductivity = 0.00211382 s
# time for set_conductivity = 0.00204802 s
# time for set_conductivity = 0.00209093 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 316 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 317 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 79
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.056963 s
# time for set_conductivity = 0.00243688 s
# time for set_conductivity = 0.00250101 s
# time for set_conductivity = 0.00236607 s
# time for set_conductivity = 0.00240493 s
# time for set_conductivity = 0.00237012 s
# time for set_conductivity = 0.00210786 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 318 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 319 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 80
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0571918 s
# time for set_conductivity = 0.00206685 s
# time for set_conductivity = 0.00228906 s
# time for set_conductivity = 0.0023098 s
# time for set_conductivity = 0.00237894 s
# time for set_conductivity = 0.00233889 s
# time for set_conductivity = 0.00206399 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 320 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 321 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]

# %%
opt.update_design([mapping(x, eta_i, cur_beta/beta_scale)]) # cur_beta/beta_scale is the final beta in the optimization.
plt.figure()
ax = plt.gca()
opt.plot2D(True)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
offset = 0.01
flux_size = 0.02

input_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
opt.sim.plot2D()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# opt.sim.run(until=10)
# opt.sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
opt.sim.plot2D()
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.29018e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0579138 s
# time for set_conductivity = 0.0021019 s
# time for set_conductivity = 0.00209689 s
# time for set_conductivity = 0.00206804 s
# time for set_conductivity = 0.0021069 s
# time for set_conductivity = 0.00204992 s
# time for set_conductivity = 0.00205493 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.3525613300628784 / 35.86940732217567 = 0.009829025801742566
# field decay(t = 90.03): 0.18831665751989476 / 35.86940732217567 = 0.005250063259435879
# field decay(t = 120.04): 0.07383784519820615 / 35.86940732217567 = 0.0020585186851570063
# on time step 14092 (time=140.92), 0.000283851 s/step
# field decay(t = 150.05): 0.016366890524315964 / 35.86940732217567 = 0.0004562910777228651
# run 322 finished at t = 150.05 (15005 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# array([81.24616462])

# %%
opt.sim.plot2D(fields=mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
print(np.array(design_variables.weights))
# Out:
# [8.73612560e-09 3.11366689e-08 1.00437587e-07 ... 1.00437587e-07
#  3.11366689e-08 8.73612560e-09]

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
np.savetxt("Symmetry_apply.txt", design_variables.weights)

# %%
plt.figure()

plt.plot(np.mean(evaluation_history, axis =1), "o-")
plt.grid(True)
plt.xlabel("Iteration")
plt.ylabel("FOM")
plt.show()

# %%
plt.figure()

plt.plot(evaluation_history, "o-")
plt.grid(True)
plt.xlabel("Iteration")
plt.ylabel("FOM")
plt.show()

# %%
80.984 / 17.081
# Out:
# 4.741174404308881

# %%
dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)

# %%
# dft_fields_array: DFT 필드 데이터 (complex 1D array)
N = len(dft_fields_array)
dx = 1.0 / resolution        # 공간 샘플링 간격
k0 = 2 * np.pi * fcen        # 진공 파수

# 1) kx 배열 (rad/unit length)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 각도 계산 (mask 없이)
#    arcsin 안에서 ratio가 ±1을 벗어나면 nan이 되므로,
#    확인용으로는 clip을 사용해 두어도 좋습니다.
theta = np.arcsin(np.clip(kx / k0, -1, 1))  
theta_deg = np.degrees(theta)

# 4) 이론적 전반사 위치 계산
#    (예: 상부 매질 굴절률이 n2, 하부가 n1이라면 θ_crit = arcsin(n2/n1))
theta_c = np.arcsin(1 /2.6)            
kx_cr = k0 * np.sin(theta_c)

# 5) kx_cr 에 가장 가까운 인덱스
idx = np.argmin(np.abs(kx - kx_cr))

print(f"이론적 임계각 θ_crit = {np.degrees(theta_c):.3f}°")
print(f"계산된 θ(kx_cr) = {theta_deg[idx]:.3f}°")

# 6) 전체 패턴 플롯
plt.figure()
plt.plot(theta_deg, np.abs(E_k)**2, 'ro')
# plt.axvline(np.degrees(theta_c), color='k', linestyle='--', label='θ_crit')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.legend()
plt.show()
# Out:
# 이론적 임계각 θ_crit = 22.620°
# 계산된 θ(kx_cr) = 29.308°
# /tmp/ipykernel_64167/2184544693.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) DFT 필드 (complex 1D array)
E = dft_fields_array
N = len(E)
dx = 1.0 / resolution    # 공간 샘플 간격
k0 = 2 * np.pi * fcen    # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

# 4) 세기 계산
I_k = np.abs(E_k)**2

# 5) 모든 데이터 플롯
plt.figure(figsize=(6,4))
plt.plot(kx, I_k, '.-')
plt.xlabel('kx (rad / unit length)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Full k-spectrum (no masking)')
plt.grid(True)
plt.tight_layout()
plt.xlim(-40,40)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# dft_fields_array: 시뮬레이션에서 얻은 DFT 필드 (complex 1D array)
N  = len(dft_fields_array)
dx = 1.0 / resolution      # 공간 샘플링 간격
k0 = 2 * np.pi * fcen      # 진공 파수

# 1) kx 벡터 생성 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 전파 모드(Propagating modes)만 골라내기 (임계각 이내)
mask = np.abs(kx) <= k0

# 4) 각도 변환
theta = np.arcsin(kx[mask] / k0)      # 라디안
theta_deg = np.degrees(theta)         # 도(deg)

# 5) 스펙트럼 세기 계산
I_theta = np.abs(E_k[mask])**2

# 6) 방사각 분포 플롯
plt.figure(figsize=(6,4))
plt.plot(theta_deg, I_theta, '-ro')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Angular Radiation Pattern')
plt.grid(True)
# plt.xlim(-40, 40)
plt.tight_layout()
plt.show()
