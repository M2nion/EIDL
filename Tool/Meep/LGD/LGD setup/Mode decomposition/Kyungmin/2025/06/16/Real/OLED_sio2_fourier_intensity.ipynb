# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
import math

from meep.materials import Ag

# %%
lambda_min = 0.4       # 최소 파장 (µm)
lambda_max = 0.7       # 최대 파장 (µm)
fmin = 1/lambda_max    # 최소 주파수
fmax = 1/lambda_min    # 최대 주파수
fcen = 0.5*(fmin+fmax) # 중앙 주파수
df = fmax-fmin         # 주파수 대역폭

resolution = 50        # 시뮬레이션 해상도
nfreq = 1             # 추출할 주파수 개수
design_region_resolution = 50

# %%
tag_bot         = 0.5
tag_side        = 4
tsio2           = 4
tdesignregion   = 1
monitor_position = 1 / fcen
monitor_blank   = 1 / fcen * 0.1

tpml = 0.4

width_ag = 0.2
width_sio2 = 2

width_bot_ag = width_ag+width_sio2+width_ag

design_region_width = round(width_bot_ag, 3)
design_region_height = 1

Sx = tpml+width_bot_ag+tpml
Sy = tag_bot+tag_side+tdesignregion+monitor_position+monitor_blank+tpml

SiO2 = mp.Medium(index = 1.45)
TiO2 = mp.Medium(index = 2.6)

Nx = int(design_region_resolution * design_region_width) + 1
Ny = int(design_region_resolution * design_region_height) + 1

y_bottom = -Sy/2
center_y_ag = y_bottom + tag_bot / 2
center_y_sio2 = y_bottom + tag_bot + tsio2 / 2
center_y_design = y_bottom + tag_bot + tsio2 + design_region_height / 2
center_y_monitor_position = y_bottom + tag_bot + tsio2 + design_region_height + 1/fcen
center_y_source_position = y_bottom + tag_bot + 1/fcen 
center_Ag_x_position = design_region_width/2-width_ag/2 #+ tpml/2

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny), TiO2, SiO2,  grid_type="U_MEAN")

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


boundary_layers = [mp.Absorber(tpml,direction=mp.X),
                   mp.PML(tpml,direction=mp.Y,side=mp.High)]

# %%
cell_size = mp.Vector3(Sx, Sy)
geometry = [
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_bot_ag, tag_bot, 0),
        center=mp.Vector3(0, center_y_ag, 0)
    ),
    mp.Block(
        material=SiO2,
        size=mp.Vector3(width_sio2, tsio2, 0),
        center=mp.Vector3(0, center_y_sio2, 0)
    ),
    mp.Block(
        material=design_variables,
        size=mp.Vector3(design_region_width, design_region_height, 0),
        center=mp.Vector3(0, center_y_design, 0)
    ),

    ######### Side metal ########## 
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(-center_Ag_x_position, center_y_sio2, 0)
    ),
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(center_Ag_x_position, center_y_sio2, 0)
    ),
]

# %%
src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True)

sources = mp.Source(
            src,
            component=mp.Ez,
            center=mp.Vector3(
                0,
                center_y_source_position,  # Alq3 층의 중간 높이
                0
            )
        )


sim = mp.Simulation(
    resolution=resolution,
    sources=[sources],
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    default_material=mp.Medium(index = 1),
    extra_materials=[Ag]
)

# %%
offset = 0.01
flux_size = 0.02

input_flux = sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
# dft_fields = sim.add_dft_fields([mp.Ez], fcen, 0, 1, 
#                                     center = mp.Vector3(0, center_y_monitor_position),
#                                     size = mp.Vector3(2*1/fcen,0,0), 
#                                     yee_gri=True)

# %%
sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# sim.run(until=10)
# sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
sim.plot2D()
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00053215 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.051136 s
# time for set_conductivity = 0.00187802 s
# time for set_conductivity = 0.00203109 s
# time for set_conductivity = 0.00201797 s
# time for set_conductivity = 0.00204682 s
# time for set_conductivity = 0.00202489 s
# time for set_conductivity = 0.002074 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.6009124373349221 / 35.86940732217567 = 0.01675278411872219
# field decay(t = 90.03): 0.2632202409285167 / 35.86940732217567 = 0.007338293564883776
# on time step 11332 (time=113.32), 0.000352995 s/step
# field decay(t = 120.04): 0.16244911625938363 / 35.86940732217567 = 0.004528904389199432
# field decay(t = 150.05): 0.08156655423702402 / 35.86940732217567 = 0.002273986673501484
# field decay(t = 180.06): 0.03438519580198319 / 35.86940732217567 = 0.0009586217997174743
# run 0 finished at t = 180.06 (18006 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# array([17.0813335])

# %%
sim.plot2D(fields = mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# array([17.0813335])

# %%
minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

def mapping(x, eta, beta):

    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_width,
        design_region_height,
        design_region_resolution,
    )

    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)

    projected_field = (
        npa.fliplr(projected_field) + projected_field
    ) / 2  # up-down symmetry

    # interpolate to actual materials
    return projected_field.flatten()

# %%
monitor_position, monitor_size = mp.Vector3(0, center_y_monitor_position), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=[fcen],
    maximum_run_time=100,
)

np.random.seed(0)
rho_vector = np.random.rand(Nx * Ny)
opt.update_design([mapping(rho_vector, eta_i, 1e3)])

opt.plot2D(True)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append(np.real(f0))

    plt.figure()
    ax = plt.gca()
    opt.plot2D(
        False,
        ax=ax,
        plot_sources_flag=False,
        plot_monitors_flag=False,
        plot_boundaries_flag=False,
    )
    circ = Circle((2, 2), minimum_length / 2)
    ax.add_patch(circ)
    ax.axis("off")
    plt.show()

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %%
evaluation_history = []
cur_iter = [0]
numevl = 0

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0 = []
    dJ_du = []

    global numevl

    f0_i, dJ_du_i = opt([mapping(v, eta_i, beta)])
    
    f0.append(f0_i.flatten())
    dJ_du.append(dJ_du_i)
        
        
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append([np.max(np.real(f0))])

    numevl += 1
    cur_iter[0] = cur_iter[0] + 1

    print("First FoM: {}".format(evaluation_history[0]))
    # print("Current f0 values: " + ", ".join(["f0_{}: {}".format(i, np.real(f0[i])) for i in range(n_dipole)]))

    return np.mean(f0)  # return the sum of the objective function values

# %%
algorithm = nlopt.LD_MMA
n = Nx * Ny  # number of parameters

# Initial guess
x = np.ones((n,)) * 0.5

# lower and upper bounds
lb = np.zeros((Nx * Ny,))
ub = np.ones((Nx * Ny,))

cur_beta = 4
beta_scale = 1.5
num_betas = 8
update_factor = 30
ftol = 1e-8

for iters in range(num_betas):
    solver = nlopt.opt(algorithm, n)
    solver.set_lower_bounds(lb)
    solver.set_upper_bounds(ub)
    solver.set_max_objective(lambda a, g: f(a, g, cur_beta))
    solver.set_maxeval(update_factor)
    solver.set_ftol_rel(ftol)
    x[:] = solver.optimize(x)
    cur_beta = cur_beta * beta_scale
# Out:
# Current iteration: 1
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0523491 s
# time for set_conductivity = 0.00199008 s
# time for set_conductivity = 0.00198913 s
# time for set_conductivity = 0.0020051 s
# time for set_conductivity = 0.00199103 s
# time for set_conductivity = 0.00197411 s
# time for set_conductivity = 0.00198698 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 1 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 2 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 2
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0542769 s
# time for set_conductivity = 0.00199986 s
# time for set_conductivity = 0.0020349 s
# time for set_conductivity = 0.00199819 s
# time for set_conductivity = 0.00206304 s
# time for set_conductivity = 0.00205517 s
# time for set_conductivity = 0.00210118 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 3 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 4 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 3
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0561888 s
# time for set_conductivity = 0.00210905 s
# time for set_conductivity = 0.00248194 s
# time for set_conductivity = 0.00219202 s
# time for set_conductivity = 0.00212717 s
# time for set_conductivity = 0.0022521 s
# time for set_conductivity = 0.00226307 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 6227 (time=62.27), 0.000642404 s/step
# run 5 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 6 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 4
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0520301 s
# time for set_conductivity = 0.00187492 s
# time for set_conductivity = 0.00188208 s
# time for set_conductivity = 0.00188494 s
# time for set_conductivity = 0.00186586 s
# time for set_conductivity = 0.0018959 s
# time for set_conductivity = 0.00186706 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 7 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 8 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 5
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0558598 s
# time for set_conductivity = 0.00197887 s
# time for set_conductivity = 0.00201893 s
# time for set_conductivity = 0.00197792 s
# time for set_conductivity = 0.00198293 s
# time for set_conductivity = 0.00200701 s
# time for set_conductivity = 0.002177 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 9 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 10 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 6
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053206 s
# time for set_conductivity = 0.00236797 s
# time for set_conductivity = 0.00202107 s
# time for set_conductivity = 0.00226092 s
# time for set_conductivity = 0.00204492 s
# time for set_conductivity = 0.00199103 s
# time for set_conductivity = 0.00203991 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 11 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 12 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 7
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0532651 s
# time for set_conductivity = 0.00203395 s
# time for set_conductivity = 0.00199389 s
# time for set_conductivity = 0.00204706 s
# time for set_conductivity = 0.00197792 s
# time for set_conductivity = 0.00233698 s
# time for set_conductivity = 0.00199008 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 13 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 5712 (time=57.12), 0.00074003 s/step
# run 14 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 8
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0522161 s
# time for set_conductivity = 0.00199103 s
# time for set_conductivity = 0.00204611 s
# time for set_conductivity = 0.00197196 s
# time for set_conductivity = 0.00202394 s
# time for set_conductivity = 0.00195813 s
# time for set_conductivity = 0.00201392 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 15 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 16 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 9
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0538201 s
# time for set_conductivity = 0.00228095 s
# time for set_conductivity = 0.00203586 s
# time for set_conductivity = 0.00208783 s
# time for set_conductivity = 0.00198913 s
# time for set_conductivity = 0.00201511 s
# time for set_conductivity = 0.00201201 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 17 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 18 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 10
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053086 s
# time for set_conductivity = 0.00200105 s
# time for set_conductivity = 0.00202298 s
# time for set_conductivity = 0.0019629 s
# time for set_conductivity = 0.00201893 s
# time for set_conductivity = 0.00203991 s
# time for set_conductivity = 0.00199986 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 19 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 20 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 11
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0530581 s
# time for set_conductivity = 0.001966 s
# time for set_conductivity = 0.00199413 s
# time for set_conductivity = 0.00198793 s
# time for set_conductivity = 0.00203395 s
# time for set_conductivity = 0.00198007 s
# time for set_conductivity = 0.00224209 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 21 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 22 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 12
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0540559 s
# time for set_conductivity = 0.00202823 s
# time for set_conductivity = 0.00199413 s
# time for set_conductivity = 0.00199199 s
# time for set_conductivity = 0.00197792 s
# time for set_conductivity = 0.00196481 s
# time for set_conductivity = 0.00197601 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 6516 (time=65.16), 0.000613883 s/step
# run 23 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 24 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 13
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053046 s
# time for set_conductivity = 0.00197911 s
# time for set_conductivity = 0.00200701 s
# time for set_conductivity = 0.00199795 s
# time for set_conductivity = 0.00204802 s
# time for set_conductivity = 0.00199485 s
# time for set_conductivity = 0.0022471 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 25 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 26 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 14
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.052918 s
# time for set_conductivity = 0.00199413 s
# time for set_conductivity = 0.00206494 s
# time for set_conductivity = 0.00200987 s
# time for set_conductivity = 0.00202894 s
# time for set_conductivity = 0.00195789 s
# time for set_conductivity = 0.0020051 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 27 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 28 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 15
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.052655 s
# time for set_conductivity = 0.00197101 s
# time for set_conductivity = 0.002002 s
# time for set_conductivity = 0.00199103 s
# time for set_conductivity = 0.0019989 s
# time for set_conductivity = 0.00195599 s
# time for set_conductivity = 0.00198388 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 29 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 30 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 16
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053798 s
# time for set_conductivity = 0.00198913 s
# time for set_conductivity = 0.00198412 s
# time for set_conductivity = 0.00225592 s
# time for set_conductivity = 0.00203013 s
# time for set_conductivity = 0.00197697 s
# time for set_conductivity = 0.00204396 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 31 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 6630 (time=66.3), 0.000603344 s/step
# run 32 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 17
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0522981 s
# time for set_conductivity = 0.00197101 s
# time for set_conductivity = 0.0020051 s
# time for set_conductivity = 0.00199914 s
# time for set_conductivity = 0.00198102 s
# time for set_conductivity = 0.0019989 s
# time for set_conductivity = 0.00199986 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 33 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 34 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 18
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.052696 s
# time for set_conductivity = 0.00197911 s
# time for set_conductivity = 0.00204802 s
# time for set_conductivity = 0.00197601 s
# time for set_conductivity = 0.00200415 s
# time for set_conductivity = 0.00197816 s
# time for set_conductivity = 0.00199604 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 35 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 36 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 19
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.054513 s
# time for set_conductivity = 0.00221586 s
# time for set_conductivity = 0.00197196 s
# time for set_conductivity = 0.00197911 s
# time for set_conductivity = 0.00208712 s
# time for set_conductivity = 0.00199699 s
# time for set_conductivity = 0.00196314 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 37 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 38 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 20
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.38419e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.052907 s
# time for set_conductivity = 0.00197601 s
# time for set_conductivity = 0.00199199 s
# time for set_conductivity = 0.00201893 s
# time for set_conductivity = 0.00198817 s
# time for set_conductivity = 0.00198293 s
# time for set_conductivity = 0.00197291 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 39 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 9009 (time=90.09), 0.00054114 s/step
# run 40 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 21
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053185 s
# time for set_conductivity = 0.00198102 s
# time for set_conductivity = 0.00215602 s
# time for set_conductivity = 0.00199199 s
# time for set_conductivity = 0.00228 s
# time for set_conductivity = 0.00205803 s
# time for set_conductivity = 0.00198889 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 41 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 42 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 22
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.79086e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0538421 s
# time for set_conductivity = 0.00199699 s
# time for set_conductivity = 0.00215292 s
# time for set_conductivity = 0.00196695 s
# time for set_conductivity = 0.00230384 s
# time for set_conductivity = 0.00207901 s
# time for set_conductivity = 0.00201297 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 43 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 44 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 23
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053159 s
# time for set_conductivity = 0.00202298 s
# time for set_conductivity = 0.00200915 s
# time for set_conductivity = 0.00200987 s
# time for set_conductivity = 0.00208902 s
# time for set_conductivity = 0.00197697 s
# time for set_conductivity = 0.00198293 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 45 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 46 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 24
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.054951 s
# time for set_conductivity = 0.00222802 s
# time for set_conductivity = 0.00200009 s
# time for set_conductivity = 0.00224614 s
# time for set_conductivity = 0.00196409 s
# time for set_conductivity = 0.00201702 s
# time for set_conductivity = 0.00195694 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 47 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 48 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 25
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0543661 s
# time for set_conductivity = 0.002002 s
# time for set_conductivity = 0.00197196 s
# time for set_conductivity = 0.002002 s
# time for set_conductivity = 0.00197911 s
# time for set_conductivity = 0.00200009 s
# time for set_conductivity = 0.00198483 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 6725 (time=67.25), 0.000606148 s/step
# run 49 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 50 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 26
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0554008 s
# time for set_conductivity = 0.00197005 s
# time for set_conductivity = 0.00213504 s
# time for set_conductivity = 0.00198412 s
# time for set_conductivity = 0.00197291 s
# time for set_conductivity = 0.00202203 s
# time for set_conductivity = 0.00196886 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 51 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 52 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 27
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.47955e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0538599 s
# time for set_conductivity = 0.00196004 s
# time for set_conductivity = 0.00202799 s
# time for set_conductivity = 0.00223899 s
# time for set_conductivity = 0.00201988 s
# time for set_conductivity = 0.00223207 s
# time for set_conductivity = 0.00201702 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# ...
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.060056 s
# time for set_conductivity = 0.00195599 s
# time for set_conductivity = 0.00229502 s
# time for set_conductivity = 0.00199795 s
# time for set_conductivity = 0.00338197 s
# time for set_conductivity = 0.00270891 s
# time for set_conductivity = 0.00290799 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 463 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 464 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 233
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0607722 s
# time for set_conductivity = 0.0020051 s
# time for set_conductivity = 0.00198889 s
# time for set_conductivity = 0.00197983 s
# time for set_conductivity = 0.00199199 s
# time for set_conductivity = 0.00197697 s
# time for set_conductivity = 0.00197482 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 6572 (time=65.72), 0.000608691 s/step
# run 465 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 466 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 234
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0616581 s
# time for set_conductivity = 0.00229311 s
# time for set_conductivity = 0.00199819 s
# time for set_conductivity = 0.00200105 s
# time for set_conductivity = 0.00198293 s
# time for set_conductivity = 0.00196409 s
# time for set_conductivity = 0.00195217 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 467 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 468 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 235
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0610271 s
# time for set_conductivity = 0.00200391 s
# time for set_conductivity = 0.00199389 s
# time for set_conductivity = 0.00200391 s
# time for set_conductivity = 0.00202608 s
# time for set_conductivity = 0.00196004 s
# time for set_conductivity = 0.00198889 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 469 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 470 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 236
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0641251 s
# time for set_conductivity = 0.00200796 s
# time for set_conductivity = 0.00198913 s
# time for set_conductivity = 0.00197482 s
# time for set_conductivity = 0.00198603 s
# time for set_conductivity = 0.00197387 s
# time for set_conductivity = 0.00201702 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 471 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 472 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 237
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057822 s
# time for set_conductivity = 0.00200701 s
# time for set_conductivity = 0.002285 s
# time for set_conductivity = 0.00251293 s
# time for set_conductivity = 0.00199199 s
# time for set_conductivity = 0.00200295 s
# time for set_conductivity = 0.00200796 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 473 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 6295 (time=62.95), 0.000635467 s/step
# run 474 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 238
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.47955e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0524158 s
# time for set_conductivity = 0.00207305 s
# time for set_conductivity = 0.00206518 s
# time for set_conductivity = 0.00202894 s
# time for set_conductivity = 0.00212884 s
# time for set_conductivity = 0.00198698 s
# time for set_conductivity = 0.002038 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 475 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 476 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 239
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0596752 s
# time for set_conductivity = 0.00210404 s
# time for set_conductivity = 0.00206804 s
# time for set_conductivity = 0.00232196 s
# time for set_conductivity = 0.0020051 s
# time for set_conductivity = 0.00223303 s
# time for set_conductivity = 0.00204992 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 477 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 478 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 240
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0585551 s
# time for set_conductivity = 0.00197601 s
# time for set_conductivity = 0.00199795 s
# time for set_conductivity = 0.00197601 s
# time for set_conductivity = 0.00201702 s
# time for set_conductivity = 0.00194883 s
# time for set_conductivity = 0.001966 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 479 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 480 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]

# %%
opt.update_design([mapping(x, eta_i, cur_beta/beta_scale)]) # cur_beta/beta_scale is the final beta in the optimization.
plt.figure()
ax = plt.gca()
opt.plot2D(True)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
offset = 0.01
flux_size = 0.02

input_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
opt.sim.plot2D()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# opt.sim.run(until=10)
# opt.sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
opt.sim.plot2D()
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.055588 s
# time for set_conductivity = 0.00199509 s
# time for set_conductivity = 0.00199008 s
# time for set_conductivity = 0.00196695 s
# time for set_conductivity = 0.00201201 s
# time for set_conductivity = 0.00196099 s
# time for set_conductivity = 0.00198913 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# on time step 5605 (time=56.05), 0.000713695 s/step
# field decay(t = 60.02): 0.2260618189807817 / 35.86940732217567 = 0.006302357241376072
# field decay(t = 90.03): 0.14468161092029733 / 35.86940732217567 = 0.004033565696270936
# field decay(t = 120.04): 0.035539510277883136 / 35.86940732217567 = 0.0009908028297950554
# run 483 finished at t = 120.04 (12004 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# array([69.17749272])

# %%
opt.sim.plot2D(fields=mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
print(np.array(design_variables.weights))
# Out:
# [4.34652314e-14 5.10480547e-13 6.01008132e-12 ... 6.01008132e-12
#  5.10480547e-13 4.34652314e-14]

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
np.savetxt("Symmetry_apply.txt", design_variables.weights)

# %%
plt.figure()

fontlabel = 16

plt.figure(figsize = (6,6))
plt.plot(np.mean(evaluation_history, axis =1), "ob-", )
plt.grid(True)
plt.xlabel("Iteration", fontsize = fontlabel)
plt.ylabel("FOM", fontsize = fontlabel)
plt.xticks(fontsize = fontlabel)
plt.yticks(fontsize = fontlabel)
plt.show()

# %%
plt.figure()

plt.plot(evaluation_history, "o-")
plt.grid(True)
plt.xlabel("Iteration")
plt.ylabel("FOM")
plt.show()

# %%
print(evaluation_history[0])
print(evaluation_history[239])
# Out:
# [0.09519464439557002]
# [0.3554761549985557]

# %%
69.1775 / 17.081 
0.35547/0.0951
# Out:
# 3.7378548895899053

# %%
dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)
#
# NameError: name 'dft_fields' is not defined

# %%
# dft_fields_array: DFT 필드 데이터 (complex 1D array)
N = len(dft_fields_array)
dx = 1.0 / resolution        # 공간 샘플링 간격
k0 = 2 * np.pi * fcen        # 진공 파수

# 1) kx 배열 (rad/unit length)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 각도 계산 (mask 없이)
#    arcsin 안에서 ratio가 ±1을 벗어나면 nan이 되므로,
#    확인용으로는 clip을 사용해 두어도 좋습니다.
theta = np.arcsin(np.clip(kx / k0, -1, 1))  
theta_deg = np.degrees(theta)

# 4) 이론적 전반사 위치 계산
#    (예: 상부 매질 굴절률이 n2, 하부가 n1이라면 θ_crit = arcsin(n2/n1))
theta_c = np.arcsin(1 /2.6)            
kx_cr = k0 * np.sin(theta_c)

# 5) kx_cr 에 가장 가까운 인덱스
idx = np.argmin(np.abs(kx - kx_cr))

print(f"이론적 임계각 θ_crit = {np.degrees(theta_c):.3f}°")
print(f"계산된 θ(kx_cr) = {theta_deg[idx]:.3f}°")

# 6) 전체 패턴 플롯
plt.figure()
plt.plot(theta_deg, np.abs(E_k)**2, 'ro')
# plt.axvline(np.degrees(theta_c), color='k', linestyle='--', label='θ_crit')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.legend()
plt.show()
# Out:
# 이론적 임계각 θ_crit = 22.620°
# 계산된 θ(kx_cr) = 29.308°
# /tmp/ipykernel_64167/2184544693.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) DFT 필드 (complex 1D array)
E = dft_fields_array
N = len(E)
dx = 1.0 / resolution    # 공간 샘플 간격
k0 = 2 * np.pi * fcen    # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

# 4) 세기 계산
I_k = np.abs(E_k)**2

# 5) 모든 데이터 플롯
plt.figure(figsize=(6,4))
plt.plot(kx, I_k, '.-')
plt.xlabel('kx (rad / unit length)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Full k-spectrum (no masking)')
plt.grid(True)
plt.tight_layout()
plt.xlim(-40,40)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# dft_fields_array: 시뮬레이션에서 얻은 DFT 필드 (complex 1D array)
N  = len(dft_fields_array)
dx = 1.0 / resolution      # 공간 샘플링 간격
k0 = 2 * np.pi * fcen      # 진공 파수

# 1) kx 벡터 생성 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 전파 모드(Propagating modes)만 골라내기 (임계각 이내)
mask = np.abs(kx) <= k0

# 4) 각도 변환
theta = np.arcsin(kx[mask] / k0)      # 라디안
theta_deg = np.degrees(theta)         # 도(deg)

# 5) 스펙트럼 세기 계산
I_theta = np.abs(E_k[mask])**2

# 6) 방사각 분포 플롯
plt.figure(figsize=(6,4))
plt.plot(theta_deg, I_theta, '-ro')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Angular Radiation Pattern')
plt.grid(True)
# plt.xlim(-40, 40)
plt.tight_layout()
plt.show()
