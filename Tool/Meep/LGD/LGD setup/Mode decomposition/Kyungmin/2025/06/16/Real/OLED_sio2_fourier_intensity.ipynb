# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
import math

from meep.materials import Ag

# %%
lambda_min = 0.4       # 최소 파장 (µm)
lambda_max = 0.7       # 최대 파장 (µm)
fmin = 1/lambda_max    # 최소 주파수
fmax = 1/lambda_min    # 최대 주파수
fcen = 0.5*(fmin+fmax) # 중앙 주파수
df = fmax-fmin         # 주파수 대역폭

resolution = 50        # 시뮬레이션 해상도
nfreq = 1             # 추출할 주파수 개수
design_region_resolution = 50

# %%
tag_bot         = 0.5
tag_side        = 4
tsio2           = 4
tdesignregion   = 1
monitor_position = 1 / fcen
monitor_blank   = 1 / fcen * 0.1

tpml = 0.4

width_ag = 0.2
width_sio2 = 2

width_bot_ag = width_ag+width_sio2+width_ag

design_region_width = round(width_bot_ag, 3)
design_region_height = 1

Sx = tpml+width_bot_ag+tpml
Sy = tag_bot+tag_side+tdesignregion+monitor_position+monitor_blank+tpml

SiO2 = mp.Medium(index = 1.45)
TiO2 = mp.Medium(index = 2.6)

Nx = int(design_region_resolution * design_region_width) + 1
Ny = int(design_region_resolution * design_region_height) + 1

y_bottom = -Sy/2
center_y_ag = y_bottom + tag_bot / 2
center_y_sio2 = y_bottom + tag_bot + tsio2 / 2
center_y_design = y_bottom + tag_bot + tsio2 + design_region_height / 2
center_y_monitor_position = y_bottom + tag_bot + tsio2 + design_region_height + 1/fcen
center_y_source_position = y_bottom + tag_bot + 1/fcen 
center_Ag_x_position = design_region_width/2-width_ag/2 #+ tpml/2

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny), TiO2, SiO2,  grid_type="U_MEAN")

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


boundary_layers = [mp.Absorber(tpml,direction=mp.X),
                   mp.PML(tpml,direction=mp.Y,side=mp.High)]

# %%
cell_size = mp.Vector3(Sx, Sy)
geometry = [
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_bot_ag, tag_bot, 0),
        center=mp.Vector3(0, center_y_ag, 0)
    ),
    mp.Block(
        material=SiO2,
        size=mp.Vector3(width_sio2, tsio2, 0),
        center=mp.Vector3(0, center_y_sio2, 0)
    ),
    mp.Block(
        material=design_variables,
        size=mp.Vector3(design_region_width, design_region_height, 0),
        center=mp.Vector3(0, center_y_design, 0)
    ),

    ######### Side metal ########## 
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(-center_Ag_x_position, center_y_sio2, 0)
    ),
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(center_Ag_x_position, center_y_sio2, 0)
    ),
]

# %%
src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True)

sources = mp.Source(
            src,
            component=mp.Ez,
            center=mp.Vector3(
                0,
                center_y_source_position,  # Alq3 층의 중간 높이
                0
            )
        )


sim = mp.Simulation(
    resolution=resolution,
    sources=[sources],
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    default_material=mp.Medium(index = 1),
    extra_materials=[Ag]
)

# %%
# dft_fields = sim.add_dft_fields([mp.Ez], fcen, 0, 1, 
#                                     center = mp.Vector3(0, center_y_monitor_position),
#                                     size = mp.Vector3(2*1/fcen,0,0), 
#                                     yee_gri=True)

# %%
minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

def mapping(x, eta, beta):

    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_width,
        design_region_height,
        design_region_resolution,
    )

    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)

    projected_field = (
        npa.fliplr(projected_field) + projected_field
    ) / 2  # up-down symmetry

    # interpolate to actual materials
    return projected_field.flatten()

# %%
monitor_position, monitor_size = mp.Vector3(0, center_y_monitor_position), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=[fcen],
    maximum_run_time=100,
)

np.random.seed(0)
rho_vector = np.random.rand(Nx * Ny)
opt.update_design([mapping(rho_vector, eta_i, 1e3)])

opt.plot2D(True)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append(np.real(f0))

    plt.figure()
    ax = plt.gca()
    opt.plot2D(
        False,
        ax=ax,
        plot_sources_flag=False,
        plot_monitors_flag=False,
        plot_boundaries_flag=False,
    )
    circ = Circle((2, 2), minimum_length / 2)
    ax.add_patch(circ)
    ax.axis("off")
    plt.show()

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %%
evaluation_history = []
cur_iter = [0]
numevl = 0

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0 = []
    dJ_du = []

    global numevl

    f0_i, dJ_du_i = opt([mapping(v, eta_i, beta)])
    
    f0.append(f0_i.flatten())
    dJ_du.append(dJ_du_i)
        
        
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append([np.max(np.real(f0))])

    numevl += 1
    cur_iter[0] = cur_iter[0] + 1

    print("First FoM: {}".format(evaluation_history[0]))
    # print("Current f0 values: " + ", ".join(["f0_{}: {}".format(i, np.real(f0[i])) for i in range(n_dipole)]))

    return np.mean(f0)  # return the sum of the objective function values

# %%
algorithm = nlopt.LD_MMA
n = Nx * Ny  # number of parameters

# Initial guess
x = np.ones((n,)) * 0.5

# lower and upper bounds
lb = np.zeros((Nx * Ny,))
ub = np.ones((Nx * Ny,))

cur_beta = 4
beta_scale = 1.5
num_betas = 8
update_factor = 10
ftol = 1e-5

for iters in range(num_betas):
    solver = nlopt.opt(algorithm, n)
    solver.set_lower_bounds(lb)
    solver.set_upper_bounds(ub)
    solver.set_max_objective(lambda a, g: f(a, g, cur_beta))
    solver.set_maxeval(update_factor)
    solver.set_ftol_rel(ftol)
    x[:] = solver.optimize(x)
    cur_beta = cur_beta * beta_scale
# Out:
# Current iteration: 1
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.79086e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.056113 s
# time for set_conductivity = 0.00199819 s
# time for set_conductivity = 0.00218987 s
# time for set_conductivity = 0.00213218 s
# time for set_conductivity = 0.00308394 s
# time for set_conductivity = 0.00206995 s
# time for set_conductivity = 0.00231385 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 7320 (time=73.2), 0.000546506 s/step
# run 0 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 7297 (time=72.97), 0.000548175 s/step
# run 1 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 2
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0536351 s
# time for set_conductivity = 0.00196505 s
# time for set_conductivity = 0.00197697 s
# time for set_conductivity = 0.00200605 s
# time for set_conductivity = 0.00202417 s
# time for set_conductivity = 0.00196004 s
# time for set_conductivity = 0.00197601 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 7156 (time=71.56), 0.000558988 s/step
# run 2 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 6915 (time=69.15), 0.00057847 s/step
# run 3 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 3
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.38419e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0527401 s
# time for set_conductivity = 0.0020411 s
# time for set_conductivity = 0.002033 s
# time for set_conductivity = 0.00237608 s
# time for set_conductivity = 0.00202703 s
# time for set_conductivity = 0.00196886 s
# time for set_conductivity = 0.00199699 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 4520 (time=45.2), 0.000884966 s/step
# run 4 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 7311 (time=73.11), 0.000547186 s/step
# run 5 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 4
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0538862 s
# time for set_conductivity = 0.00202107 s
# time for set_conductivity = 0.00207281 s
# time for set_conductivity = 0.00206518 s
# time for set_conductivity = 0.00202894 s
# time for set_conductivity = 0.00211883 s
# time for set_conductivity = 0.00226092 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 5685 (time=56.85), 0.000703674 s/step
# run 6 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 7122 (time=71.22), 0.000561694 s/step
# run 7 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 5
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.054354 s
# time for set_conductivity = 0.00212598 s
# time for set_conductivity = 0.00205612 s
# time for set_conductivity = 0.00204396 s
# time for set_conductivity = 0.002244 s
# time for set_conductivity = 0.00200081 s
# time for set_conductivity = 0.00207186 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 6416 (time=64.16), 0.00062348 s/step
# run 8 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 7418 (time=74.18), 0.000539263 s/step
# run 9 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 6
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053762 s
# time for set_conductivity = 0.00199294 s
# time for set_conductivity = 0.00217199 s
# time for set_conductivity = 0.00207901 s
# time for set_conductivity = 0.00200415 s
# time for set_conductivity = 0.00198483 s
# time for set_conductivity = 0.00202584 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 7227 (time=72.27), 0.000553517 s/step
# run 10 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 9679 (time=96.79), 0.000413294 s/step
# run 11 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 7
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.054198 s
# time for set_conductivity = 0.00199294 s
# time for set_conductivity = 0.00202894 s
# time for set_conductivity = 0.00200891 s
# time for set_conductivity = 0.00204301 s
# time for set_conductivity = 0.00230598 s
# time for set_conductivity = 0.00201607 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 12 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 13 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 8
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0516548 s
# time for set_conductivity = 0.00196505 s
# time for set_conductivity = 0.00196409 s
# time for set_conductivity = 0.00196218 s
# time for set_conductivity = 0.00193596 s
# time for set_conductivity = 0.002213 s
# time for set_conductivity = 0.00193906 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 14 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 15 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 9
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053566 s
# time for set_conductivity = 0.00201106 s
# time for set_conductivity = 0.00232911 s
# time for set_conductivity = 0.00202107 s
# time for set_conductivity = 0.00204706 s
# time for set_conductivity = 0.00200009 s
# time for set_conductivity = 0.00201702 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 16 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 8658 (time=86.58), 0.000543985 s/step
# run 17 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 10
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.31266e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0537851 s
# time for set_conductivity = 0.00198197 s
# time for set_conductivity = 0.00201201 s
# time for set_conductivity = 0.00196218 s
# time for set_conductivity = 0.0022831 s
# time for set_conductivity = 0.00199008 s
# time for set_conductivity = 0.00201011 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 18 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 19 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 11
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0542431 s
# time for set_conductivity = 0.00198698 s
# time for set_conductivity = 0.00207281 s
# time for set_conductivity = 0.00200105 s
# time for set_conductivity = 0.00202012 s
# time for set_conductivity = 0.00199699 s
# time for set_conductivity = 0.00202203 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 20 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 21 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 12
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.21729e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0521679 s
# time for set_conductivity = 0.00191998 s
# time for set_conductivity = 0.00194502 s
# time for set_conductivity = 0.00193 s
# time for set_conductivity = 0.00191307 s
# time for set_conductivity = 0.00192094 s
# time for set_conductivity = 0.00195312 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 22 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 23 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 13
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053715 s
# time for set_conductivity = 0.00198293 s
# time for set_conductivity = 0.002316 s
# time for set_conductivity = 0.00200486 s
# time for set_conductivity = 0.00201511 s
# time for set_conductivity = 0.00200915 s
# time for set_conductivity = 0.00198793 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 24 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 25 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 14
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.052887 s
# time for set_conductivity = 0.00200915 s
# time for set_conductivity = 0.00202799 s
# time for set_conductivity = 0.00202084 s
# time for set_conductivity = 0.00198793 s
# time for set_conductivity = 0.00199509 s
# time for set_conductivity = 0.00198197 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 7321 (time=73.21), 0.000574324 s/step
# run 26 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 27 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 15
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0537958 s
# time for set_conductivity = 0.00200009 s
# time for set_conductivity = 0.00202417 s
# time for set_conductivity = 0.00225282 s
# time for set_conductivity = 0.00210309 s
# time for set_conductivity = 0.00198913 s
# time for set_conductivity = 0.00197887 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 28 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 29 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 16
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0531211 s
# time for set_conductivity = 0.00225592 s
# time for set_conductivity = 0.00198984 s
# time for set_conductivity = 0.00200295 s
# time for set_conductivity = 0.00199604 s
# time for set_conductivity = 0.0019989 s
# time for set_conductivity = 0.00200105 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 30 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 31 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 17
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0563099 s
# time for set_conductivity = 0.00210309 s
# time for set_conductivity = 0.00209594 s
# time for set_conductivity = 0.00214005 s
# time for set_conductivity = 0.00210404 s
# time for set_conductivity = 0.00208497 s
# time for set_conductivity = 0.00213194 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 32 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 33 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 18
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0553651 s
# time for set_conductivity = 0.00199294 s
# time for set_conductivity = 0.00203013 s
# time for set_conductivity = 0.0020299 s
# time for set_conductivity = 0.00198793 s
# time for set_conductivity = 0.00225902 s
# time for set_conductivity = 0.00198913 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 34 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 7177 (time=71.77), 0.000587814 s/step
# run 35 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 19
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.054528 s
# time for set_conductivity = 0.00200701 s
# time for set_conductivity = 0.002316 s
# time for set_conductivity = 0.00202298 s
# time for set_conductivity = 0.00227785 s
# time for set_conductivity = 0.002038 s
# time for set_conductivity = 0.00201893 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 36 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 37 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 20
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0521162 s
# time for set_conductivity = 0.0019691 s
# time for set_conductivity = 0.00201797 s
# time for set_conductivity = 0.00198102 s
# time for set_conductivity = 0.00197792 s
# time for set_conductivity = 0.00199986 s
# time for set_conductivity = 0.00237393 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 38 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 39 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 21
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0529149 s
# time for set_conductivity = 0.00194812 s
# time for set_conductivity = 0.00201201 s
# time for set_conductivity = 0.00198698 s
# time for set_conductivity = 0.00198293 s
# time for set_conductivity = 0.00196695 s
# time for set_conductivity = 0.001966 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 40 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 41 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 22
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0534399 s
# time for set_conductivity = 0.00198412 s
# time for set_conductivity = 0.00198293 s
# time for set_conductivity = 0.00199699 s
# time for set_conductivity = 0.00227213 s
# time for set_conductivity = 0.00202107 s
# time for set_conductivity = 0.00230789 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 42 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 43 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 23
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053833 s
# time for set_conductivity = 0.0020051 s
# time for set_conductivity = 0.00198507 s
# time for set_conductivity = 0.00203204 s
# time for set_conductivity = 0.00198793 s
# time for set_conductivity = 0.00199819 s
# time for set_conductivity = 0.00197101 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 6784 (time=67.84), 0.000589662 s/step
# run 44 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 45 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 24
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.09808e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0519681 s
# time for set_conductivity = 0.00190902 s
# time for set_conductivity = 0.00191498 s
# time for set_conductivity = 0.00192499 s
# time for set_conductivity = 0.00190997 s
# time for set_conductivity = 0.00191212 s
# time for set_conductivity = 0.00190496 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 46 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 47 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 25
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.053515 s
# time for set_conductivity = 0.00197196 s
# time for set_conductivity = 0.00197887 s
# time for set_conductivity = 0.0019331 s
# time for set_conductivity = 0.00198507 s
# time for set_conductivity = 0.00195098 s
# time for set_conductivity = 0.00196314 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 48 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 49 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 26
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0574241 s
# time for set_conductivity = 0.00208902 s
# time for set_conductivity = 0.00213194 s
# time for set_conductivity = 0.00211382 s
# time for set_conductivity = 0.00209308 s
# time for set_conductivity = 0.00207806 s
# time for set_conductivity = 0.00209212 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 50 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 51 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 27
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# ...
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0551519 s
# time for set_conductivity = 0.00203609 s
# time for set_conductivity = 0.00205898 s
# time for set_conductivity = 0.00201416 s
# time for set_conductivity = 0.00205493 s
# time for set_conductivity = 0.00202298 s
# time for set_conductivity = 0.00203109 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 142 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 143 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 73
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.21729e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.052094 s
# time for set_conductivity = 0.00188804 s
# time for set_conductivity = 0.00194001 s
# time for set_conductivity = 0.00186491 s
# time for set_conductivity = 0.00191903 s
# time for set_conductivity = 0.00187206 s
# time for set_conductivity = 0.00187898 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 144 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 145 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 74
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0499279 s
# time for set_conductivity = 0.001858 s
# time for set_conductivity = 0.0018971 s
# time for set_conductivity = 0.00190091 s
# time for set_conductivity = 0.00193286 s
# time for set_conductivity = 0.00187492 s
# time for set_conductivity = 0.00213099 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 146 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 147 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 75
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0527229 s
# time for set_conductivity = 0.00198603 s
# time for set_conductivity = 0.0019691 s
# time for set_conductivity = 0.00199294 s
# time for set_conductivity = 0.00197196 s
# time for set_conductivity = 0.00198889 s
# time for set_conductivity = 0.00207281 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 148 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# on time step 6925 (time=69.25), 0.000735678 s/step
# run 149 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 76
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.059427 s
# time for set_conductivity = 0.00203419 s
# time for set_conductivity = 0.00203609 s
# time for set_conductivity = 0.00203395 s
# time for set_conductivity = 0.00204206 s
# time for set_conductivity = 0.00201797 s
# time for set_conductivity = 0.00210094 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 150 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 151 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 77
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.31266e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0515881 s
# time for set_conductivity = 0.00186992 s
# time for set_conductivity = 0.00186992 s
# time for set_conductivity = 0.00192809 s
# time for set_conductivity = 0.00188804 s
# time for set_conductivity = 0.00187922 s
# time for set_conductivity = 0.00186992 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 152 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 153 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 78
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.21729e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0500848 s
# time for set_conductivity = 0.00188494 s
# time for set_conductivity = 0.001863 s
# time for set_conductivity = 0.00190401 s
# time for set_conductivity = 0.00187802 s
# time for set_conductivity = 0.00189996 s
# time for set_conductivity = 0.00200701 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 154 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 155 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 79
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.40803e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0530791 s
# time for set_conductivity = 0.00198793 s
# time for set_conductivity = 0.00197887 s
# time for set_conductivity = 0.00199604 s
# time for set_conductivity = 0.00197005 s
# time for set_conductivity = 0.00198293 s
# time for set_conductivity = 0.00200105 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 156 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 157 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]
# Current iteration: 80
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.052659 s
# time for set_conductivity = 0.0022521 s
# time for set_conductivity = 0.00204897 s
# time for set_conductivity = 0.00197697 s
# time for set_conductivity = 0.00236416 s
# time for set_conductivity = 0.00199294 s
# time for set_conductivity = 0.00198293 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 3891 (time=38.91), 0.00102802 s/step
# run 158 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 159 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09387706396685475]

# %%
opt.update_design([mapping(x, eta_i, cur_beta/beta_scale)]) # cur_beta/beta_scale is the final beta in the optimization.
plt.figure()
ax = plt.gca()
opt.plot2D(True)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
offset = 0.01
flux_size = 0.02

input_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
opt.sim.plot2D()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# opt.sim.run(until=10)
# opt.sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
opt.sim.plot2D()
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.29153e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0634341 s
# time for set_conductivity = 0.00241113 s
# time for set_conductivity = 0.00241518 s
# time for set_conductivity = 0.00240612 s
# time for set_conductivity = 0.00240612 s
# time for set_conductivity = 0.00304794 s
# time for set_conductivity = 0.00241804 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.4254544945358583 / 35.86940732217567 = 0.01186120781741571
# field decay(t = 90.03): 0.22501340405557838 / 35.86940732217567 = 0.006273128575404912
# field decay(t = 120.04): 0.07906441667368752 / 35.86940732217567 = 0.0022042298040650158
# on time step 13807 (time=138.07), 0.000289712 s/step
# field decay(t = 150.05): 0.01981491214380801 / 35.86940732217567 = 0.0005524181641985975
# run 325 finished at t = 150.05 (15005 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# array([80.98403336])

# %%
opt.sim.plot2D(fields=mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
design_variables.weights
# Out:
# array([7.99302058e-09, 2.84086757e-08, 9.09613348e-08, ...,
#        9.09613348e-08, 2.84086757e-08, 7.99302058e-09])

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
80.984 / 17.081
# Out:
# 4.741174404308881

# %%
dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)

# %%
# dft_fields_array: DFT 필드 데이터 (complex 1D array)
N = len(dft_fields_array)
dx = 1.0 / resolution        # 공간 샘플링 간격
k0 = 2 * np.pi * fcen        # 진공 파수

# 1) kx 배열 (rad/unit length)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 각도 계산 (mask 없이)
#    arcsin 안에서 ratio가 ±1을 벗어나면 nan이 되므로,
#    확인용으로는 clip을 사용해 두어도 좋습니다.
theta = np.arcsin(np.clip(kx / k0, -1, 1))  
theta_deg = np.degrees(theta)

# 4) 이론적 전반사 위치 계산
#    (예: 상부 매질 굴절률이 n2, 하부가 n1이라면 θ_crit = arcsin(n2/n1))
theta_c = np.arcsin(1 /2.6)            
kx_cr = k0 * np.sin(theta_c)

# 5) kx_cr 에 가장 가까운 인덱스
idx = np.argmin(np.abs(kx - kx_cr))

print(f"이론적 임계각 θ_crit = {np.degrees(theta_c):.3f}°")
print(f"계산된 θ(kx_cr) = {theta_deg[idx]:.3f}°")

# 6) 전체 패턴 플롯
plt.figure()
plt.plot(theta_deg, np.abs(E_k)**2, 'ro')
# plt.axvline(np.degrees(theta_c), color='k', linestyle='--', label='θ_crit')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.legend()
plt.show()
# Out:
# 이론적 임계각 θ_crit = 22.620°
# 계산된 θ(kx_cr) = 29.308°
# /tmp/ipykernel_64167/2184544693.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) DFT 필드 (complex 1D array)
E = dft_fields_array
N = len(E)
dx = 1.0 / resolution    # 공간 샘플 간격
k0 = 2 * np.pi * fcen    # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

# 4) 세기 계산
I_k = np.abs(E_k)**2

# 5) 모든 데이터 플롯
plt.figure(figsize=(6,4))
plt.plot(kx, I_k, '.-')
plt.xlabel('kx (rad / unit length)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Full k-spectrum (no masking)')
plt.grid(True)
plt.tight_layout()
plt.xlim(-40,40)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# dft_fields_array: 시뮬레이션에서 얻은 DFT 필드 (complex 1D array)
N  = len(dft_fields_array)
dx = 1.0 / resolution      # 공간 샘플링 간격
k0 = 2 * np.pi * fcen      # 진공 파수

# 1) kx 벡터 생성 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 전파 모드(Propagating modes)만 골라내기 (임계각 이내)
mask = np.abs(kx) <= k0

# 4) 각도 변환
theta = np.arcsin(kx[mask] / k0)      # 라디안
theta_deg = np.degrees(theta)         # 도(deg)

# 5) 스펙트럼 세기 계산
I_theta = np.abs(E_k[mask])**2

# 6) 방사각 분포 플롯
plt.figure(figsize=(6,4))
plt.plot(theta_deg, I_theta, '-ro')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Angular Radiation Pattern')
plt.grid(True)
# plt.xlim(-40, 40)
plt.tight_layout()
plt.show()
