# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
import math

from meep.materials import Ag

# %%
lambda_min = 0.4       # 최소 파장 (µm)
lambda_max = 0.7       # 최대 파장 (µm)
fmin = 1/lambda_max    # 최소 주파수
fmax = 1/lambda_min    # 최대 주파수
fcen = 0.5*(fmin+fmax) # 중앙 주파수
df = fmax-fmin         # 주파수 대역폭

resolution = 50        # 시뮬레이션 해상도
nfreq = 1             # 추출할 주파수 개수
design_region_resolution = 50

# %%
tag_bot         = 0.5
tag_side        = 4
tsio2           = 4
tdesignregion   = 1
monitor_position = 1 / fcen
monitor_blank   = 1 / fcen * 0.1

tpml = 0.4

width_ag = 0.2
width_sio2 = 2

width_bot_ag = width_ag+width_sio2+width_ag

design_region_width = round(width_bot_ag, 3)
design_region_height = 1

Sx = tpml+width_bot_ag+tpml
Sy = tag_bot+tag_side+tdesignregion+monitor_position+monitor_blank+tpml

SiO2 = mp.Medium(index = 1.45)
TiO2 = mp.Medium(index = 2.6)

Nx = int(design_region_resolution * design_region_width) + 1
Ny = int(design_region_resolution * design_region_height) + 1

y_bottom = -Sy/2
center_y_ag = y_bottom + tag_bot / 2
center_y_sio2 = y_bottom + tag_bot + tsio2 / 2
center_y_design = y_bottom + tag_bot + tsio2 + design_region_height / 2
center_y_monitor_position = y_bottom + tag_bot + tsio2 + design_region_height + 1/fcen
center_y_source_position = y_bottom + tag_bot + 1/fcen 
center_Ag_x_position = design_region_width/2-width_ag/2 #+ tpml/2

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny), TiO2, SiO2,  grid_type="U_MEAN")

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


boundary_layers = [mp.Absorber(tpml,direction=mp.X),
                   mp.PML(tpml,direction=mp.Y,side=mp.High)]

# %%
cell_size = mp.Vector3(Sx, Sy)
geometry = [
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_bot_ag, tag_bot, 0),
        center=mp.Vector3(0, center_y_ag, 0)
    ),
    mp.Block(
        material=SiO2,
        size=mp.Vector3(width_sio2, tsio2, 0),
        center=mp.Vector3(0, center_y_sio2, 0)
    ),
    mp.Block(
        material=design_variables,
        size=mp.Vector3(design_region_width, design_region_height, 0),
        center=mp.Vector3(0, center_y_design, 0)
    ),

    ######### Side metal ########## 
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(-center_Ag_x_position, center_y_sio2, 0)
    ),
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(center_Ag_x_position, center_y_sio2, 0)
    ),
]

# %%
src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True)

sources = mp.Source(
            src,
            component=mp.Ez,
            center=mp.Vector3(
                0,
                center_y_source_position,  # Alq3 층의 중간 높이
                0
            )
        )


sim = mp.Simulation(
    resolution=resolution,
    sources=[sources],
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    default_material=mp.Medium(index = 1),
    extra_materials=[Ag]
)

# %%
offset = 0.01
flux_size = 0.02

input_flux = sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
# dft_fields = sim.add_dft_fields([mp.Ez], fcen, 0, 1, 
#                                     center = mp.Vector3(0, center_y_monitor_position),
#                                     size = mp.Vector3(2*1/fcen,0,0), 
#                                     yee_gri=True)

# %%
sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# sim.run(until=10)
# sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
sim.plot2D()
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.31538e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.063308 s
# time for set_conductivity = 0.00267577 s
# time for set_conductivity = 0.00213408 s
# time for set_conductivity = 0.0021472 s
# time for set_conductivity = 0.00216198 s
# time for set_conductivity = 0.00216484 s
# time for set_conductivity = 0.00212312 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.6009124373349221 / 35.86940732217567 = 0.01675278411872219
# field decay(t = 90.03): 0.2632202409285167 / 35.86940732217567 = 0.007338293564883776
# field decay(t = 120.04): 0.16244911625938363 / 35.86940732217567 = 0.004528904389199432
# on time step 13414 (time=134.14), 0.000298208 s/step
# field decay(t = 150.05): 0.08156655423702402 / 35.86940732217567 = 0.002273986673501484
# field decay(t = 180.06): 0.03438519580198319 / 35.86940732217567 = 0.0009586217997174743
# run 0 finished at t = 180.06 (18006 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# array([17.0813335])

# %%
sim.plot2D(fields = mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# array([17.0813335])

# %%
minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

def mapping(x, eta, beta):

    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_width,
        design_region_height,
        design_region_resolution,
    )

    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)

    projected_field = (
        npa.fliplr(projected_field) + projected_field
    ) / 2  # up-down symmetry

    # interpolate to actual materials
    return projected_field.flatten()

# %%
monitor_position, monitor_size = mp.Vector3(0, center_y_monitor_position), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=[fcen],
    maximum_run_time=100,
)

np.random.seed(0)
rho_vector = np.random.rand(Nx * Ny)
opt.update_design([mapping(rho_vector, eta_i, 1e3)])

opt.plot2D(True)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append(np.real(f0))

    plt.figure()
    ax = plt.gca()
    opt.plot2D(
        False,
        ax=ax,
        plot_sources_flag=False,
        plot_monitors_flag=False,
        plot_boundaries_flag=False,
    )
    circ = Circle((2, 2), minimum_length / 2)
    ax.add_patch(circ)
    ax.axis("off")
    plt.show()

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %%
evaluation_history = []
cur_iter = [0]
numevl = 0

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0 = []
    dJ_du = []

    global numevl

    f0_i, dJ_du_i = opt([mapping(v, eta_i, beta)])
    
    f0.append(f0_i.flatten())
    dJ_du.append(dJ_du_i)
        
        
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append([np.max(np.real(f0))])

    numevl += 1
    cur_iter[0] = cur_iter[0] + 1

    print("First FoM: {}".format(evaluation_history[0]))
    # print("Current f0 values: " + ", ".join(["f0_{}: {}".format(i, np.real(f0[i])) for i in range(n_dipole)]))

    return np.mean(f0)  # return the sum of the objective function values

# %%
algorithm = nlopt.LD_MMA
n = Nx * Ny  # number of parameters

# Initial guess
x = np.ones((n,)) * 0.5

# lower and upper bounds
lb = np.zeros((Nx * Ny,))
ub = np.ones((Nx * Ny,))

cur_beta = 4
beta_scale = 1.5
num_betas = 8
update_factor = 30
ftol = 1e-8

for iters in range(num_betas):
    solver = nlopt.opt(algorithm, n)
    solver.set_lower_bounds(lb)
    solver.set_upper_bounds(ub)
    solver.set_max_objective(lambda a, g: f(a, g, cur_beta))
    solver.set_maxeval(update_factor)
    solver.set_ftol_rel(ftol)
    x[:] = solver.optimize(x)
    cur_beta = cur_beta * beta_scale
# Out:
# Current iteration: 1
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0596511 s
# time for set_conductivity = 0.00223398 s
# time for set_conductivity = 0.00213504 s
# time for set_conductivity = 0.00207186 s
# time for set_conductivity = 0.00242305 s
# time for set_conductivity = 0.00208902 s
# time for set_conductivity = 0.002069 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 1 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 2 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 2
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057117 s
# time for set_conductivity = 0.00229001 s
# time for set_conductivity = 0.00208092 s
# time for set_conductivity = 0.00254798 s
# time for set_conductivity = 0.00262403 s
# time for set_conductivity = 0.00237584 s
# time for set_conductivity = 0.00234413 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 3 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 4 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 3
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0567589 s
# time for set_conductivity = 0.00207996 s
# time for set_conductivity = 0.0020771 s
# time for set_conductivity = 0.00264406 s
# time for set_conductivity = 0.00217509 s
# time for set_conductivity = 0.0021019 s
# time for set_conductivity = 0.00212502 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 5 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 6 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 4
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0571661 s
# time for set_conductivity = 0.00208712 s
# time for set_conductivity = 0.00253296 s
# time for set_conductivity = 0.00207186 s
# time for set_conductivity = 0.00235295 s
# time for set_conductivity = 0.002074 s
# time for set_conductivity = 0.002074 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 7 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 8 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 5
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.05791 s
# time for set_conductivity = 0.00212789 s
# time for set_conductivity = 0.00216603 s
# time for set_conductivity = 0.00227714 s
# time for set_conductivity = 0.0025661 s
# time for set_conductivity = 0.00205517 s
# time for set_conductivity = 0.00208306 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 9 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 10 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 6
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057621 s
# time for set_conductivity = 0.002074 s
# time for set_conductivity = 0.00209594 s
# time for set_conductivity = 0.00207615 s
# time for set_conductivity = 0.00211096 s
# time for set_conductivity = 0.00209785 s
# time for set_conductivity = 0.00205112 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 11 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 12 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 7
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0575771 s
# time for set_conductivity = 0.0020678 s
# time for set_conductivity = 0.00208688 s
# time for set_conductivity = 0.00284195 s
# time for set_conductivity = 0.00282192 s
# time for set_conductivity = 0.00206804 s
# time for set_conductivity = 0.00211692 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 13 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 14 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 8
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057369 s
# time for set_conductivity = 0.00208092 s
# time for set_conductivity = 0.00207806 s
# time for set_conductivity = 0.00231695 s
# time for set_conductivity = 0.00232387 s
# time for set_conductivity = 0.00261402 s
# time for set_conductivity = 0.00209498 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 15 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 16 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 9
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0568171 s
# time for set_conductivity = 0.0020721 s
# time for set_conductivity = 0.00211596 s
# time for set_conductivity = 0.00208712 s
# time for set_conductivity = 0.002316 s
# time for set_conductivity = 0.00234294 s
# time for set_conductivity = 0.00265598 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 17 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 18 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 10
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0599952 s
# time for set_conductivity = 0.00205779 s
# time for set_conductivity = 0.00267601 s
# time for set_conductivity = 0.00300598 s
# time for set_conductivity = 0.00241208 s
# time for set_conductivity = 0.00205708 s
# time for set_conductivity = 0.00208592 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 19 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 20 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 11
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.50475e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057956 s
# time for set_conductivity = 0.00208712 s
# time for set_conductivity = 0.00212407 s
# time for set_conductivity = 0.00206399 s
# time for set_conductivity = 0.00208211 s
# time for set_conductivity = 0.00208712 s
# time for set_conductivity = 0.00208306 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 21 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 22 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 12
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057544 s
# time for set_conductivity = 0.00259113 s
# time for set_conductivity = 0.0021131 s
# time for set_conductivity = 0.00206113 s
# time for set_conductivity = 0.00207591 s
# time for set_conductivity = 0.00207591 s
# time for set_conductivity = 0.00205493 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 23 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 24 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 13
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058825 s
# time for set_conductivity = 0.00209093 s
# time for set_conductivity = 0.00213194 s
# time for set_conductivity = 0.00211191 s
# time for set_conductivity = 0.00213504 s
# time for set_conductivity = 0.00205803 s
# time for set_conductivity = 0.00209999 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 25 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 26 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 14
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0576031 s
# time for set_conductivity = 0.00214601 s
# time for set_conductivity = 0.00211 s
# time for set_conductivity = 0.00233388 s
# time for set_conductivity = 0.00238395 s
# time for set_conductivity = 0.00235605 s
# time for set_conductivity = 0.00272012 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 27 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 28 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 15
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057426 s
# time for set_conductivity = 0.00210905 s
# time for set_conductivity = 0.00207996 s
# time for set_conductivity = 0.00232792 s
# time for set_conductivity = 0.00240588 s
# time for set_conductivity = 0.00246 s
# time for set_conductivity = 0.00205803 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 29 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 30 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 16
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.50611e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0579479 s
# time for set_conductivity = 0.00265288 s
# time for set_conductivity = 0.00211596 s
# time for set_conductivity = 0.00260496 s
# time for set_conductivity = 0.00262809 s
# time for set_conductivity = 0.00238991 s
# time for set_conductivity = 0.00205803 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 31 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 32 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 17
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0579879 s
# time for set_conductivity = 0.00294018 s
# time for set_conductivity = 0.00212598 s
# time for set_conductivity = 0.00238395 s
# time for set_conductivity = 0.00237203 s
# time for set_conductivity = 0.00258303 s
# time for set_conductivity = 0.00208187 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 33 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 34 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 18
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.19481e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.059258 s
# time for set_conductivity = 0.00214696 s
# time for set_conductivity = 0.00216293 s
# time for set_conductivity = 0.00215697 s
# time for set_conductivity = 0.00252295 s
# time for set_conductivity = 0.00214195 s
# time for set_conductivity = 0.00216603 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 35 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 36 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 19
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057363 s
# time for set_conductivity = 0.00213695 s
# time for set_conductivity = 0.00209618 s
# time for set_conductivity = 0.00211692 s
# time for set_conductivity = 0.00209212 s
# time for set_conductivity = 0.002069 s
# time for set_conductivity = 0.00209594 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 37 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 38 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 20
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058511 s
# time for set_conductivity = 0.0021708 s
# time for set_conductivity = 0.00212502 s
# time for set_conductivity = 0.00213194 s
# time for set_conductivity = 0.00221491 s
# time for set_conductivity = 0.00211 s
# time for set_conductivity = 0.00278401 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 39 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 40 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 21
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0574288 s
# time for set_conductivity = 0.00264096 s
# time for set_conductivity = 0.00263 s
# time for set_conductivity = 0.00229907 s
# time for set_conductivity = 0.00230289 s
# time for set_conductivity = 0.00230098 s
# time for set_conductivity = 0.00255108 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 41 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 42 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 22
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0571671 s
# time for set_conductivity = 0.002074 s
# time for set_conductivity = 0.00238609 s
# time for set_conductivity = 0.00208688 s
# time for set_conductivity = 0.00207996 s
# time for set_conductivity = 0.00205088 s
# time for set_conductivity = 0.00209093 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 43 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 44 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 23
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0569551 s
# time for set_conductivity = 0.00205517 s
# time for set_conductivity = 0.00208282 s
# time for set_conductivity = 0.00216699 s
# time for set_conductivity = 0.00246882 s
# time for set_conductivity = 0.00212908 s
# time for set_conductivity = 0.00216222 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 45 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 46 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 24
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0579681 s
# time for set_conductivity = 0.0021162 s
# time for set_conductivity = 0.00209904 s
# time for set_conductivity = 0.00207996 s
# time for set_conductivity = 0.00211596 s
# time for set_conductivity = 0.00206208 s
# time for set_conductivity = 0.00209498 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 47 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 48 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 25
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057642 s
# time for set_conductivity = 0.00209785 s
# time for set_conductivity = 0.00212598 s
# time for set_conductivity = 0.00208211 s
# time for set_conductivity = 0.00210309 s
# time for set_conductivity = 0.002491 s
# time for set_conductivity = 0.00205994 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 49 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 50 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 26
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0578051 s
# time for set_conductivity = 0.00209594 s
# time for set_conductivity = 0.00210905 s
# time for set_conductivity = 0.00213194 s
# time for set_conductivity = 0.00210094 s
# time for set_conductivity = 0.00211692 s
# time for set_conductivity = 0.00211787 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 51 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 52 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 27
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0580258 s
# time for set_conductivity = 0.0021081 s
# time for set_conductivity = 0.00209498 s
# time for set_conductivity = 0.00211787 s
# time for set_conductivity = 0.0021019 s
# time for set_conductivity = 0.00205398 s
# time for set_conductivity = 0.00208211 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 53 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 54 finished at t = 100.01 (10001 timesteps)
# ...
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0621831 s
# time for set_conductivity = 0.00216198 s
# time for set_conductivity = 0.00214601 s
# time for set_conductivity = 0.0021441 s
# time for set_conductivity = 0.00212193 s
# time for set_conductivity = 0.0020659 s
# time for set_conductivity = 0.00224304 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 463 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 464 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 233
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0641429 s
# time for set_conductivity = 0.00219393 s
# time for set_conductivity = 0.00216103 s
# time for set_conductivity = 0.00209117 s
# time for set_conductivity = 0.00212002 s
# time for set_conductivity = 0.00248098 s
# time for set_conductivity = 0.00208116 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 465 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 466 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 234
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0606492 s
# time for set_conductivity = 0.002177 s
# time for set_conductivity = 0.00220895 s
# time for set_conductivity = 0.00211883 s
# time for set_conductivity = 0.00212908 s
# time for set_conductivity = 0.00214195 s
# time for set_conductivity = 0.0021019 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 467 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 468 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 235
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.60012e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.060411 s
# time for set_conductivity = 0.00214219 s
# time for set_conductivity = 0.00212383 s
# time for set_conductivity = 0.00213695 s
# time for set_conductivity = 0.00209999 s
# time for set_conductivity = 0.00209117 s
# time for set_conductivity = 0.00211883 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 469 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 470 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 236
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 5.81741e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0637271 s
# time for set_conductivity = 0.00217295 s
# time for set_conductivity = 0.00210285 s
# time for set_conductivity = 0.00261903 s
# time for set_conductivity = 0.00212312 s
# time for set_conductivity = 0.00205898 s
# time for set_conductivity = 0.00208187 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 471 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 472 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 237
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0599389 s
# time for set_conductivity = 0.00214005 s
# time for set_conductivity = 0.00213599 s
# time for set_conductivity = 0.00256014 s
# time for set_conductivity = 0.00258589 s
# time for set_conductivity = 0.00214505 s
# time for set_conductivity = 0.00208306 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 473 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 474 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 238
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0598481 s
# time for set_conductivity = 0.00217295 s
# time for set_conductivity = 0.00216198 s
# time for set_conductivity = 0.00215292 s
# time for set_conductivity = 0.00209713 s
# time for set_conductivity = 0.00208902 s
# time for set_conductivity = 0.0021069 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 475 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 476 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 239
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.061553 s
# time for set_conductivity = 0.00215912 s
# time for set_conductivity = 0.00211692 s
# time for set_conductivity = 0.00211191 s
# time for set_conductivity = 0.00212908 s
# time for set_conductivity = 0.00214696 s
# time for set_conductivity = 0.00213289 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 477 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 478 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 240
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.061403 s
# time for set_conductivity = 0.00215602 s
# time for set_conductivity = 0.00211191 s
# time for set_conductivity = 0.00212979 s
# time for set_conductivity = 0.00214195 s
# time for set_conductivity = 0.00207901 s
# time for set_conductivity = 0.00212502 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 479 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 480 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]

# %%
import numpy as np

data = np.loadtxt('Symmetry_apply_80.txt')

print("Loaded array shape:", data.shape)

opt.update_design([data])
# data
# Out:
# Loaded array shape: (6171,)

# %%
# opt.update_design([mapping(x, eta_i, cur_beta/beta_scale)]) # cur_beta/beta_scale is the final beta in the optimization.
plt.figure()
ax = plt.gca()
opt.plot2D(True)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
dft_fields = opt.sim.add_dft_fields([mp.Ez], fcen, 0, 1, 
                                    center = mp.Vector3(0, center_y_monitor_position),
                                    size = mp.Vector3(design_region_width,0,0), 
                                    yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
opt.sim.plot2D()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 6.00815e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057832 s
# time for set_conductivity = 0.00209284 s
# time for set_conductivity = 0.00209999 s
# time for set_conductivity = 0.00218391 s
# time for set_conductivity = 0.00213099 s
# time for set_conductivity = 0.00227904 s
# time for set_conductivity = 0.00258183 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.35256132993859984 / 35.86940732217567 = 0.009829025798277817
# field decay(t = 90.03): 0.18831665746390228 / 35.86940732217567 = 0.005250063257874869
# field decay(t = 120.04): 0.07383784517774826 / 35.86940732217567 = 0.0020585186845866626
# on time step 13291 (time=132.91), 0.000300975 s/step
# field decay(t = 150.05): 0.016366890535066996 / 35.86940732217567 = 0.00045629107802259213
# run 483 finished at t = 150.05 (15005 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
reference_data = np.array([
    9.11790944e-12, 8.22476236e-11, 2.29505758e-10, 4.52910835e-10,
    7.55544068e-10, 1.14161538e-09, 1.61655468e-09, 2.18713133e-09,
    2.86160583e-09, 3.64991880e-09, 4.56392384e-09, 5.61767259e-09,
    6.82776242e-09, 8.21376011e-09, 9.79871794e-09, 1.16098036e-08,
    1.36790704e-08, 1.60444019e-08, 1.87506749e-08, 2.18511957e-08,
    2.54094840e-08, 2.95014963e-08, 3.42184140e-08, 3.96701572e-08,
    4.59898405e-08, 5.33394576e-08, 6.19171838e-08, 7.19668218e-08,
    8.37901138e-08, 9.77629178e-08, 1.14356646e-07, 1.34166938e-07,
    1.57952384e-07, 1.86687387e-07, 2.21635131e-07, 2.64449568e-07,
    3.17319844e-07, 3.83177810e-07, 4.66000896e-07, 5.71261865e-07,
    7.06609463e-07, 8.82920397e-07, 1.11596402e-06, 1.42910512e-06,
    1.85783154e-06, 2.45756992e-06, 3.31780950e-06, 4.58862759e-06,
    6.53351339e-06, 9.64162170e-06, 1.48864614e-05, 2.43893917e-05,
    4.33284559e-05, 8.72513334e-05, 2.19053365e-04, 1.03118818e-03,
    6.62023780e-03, 9.88401273e-04, 1.41300927e-02, 3.64787715e-03,
    1.14737099e-04, 3.64787715e-03, 1.41300927e-02, 9.88401273e-04,
    6.62023780e-03, 1.03118818e-03, 2.19053365e-04, 8.72513334e-05,
    4.33284559e-05, 2.43893917e-05, 1.48864614e-05, 9.64162170e-06,
    6.53351339e-06, 4.58862759e-06, 3.31780950e-06, 2.45756992e-06,
    1.85783154e-06, 1.42910512e-06, 1.11596402e-06, 8.82920397e-07,
    7.06609463e-07, 5.71261865e-07, 4.66000896e-07, 3.83177810e-07,
    3.17319844e-07, 2.64449568e-07, 2.21635131e-07, 1.86687387e-07,
    1.57952384e-07, 1.34166938e-07, 1.14356646e-07, 9.77629178e-08,
    8.37901138e-08, 7.19668218e-08, 6.19171838e-08, 5.33394576e-08,
    4.59898405e-08, 3.96701572e-08, 3.42184140e-08, 2.95014963e-08,
    2.54094840e-08, 2.18511957e-08, 1.87506749e-08, 1.60444019e-08,
    1.36790704e-08, 1.16098036e-08, 9.79871794e-09, 8.21376011e-09,
    6.82776242e-09, 5.61767259e-09, 4.56392384e-09, 3.64991880e-09,
    2.86160583e-09, 2.18713133e-09, 1.61655468e-09, 1.14161538e-09,
    7.55544068e-10, 4.52910835e-10, 2.29505758e-10, 8.22476236e-11,
    9.11790944e-12
])

# %%
data_240 = np.array([5.00145968e-12, 4.51152108e-11, 1.25889491e-10, 2.48429385e-10,
       4.14421701e-10, 6.26171025e-10, 8.86649554e-10, 1.19956233e-09,
       1.56943005e-09, 2.00169216e-09, 2.50283399e-09, 3.08054212e-09,
       3.74389375e-09, 4.50359899e-09, 5.37226159e-09, 6.36466557e-09,
       7.49843654e-09, 8.79416471e-09, 1.02764739e-08, 1.19743907e-08,
       1.39225000e-08, 1.61624777e-08, 1.87437936e-08, 2.17265587e-08,
       2.51834320e-08, 2.92023956e-08, 3.38900033e-08, 3.93793906e-08,
       4.58399960e-08, 5.34693474e-08, 6.25237447e-08, 7.33286473e-08,
       8.62898252e-08, 1.01951158e-07, 1.20965503e-07, 1.44262392e-07,
       1.72984013e-07, 2.08743152e-07, 2.53645745e-07, 3.10647159e-07,
       3.83812967e-07, 4.78975654e-07, 6.04551986e-07, 7.72715019e-07,
       1.00250740e-06, 1.32257202e-06, 1.78004359e-06, 2.45207771e-06,
       3.47447379e-06, 5.09521443e-06, 7.79651397e-06, 1.26586456e-05,
       2.23394769e-05, 4.22391319e-05, 1.46074795e-04, 5.38537379e-04,
       6.17168483e-03, 7.54309602e-03, 2.60140478e-02, 6.43335947e-03,
       4.12743159e-02, 6.43335947e-03, 2.60140478e-02, 7.54309602e-03,
       6.17168483e-03, 5.38537379e-04, 1.46074795e-04, 4.22391319e-05,
       2.23394769e-05, 1.26586456e-05, 7.79651397e-06, 5.09521443e-06,
       3.47447379e-06, 2.45207771e-06, 1.78004359e-06, 1.32257202e-06,
       1.00250740e-06, 7.72715019e-07, 6.04551986e-07, 4.78975654e-07,
       3.83812967e-07, 3.10647159e-07, 2.53645745e-07, 2.08743152e-07,
       1.72984013e-07, 1.44262392e-07, 1.20965503e-07, 1.01951158e-07,
       8.62898252e-08, 7.33286473e-08, 6.25237447e-08, 5.34693474e-08,
       4.58399960e-08, 3.93793906e-08, 3.38900033e-08, 2.92023956e-08,
       2.51834320e-08, 2.17265587e-08, 1.87437936e-08, 1.61624777e-08,
       1.39225000e-08, 1.19743907e-08, 1.02764739e-08, 8.79416471e-09,
       7.49843654e-09, 6.36466557e-09, 5.37226159e-09, 4.50359899e-09,
       3.74389376e-09, 3.08054212e-09, 2.50283399e-09, 2.00169216e-09,
       1.56943005e-09, 1.19956233e-09, 8.86649554e-10, 6.26171025e-10,
       4.14421701e-10, 2.48429385e-10, 1.25889491e-10, 4.51152109e-11,
       5.00145970e-12])

# %%
import numpy as np
import matplotlib.pyplot as plt
dft_fields_array = opt.sim.get_dft_array( dft_fields, mp.Ez, 0)


# 1) DFT 필드 (complex 1D array)
E = dft_fields_array
N = len(E)
dx = 1.0 / resolution    # 공간 샘플 간격
k0 = 2 * np.pi * fcen    # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

angle = np.arcsin(kx/k0)
theta_angle = np.degrees(angle)

mode = kx*(design_region_width/(2*np.pi))
mode

# 4) 세기 계산
I_k = np.abs(E_k)**2

fontlabel = 16

# 5) 모든 데이터 플롯
plt.figure(figsize=(6,6))
plt.plot(mode, reference_data, 'ro--', label='Reference Data')
plt.plot(mode, I_k, 'bo--', label='Symmetry(O) Iter - 80')
plt.plot(mode, data_240, 'go--', label='Symmetry(O) Iter - 240')

plt.xlabel('kx Mode index', fontsize=fontlabel)
plt.ylabel('Flux Intensity', fontsize=fontlabel)
plt.legend(
    loc='upper left',              # 범례 박스의 기준점을 플롯의 왼쪽 상단으로
    bbox_to_anchor=(1.02, 1.0),    # 기준점이 그림(ax)의 (1.02, 1.0) 위치로
    fontsize=fontlabel,
    borderaxespad=0.0
)
# plt.grid(True)
# plt.tight_layout()
plt.xlim(-10,10)
plt.xticks(fontsize=fontlabel)
plt.yticks(fontsize=fontlabel)
plt.show()
# Out:
# /tmp/ipykernel_773/1251623338.py:18: RuntimeWarning: invalid value encountered in arcsin
#   angle = np.arcsin(kx/k0)

# %%
offset = 0.01
flux_size = 0.02

input_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
opt.sim.plot2D()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# opt.sim.run(until=10)
# opt.sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
opt.sim.plot2D()
external_flux = mp.get_fluxes(out_flux)
box_flux = mp.get_fluxes(input_flux)

np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.29018e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0573578 s
# time for set_conductivity = 0.0020802 s
# time for set_conductivity = 0.00209188 s
# time for set_conductivity = 0.00207305 s
# time for set_conductivity = 0.0020709 s
# time for set_conductivity = 0.00266504 s
# time for set_conductivity = 0.00207305 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.5122879946559057 / 35.86940732217567 = 0.014282031204323583
# field decay(t = 90.03): 0.19806803857912006 / 35.86940732217567 = 0.005521921140209857
# field decay(t = 120.04): 0.10033565242910256 / 35.86940732217567 = 0.002797248684035872
# on time step 13847 (time=138.47), 0.000288891 s/step
# field decay(t = 150.05): 0.02640203167383568 / 35.86940732217567 = 0.0007360598806859309
# run 481 finished at t = 150.05 (15005 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# array([58.57464238])

# %%
opt.sim.plot2D(fields=mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
print(np.array(design_variables.weights))
# Out:
# [3.85247390e-14 4.65461003e-13 5.63249447e-12 ... 5.63249447e-12
#  4.65461003e-13 3.85247390e-14]

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
# np.savetxt("Symmetry_apply_240.txt", design_variables.weights)

# %%
plt.figure()

fontlabel = 16

plt.figure(figsize = (6,6))
plt.plot(np.mean(evaluation_history, axis =1), "ob-", )
plt.grid(True)
plt.xlabel("Iteration", fontsize = fontlabel)
plt.ylabel("FOM", fontsize = fontlabel)
plt.xticks(fontsize = fontlabel)
plt.yticks(fontsize = fontlabel)
plt.show()

# %%
plt.figure()

plt.plot(evaluation_history, "o-")
plt.grid(True)
plt.xlabel("Iteration")
plt.ylabel("FOM")
plt.show()

# %%
print(evaluation_history[0])
print(evaluation_history[239])
# Out:
# [0.09519464439557002]
# [0.3554761549985557]

# %%
69.1775 / 17.081 
0.35547/0.0951
# Out:
# 3.7378548895899053

# %%
dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)
#
# NameError: name 'dft_fields' is not defined

# %%
# dft_fields_array: DFT 필드 데이터 (complex 1D array)
N = len(dft_fields_array)
dx = 1.0 / resolution        # 공간 샘플링 간격
k0 = 2 * np.pi * fcen        # 진공 파수

# 1) kx 배열 (rad/unit length)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 각도 계산 (mask 없이)
#    arcsin 안에서 ratio가 ±1을 벗어나면 nan이 되므로,
#    확인용으로는 clip을 사용해 두어도 좋습니다.
theta = np.arcsin(np.clip(kx / k0, -1, 1))  
theta_deg = np.degrees(theta)

# 4) 이론적 전반사 위치 계산
#    (예: 상부 매질 굴절률이 n2, 하부가 n1이라면 θ_crit = arcsin(n2/n1))
theta_c = np.arcsin(1 /2.6)            
kx_cr = k0 * np.sin(theta_c)

# 5) kx_cr 에 가장 가까운 인덱스
idx = np.argmin(np.abs(kx - kx_cr))

print(f"이론적 임계각 θ_crit = {np.degrees(theta_c):.3f}°")
print(f"계산된 θ(kx_cr) = {theta_deg[idx]:.3f}°")

# 6) 전체 패턴 플롯
plt.figure()
plt.plot(theta_deg, np.abs(E_k)**2, 'ro')
# plt.axvline(np.degrees(theta_c), color='k', linestyle='--', label='θ_crit')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.legend()
plt.show()
# Out:
# 이론적 임계각 θ_crit = 22.620°
# 계산된 θ(kx_cr) = 29.308°
# /tmp/ipykernel_64167/2184544693.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) DFT 필드 (complex 1D array)
E = dft_fields_array
N = len(E)
dx = 1.0 / resolution    # 공간 샘플 간격
k0 = 2 * np.pi * fcen    # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

# 4) 세기 계산
I_k = np.abs(E_k)**2

# 5) 모든 데이터 플롯
plt.figure(figsize=(6,4))
plt.plot(kx, I_k, '.-')
plt.xlabel('kx (rad / unit length)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Full k-spectrum (no masking)')
plt.grid(True)
plt.tight_layout()
plt.xlim(-40,40)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# dft_fields_array: 시뮬레이션에서 얻은 DFT 필드 (complex 1D array)
N  = len(dft_fields_array)
dx = 1.0 / resolution      # 공간 샘플링 간격
k0 = 2 * np.pi * fcen      # 진공 파수

# 1) kx 벡터 생성 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 전파 모드(Propagating modes)만 골라내기 (임계각 이내)
mask = np.abs(kx) <= k0

# 4) 각도 변환
theta = np.arcsin(kx[mask] / k0)      # 라디안
theta_deg = np.degrees(theta)         # 도(deg)

# 5) 스펙트럼 세기 계산
I_theta = np.abs(E_k[mask])**2

# 6) 방사각 분포 플롯
plt.figure(figsize=(6,4))
plt.plot(theta_deg, I_theta, '-ro')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Angular Radiation Pattern')
plt.grid(True)
# plt.xlim(-40, 40)
plt.tight_layout()
plt.show()
