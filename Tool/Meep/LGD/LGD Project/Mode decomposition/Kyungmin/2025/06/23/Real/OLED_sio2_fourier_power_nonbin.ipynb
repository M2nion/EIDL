# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
import math

from meep.materials import Ag

# %%
lambda_min = 0.4       # 최소 파장 (µm)
lambda_max = 0.7       # 최대 파장 (µm)
fmin = 1/lambda_max    # 최소 주파수
fmax = 1/lambda_min    # 최대 주파수
fcen = 0.5*(fmin+fmax) # 중앙 주파수
df = fmax-fmin         # 주파수 대역폭

resolution = 50        # 시뮬레이션 해상도
nfreq = 1             # 추출할 주파수 개수
design_region_resolution = 50

# %%
tag_bot         = 0.5
tag_side        = 4
tsio2           = 4
tdesignregion   = 1
monitor_position = 1 / fcen
monitor_blank   = 1 / fcen * 0.1

tpml = 0.4

width_ag = 0.2
width_sio2 = 2

width_bot_ag = width_ag+width_sio2+width_ag

design_region_width = round(width_bot_ag, 3)
design_region_height = 1

Sx = tpml+width_bot_ag+tpml
Sy = tag_bot+tag_side+tdesignregion+monitor_position+monitor_blank+tpml

SiO2 = mp.Medium(index = 1.45)
TiO2 = mp.Medium(index = 2.6)

Nx = int(design_region_resolution * design_region_width) + 1
Ny = int(design_region_resolution * design_region_height) + 1

y_bottom = -Sy/2
center_y_ag = y_bottom + tag_bot / 2
center_y_sio2 = y_bottom + tag_bot + tsio2 / 2
center_y_design = y_bottom + tag_bot + tsio2 + design_region_height / 2
center_y_monitor_position = y_bottom + tag_bot + tsio2 + design_region_height + 1/fcen
center_y_source_position = y_bottom + tag_bot + 1/fcen 
center_Ag_x_position = design_region_width/2-width_ag/2 #+ tpml/2

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny), TiO2, SiO2,  grid_type="U_MEAN")

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


boundary_layers = [mp.Absorber(tpml,direction=mp.X),
                   mp.PML(tpml,direction=mp.Y,side=mp.High)]

# %%
cell_size = mp.Vector3(Sx, Sy)
geometry = [
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_bot_ag, tag_bot, 0),
        center=mp.Vector3(0, center_y_ag, 0)
    ),
    mp.Block(
        material=SiO2,
        size=mp.Vector3(width_sio2, tsio2, 0),
        center=mp.Vector3(0, center_y_sio2, 0)
    ),
    mp.Block(
        material=design_variables,
        size=mp.Vector3(design_region_width, design_region_height, 0),
        center=mp.Vector3(0, center_y_design, 0)
    ),

    ######### Side metal ########## 
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(-center_Ag_x_position, center_y_sio2, 0)
    ),
    mp.Block(
        material=Ag,
        size=mp.Vector3(width_ag, tsio2, 0),
        center=mp.Vector3(center_Ag_x_position, center_y_sio2, 0)
    ),
]

# %%
src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True)

sources = mp.Source(
            src,
            component=mp.Ez,
            center=mp.Vector3(
                0,
                center_y_source_position,  # Alq3 층의 중간 높이
                0
            )
        )


sim = mp.Simulation(
    resolution=resolution,
    sources=[sources],
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry,
    default_material=mp.Medium(index = 1),
    extra_materials=[Ag]
)

# %%
# dft_fields = sim.add_dft_fields([mp.Ez], fcen, 0, 1, 
#                                     center = mp.Vector3(0, center_y_monitor_position),
#                                     size = mp.Vector3(2*1/fcen,0,0), 
#                                     yee_gri=True)

# %%
minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)

def mapping(x, eta, beta):

    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_width,
        design_region_height,
        design_region_resolution,
    )

    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)

    # interpolate to actual materials
    return projected_field.flatten()

# %%
monitor_position, monitor_size = mp.Vector3(0, center_y_monitor_position), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=[fcen],
    maximum_run_time=100,
)

np.random.seed(0)
rho_vector = np.random.rand(Nx * Ny)
opt.update_design([mapping(rho_vector, eta_i, 1e3)])

opt.plot2D(True)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
sim.field

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
evaluation_history = []
cur_iter = [0]
numevl = 0

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0 = []
    dJ_du = []

    global numevl

    f0_i, dJ_du_i = opt([mapping(v, eta_i, beta)])
    
    f0.append(f0_i.flatten())
    dJ_du.append(dJ_du_i)
        
        
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    evaluation_history.append([np.max(np.real(f0))])

    numevl += 1
    cur_iter[0] = cur_iter[0] + 1

    print("First FoM: {}".format(evaluation_history[0]))
    # print("Current f0 values: " + ", ".join(["f0_{}: {}".format(i, np.real(f0[i])) for i in range(n_dipole)]))

    return np.mean(f0)  # return the sum of the objective function values

# %%
evaluation_history = []
cur_iter = [0]
numevl = 0

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0 = []
    dJ_du = []

    global numevl

    f0_i, dJ_du_i = opt([mapping(v, eta_i, beta)])
    
    f0.append(f0_i.flatten())
    dJ_du.append(dJ_du_i)
        
        
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=0)
        )  # backprop

    value = np.max(np.real(f0))
    evaluation_history.append([value])

    numevl += 1
    cur_iter[0] = cur_iter[0] + 1

    print("First FoM: {}".format(evaluation_history[0]))
    # print("Current f0 values: " + ", ".join(["f0_{}: {}".format(i, np.real(f0[i])) for i in range(n_dipole)]))

    return value  # return the sum of the objective function values

# %%
algorithm = nlopt.LD_MMA
n = Nx * Ny  # number of parameters

# Initial guess
x = np.ones((n,)) * 0.5

# lower and upper bounds
lb = np.zeros((Nx * Ny,))
ub = np.ones((Nx * Ny,))

cur_beta = 4
beta_scale = 1.5
num_betas = 8
update_factor = 10
ftol = 1e-5

# %%
for iters in range(num_betas): 
    solver = nlopt.opt(algorithm, n)
    solver.set_lower_bounds(lb)
    solver.set_upper_bounds(ub)
    solver.set_max_objective(lambda a, g: f(a, g, cur_beta))
    solver.set_maxeval(update_factor)
    solver.set_ftol_rel(ftol)
    x[:] = solver.optimize(x)
    cur_beta = cur_beta * beta_scale
# Out:
# Current iteration: 1
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.1008e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0624521 s
# time for set_conductivity = 0.00209904 s
# time for set_conductivity = 0.00209618 s
# time for set_conductivity = 0.00207806 s
# time for set_conductivity = 0.00212097 s
# time for set_conductivity = 0.0026679 s
# time for set_conductivity = 0.00279093 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 0 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 1 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 2
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0595961 s
# time for set_conductivity = 0.002074 s
# time for set_conductivity = 0.00208783 s
# time for set_conductivity = 0.00211215 s
# time for set_conductivity = 0.00208402 s
# time for set_conductivity = 0.00208116 s
# time for set_conductivity = 0.00206614 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 2 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 3 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 3
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057235 s
# time for set_conductivity = 0.00210714 s
# time for set_conductivity = 0.00230002 s
# time for set_conductivity = 0.00212002 s
# time for set_conductivity = 0.00210881 s
# time for set_conductivity = 0.00208521 s
# time for set_conductivity = 0.0021131 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 4 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 5 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 4
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0577152 s
# time for set_conductivity = 0.00210619 s
# time for set_conductivity = 0.00212598 s
# time for set_conductivity = 0.00210214 s
# time for set_conductivity = 0.00224614 s
# time for set_conductivity = 0.00210214 s
# time for set_conductivity = 0.00208211 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 6 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 7 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 5
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057447 s
# time for set_conductivity = 0.00207114 s
# time for set_conductivity = 0.0021081 s
# time for set_conductivity = 0.00218511 s
# time for set_conductivity = 0.00218606 s
# time for set_conductivity = 0.00223994 s
# time for set_conductivity = 0.00211382 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 8 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 9 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 6
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0572238 s
# time for set_conductivity = 0.00209403 s
# time for set_conductivity = 0.00211096 s
# time for set_conductivity = 0.00206494 s
# time for set_conductivity = 0.00209713 s
# time for set_conductivity = 0.00258589 s
# time for set_conductivity = 0.00207496 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 10 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 11 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 7
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058053 s
# time for set_conductivity = 0.00215793 s
# time for set_conductivity = 0.00247312 s
# time for set_conductivity = 0.00269103 s
# time for set_conductivity = 0.00219297 s
# time for set_conductivity = 0.0021131 s
# time for set_conductivity = 0.00209904 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 12 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 13 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 8
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057271 s
# time for set_conductivity = 0.00208497 s
# time for set_conductivity = 0.00208712 s
# time for set_conductivity = 0.00211596 s
# time for set_conductivity = 0.00210404 s
# time for set_conductivity = 0.00206804 s
# time for set_conductivity = 0.00211716 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 14 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 15 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 9
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0576069 s
# time for set_conductivity = 0.00213003 s
# time for set_conductivity = 0.00268793 s
# time for set_conductivity = 0.00290298 s
# time for set_conductivity = 0.00233197 s
# time for set_conductivity = 0.0023191 s
# time for set_conductivity = 0.00207996 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 16 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 17 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 10
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0579119 s
# time for set_conductivity = 0.0021441 s
# time for set_conductivity = 0.00211 s
# time for set_conductivity = 0.00267196 s
# time for set_conductivity = 0.00213599 s
# time for set_conductivity = 0.00266314 s
# time for set_conductivity = 0.00208783 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 18 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 19 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 11
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0574939 s
# time for set_conductivity = 0.00209808 s
# time for set_conductivity = 0.0021131 s
# time for set_conductivity = 0.00235796 s
# time for set_conductivity = 0.00236607 s
# time for set_conductivity = 0.00238419 s
# time for set_conductivity = 0.00206494 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 20 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 21 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 12
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.059164 s
# time for set_conductivity = 0.00213194 s
# time for set_conductivity = 0.00219107 s
# time for set_conductivity = 0.00212717 s
# time for set_conductivity = 0.00218701 s
# time for set_conductivity = 0.00216317 s
# time for set_conductivity = 0.00212622 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 22 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 23 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 13
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058054 s
# time for set_conductivity = 0.00213099 s
# time for set_conductivity = 0.00208521 s
# time for set_conductivity = 0.00238109 s
# time for set_conductivity = 0.00237608 s
# time for set_conductivity = 0.00250196 s
# time for set_conductivity = 0.00210786 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 24 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 25 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 14
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0573251 s
# time for set_conductivity = 0.00207996 s
# time for set_conductivity = 0.00210404 s
# time for set_conductivity = 0.00209093 s
# time for set_conductivity = 0.00212812 s
# time for set_conductivity = 0.00210118 s
# time for set_conductivity = 0.00208402 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 26 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 27 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 15
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057374 s
# time for set_conductivity = 0.00209999 s
# time for set_conductivity = 0.00208211 s
# time for set_conductivity = 0.00255203 s
# time for set_conductivity = 0.00217485 s
# time for set_conductivity = 0.00207114 s
# time for set_conductivity = 0.00221777 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 28 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 29 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 16
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0583339 s
# time for set_conductivity = 0.00213003 s
# time for set_conductivity = 0.00215483 s
# time for set_conductivity = 0.00234389 s
# time for set_conductivity = 0.0023911 s
# time for set_conductivity = 0.00211596 s
# time for set_conductivity = 0.00214791 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 30 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 31 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 17
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0570822 s
# time for set_conductivity = 0.00247502 s
# time for set_conductivity = 0.00214601 s
# time for set_conductivity = 0.00207591 s
# time for set_conductivity = 0.0020709 s
# time for set_conductivity = 0.00209904 s
# time for set_conductivity = 0.00206685 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 32 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 33 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 18
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0574441 s
# time for set_conductivity = 0.00208998 s
# time for set_conductivity = 0.00210118 s
# time for set_conductivity = 0.00218916 s
# time for set_conductivity = 0.00214601 s
# time for set_conductivity = 0.00276685 s
# time for set_conductivity = 0.0021131 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 34 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 35 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 19
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0575731 s
# time for set_conductivity = 0.00208092 s
# time for set_conductivity = 0.00209808 s
# time for set_conductivity = 0.00227618 s
# time for set_conductivity = 0.0022769 s
# time for set_conductivity = 0.00223994 s
# time for set_conductivity = 0.00208521 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 36 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 37 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 20
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0581141 s
# time for set_conductivity = 0.00277615 s
# time for set_conductivity = 0.00208092 s
# time for set_conductivity = 0.00276184 s
# time for set_conductivity = 0.00238895 s
# time for set_conductivity = 0.00233793 s
# time for set_conductivity = 0.0023241 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 38 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 39 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 21
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0581341 s
# time for set_conductivity = 0.00205994 s
# time for set_conductivity = 0.00208211 s
# time for set_conductivity = 0.00212121 s
# time for set_conductivity = 0.00210404 s
# time for set_conductivity = 0.00243115 s
# time for set_conductivity = 0.00211096 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 40 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 41 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 22
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0579901 s
# time for set_conductivity = 0.00212288 s
# time for set_conductivity = 0.00213003 s
# time for set_conductivity = 0.00232196 s
# time for set_conductivity = 0.00235105 s
# time for set_conductivity = 0.00231004 s
# time for set_conductivity = 0.00234008 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 42 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 43 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 23
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.058367 s
# time for set_conductivity = 0.00209308 s
# time for set_conductivity = 0.00211096 s
# time for set_conductivity = 0.00229478 s
# time for set_conductivity = 0.00239396 s
# time for set_conductivity = 0.00255203 s
# time for set_conductivity = 0.00208592 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 44 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 45 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 24
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0576 s
# time for set_conductivity = 0.00208092 s
# time for set_conductivity = 0.00212693 s
# time for set_conductivity = 0.00216007 s
# time for set_conductivity = 0.00220823 s
# time for set_conductivity = 0.00218415 s
# time for set_conductivity = 0.00208902 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 46 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 47 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 25
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0574849 s
# time for set_conductivity = 0.0020771 s
# time for set_conductivity = 0.00212693 s
# time for set_conductivity = 0.00208592 s
# time for set_conductivity = 0.00208306 s
# time for set_conductivity = 0.00209308 s
# time for set_conductivity = 0.0020659 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 48 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 49 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 26
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0577531 s
# time for set_conductivity = 0.00207019 s
# time for set_conductivity = 0.00212812 s
# time for set_conductivity = 0.00233388 s
# time for set_conductivity = 0.00234103 s
# time for set_conductivity = 0.00232911 s
# time for set_conductivity = 0.00277996 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 50 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 51 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 27
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057735 s
# time for set_conductivity = 0.00209022 s
# time for set_conductivity = 0.00213289 s
# time for set_conductivity = 0.00210285 s
# time for set_conductivity = 0.0021019 s
# time for set_conductivity = 0.00215101 s
# time for set_conductivity = 0.00209999 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 52 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# ...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057651 s
# time for set_conductivity = 0.00209594 s
# time for set_conductivity = 0.00215101 s
# time for set_conductivity = 0.00242996 s
# time for set_conductivity = 0.00240898 s
# time for set_conductivity = 0.002388 s
# time for set_conductivity = 0.00213003 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 142 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 143 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 73
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.065063 s
# time for set_conductivity = 0.00215101 s
# time for set_conductivity = 0.00216603 s
# time for set_conductivity = 0.00212097 s
# time for set_conductivity = 0.00212598 s
# time for set_conductivity = 0.00208688 s
# time for set_conductivity = 0.00215483 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 144 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 145 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 74
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0577819 s
# time for set_conductivity = 0.0020709 s
# time for set_conductivity = 0.0021379 s
# time for set_conductivity = 0.00214791 s
# time for set_conductivity = 0.00218391 s
# time for set_conductivity = 0.00210714 s
# time for set_conductivity = 0.00209188 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 146 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 147 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 75
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0578051 s
# time for set_conductivity = 0.00210905 s
# time for set_conductivity = 0.00210881 s
# time for set_conductivity = 0.00207996 s
# time for set_conductivity = 0.00211096 s
# time for set_conductivity = 0.00205898 s
# time for set_conductivity = 0.00229383 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 148 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 149 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 76
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0576489 s
# time for set_conductivity = 0.00209808 s
# time for set_conductivity = 0.00209808 s
# time for set_conductivity = 0.00256395 s
# time for set_conductivity = 0.00244594 s
# time for set_conductivity = 0.002352 s
# time for set_conductivity = 0.00232196 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 150 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 151 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 77
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.057363 s
# time for set_conductivity = 0.00209308 s
# time for set_conductivity = 0.00207901 s
# time for set_conductivity = 0.00261903 s
# time for set_conductivity = 0.00240397 s
# time for set_conductivity = 0.00234699 s
# time for set_conductivity = 0.00206709 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 152 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 153 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 78
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0574009 s
# time for set_conductivity = 0.00209785 s
# time for set_conductivity = 0.00209713 s
# time for set_conductivity = 0.00211406 s
# time for set_conductivity = 0.00207806 s
# time for set_conductivity = 0.00207996 s
# time for set_conductivity = 0.00211287 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 154 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 155 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 79
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.05761 s
# time for set_conductivity = 0.00271893 s
# time for set_conductivity = 0.00214314 s
# time for set_conductivity = 0.00256681 s
# time for set_conductivity = 0.00209999 s
# time for set_conductivity = 0.00213099 s
# time for set_conductivity = 0.00207615 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 156 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 157 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]
# Current iteration: 80
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0595291 s
# time for set_conductivity = 0.00209498 s
# time for set_conductivity = 0.00213003 s
# time for set_conductivity = 0.00208211 s
# time for set_conductivity = 0.00232482 s
# time for set_conductivity = 0.00208402 s
# time for set_conductivity = 0.00209713 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# run 158 finished at t = 100.01 (10001 timesteps)
# Starting adjoint run...
# run 159 finished at t = 100.01 (10001 timesteps)
# Calculating gradient...
# First FoM: [0.09519464439557002]

# %%
# np.savetxt("No-Symmetry_80.txt", design_variables.weights)

# %%
import numpy as np

data = np.loadtxt('No-Symmetry_240.txt')

print("Loaded array shape:", data.shape)

opt.update_design([data])
# Out:
# Loaded array shape: (6171,)

# %%
design_variables.weights
# Out:
# array([8.07598895e-02, 1.07132060e-01, 1.43897280e-01, ...,
#        1.36019851e-07, 2.67490158e-08, 4.60443350e-09])

# %%
# opt.update_design([mapping(x, eta_i, cur_beta/beta_scale)]) # cur_beta/beta_scale is the final beta in the optimization.
plt.figure()
ax = plt.gca()
opt.plot2D(True)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
offset = 0.01
flux_size = 0.02

input_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(center=sources.center - mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(offset, 0, 0),
                    size=mp.Vector3(0, flux_size),
                    # direction=mp.X
                    ),
        mp.FluxRegion(center=sources.center - mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y, 
                    weight=-1),
        mp.FluxRegion(center=sources.center + mp.Vector3(0, offset, 0),
                    size=mp.Vector3(flux_size, 0),
                    # direction=mp.Y
                    )
    )

out_flux = opt.sim.add_flux(
        fcen, 0, 1,
        mp.FluxRegion(
            center=mp.Vector3(0, center_y_monitor_position),
                    size=mp.Vector3(2*1/fcen,0,0),
                    # direction=mp.Y
                    )
    )

# %%
opt.sim.plot2D()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
dft_fields = opt.sim.add_dft_fields([mp.Ez], fcen, 0, 1, 
                                    center = mp.Vector3(0, center_y_monitor_position),
                                    size = mp.Vector3(design_region_width,0,0), 
                                    yee_grid=True)

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(30, mp.Ez, sources.center, 1e-3))
# opt.sim.run(until=10)
# opt.sim.plot2D(output_plane=mp.Volume(center = sources.center, size = mp.Vector3(0.1,0.1)))
opt.sim.plot2D()
# external_flux = mp.get_fluxes(out_flux)
# box_flux = mp.get_fluxes(input_flux)

# np.array(external_flux) / np.array(box_flux) * 100
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.79086e-05 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 6.46 x 0 with resolution 50
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0633891 s
# time for set_conductivity = 0.00217986 s
# time for set_conductivity = 0.00215816 s
# time for set_conductivity = 0.00208688 s
# time for set_conductivity = 0.00205994 s
# time for set_conductivity = 0.002105 s
# time for set_conductivity = 0.00214815 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# field decay(t = 30.01): 35.86940732217567 / 35.86940732217567 = 1.0
# field decay(t = 60.02): 0.26530136696407874 / 35.86940732217567 = 0.007396313091575967
# field decay(t = 90.03): 0.17533971880246385 / 35.86940732217567 = 0.004888280345074533
# on time step 11619 (time=116.19), 0.000344269 s/step
# field decay(t = 120.04): 0.05938482685654864 / 35.86940732217567 = 0.0016555842789137737
# field decay(t = 150.05): 0.01227310526612578 / 35.86940732217567 = 0.0003421608044953153
# run 161 finished at t = 150.05 (15005 timesteps)
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
reference_data = np.array([
    9.11790944e-12, 8.22476236e-11, 2.29505758e-10, 4.52910835e-10,
    7.55544068e-10, 1.14161538e-09, 1.61655468e-09, 2.18713133e-09,
    2.86160583e-09, 3.64991880e-09, 4.56392384e-09, 5.61767259e-09,
    6.82776242e-09, 8.21376011e-09, 9.79871794e-09, 1.16098036e-08,
    1.36790704e-08, 1.60444019e-08, 1.87506749e-08, 2.18511957e-08,
    2.54094840e-08, 2.95014963e-08, 3.42184140e-08, 3.96701572e-08,
    4.59898405e-08, 5.33394576e-08, 6.19171838e-08, 7.19668218e-08,
    8.37901138e-08, 9.77629178e-08, 1.14356646e-07, 1.34166938e-07,
    1.57952384e-07, 1.86687387e-07, 2.21635131e-07, 2.64449568e-07,
    3.17319844e-07, 3.83177810e-07, 4.66000896e-07, 5.71261865e-07,
    7.06609463e-07, 8.82920397e-07, 1.11596402e-06, 1.42910512e-06,
    1.85783154e-06, 2.45756992e-06, 3.31780950e-06, 4.58862759e-06,
    6.53351339e-06, 9.64162170e-06, 1.48864614e-05, 2.43893917e-05,
    4.33284559e-05, 8.72513334e-05, 2.19053365e-04, 1.03118818e-03,
    6.62023780e-03, 9.88401273e-04, 1.41300927e-02, 3.64787715e-03,
    1.14737099e-04, 3.64787715e-03, 1.41300927e-02, 9.88401273e-04,
    6.62023780e-03, 1.03118818e-03, 2.19053365e-04, 8.72513334e-05,
    4.33284559e-05, 2.43893917e-05, 1.48864614e-05, 9.64162170e-06,
    6.53351339e-06, 4.58862759e-06, 3.31780950e-06, 2.45756992e-06,
    1.85783154e-06, 1.42910512e-06, 1.11596402e-06, 8.82920397e-07,
    7.06609463e-07, 5.71261865e-07, 4.66000896e-07, 3.83177810e-07,
    3.17319844e-07, 2.64449568e-07, 2.21635131e-07, 1.86687387e-07,
    1.57952384e-07, 1.34166938e-07, 1.14356646e-07, 9.77629178e-08,
    8.37901138e-08, 7.19668218e-08, 6.19171838e-08, 5.33394576e-08,
    4.59898405e-08, 3.96701572e-08, 3.42184140e-08, 2.95014963e-08,
    2.54094840e-08, 2.18511957e-08, 1.87506749e-08, 1.60444019e-08,
    1.36790704e-08, 1.16098036e-08, 9.79871794e-09, 8.21376011e-09,
    6.82776242e-09, 5.61767259e-09, 4.56392384e-09, 3.64991880e-09,
    2.86160583e-09, 2.18713133e-09, 1.61655468e-09, 1.14161538e-09,
    7.55544068e-10, 4.52910835e-10, 2.29505758e-10, 8.22476236e-11,
    9.11790944e-12
])

# %%
data_80 = np.array([3.65298145e-12, 3.29514792e-11, 9.19483382e-11, 1.81451730e-10,
       3.02695291e-10, 4.57364528e-10, 6.47633333e-10, 8.76211778e-10,
       1.14640679e-09, 1.46219772e-09, 1.82832953e-09, 2.25042672e-09,
       2.73513247e-09, 3.29027790e-09, 3.92508860e-09, 4.65043790e-09,
       5.47914215e-09, 6.42636413e-09, 7.51007849e-09, 8.75155692e-09,
       1.01762614e-08, 1.18145431e-08, 1.37028547e-08, 1.58851346e-08,
       1.84143311e-08, 2.13552166e-08, 2.47899911e-08, 2.88154056e-08,
       3.35387425e-08, 3.91304285e-08, 4.57682808e-08, 5.36940479e-08,
       6.32066480e-08, 7.46896066e-08, 8.86674862e-08, 1.05771645e-07,
       1.26903612e-07, 1.53208434e-07, 1.86290149e-07, 2.28317287e-07,
       2.82349824e-07, 3.52708333e-07, 4.45669402e-07, 5.70587177e-07,
       7.41611242e-07, 9.80709388e-07, 1.32393374e-06, 1.83115847e-06,
       2.60868095e-06, 3.85542471e-06, 5.97227186e-06, 9.84244962e-06,
       1.78719056e-05, 3.73851277e-05, 1.27829490e-04, 2.63042733e-03,
       3.12983160e-02, 9.01713595e-03, 2.10379460e-03, 1.13932864e-02,
       4.65599470e-03, 1.13932864e-02, 2.10379460e-03, 9.01713595e-03,
       3.12983160e-02, 2.63042733e-03, 1.27829490e-04, 3.73851277e-05,
       1.78719056e-05, 9.84244962e-06, 5.97227186e-06, 3.85542471e-06,
       2.60868095e-06, 1.83115847e-06, 1.32393374e-06, 9.80709387e-07,
       7.41611242e-07, 5.70587176e-07, 4.45669402e-07, 3.52708332e-07,
       2.82349824e-07, 2.28317287e-07, 1.86290149e-07, 1.53208434e-07,
       1.26903612e-07, 1.05771645e-07, 8.86674861e-08, 7.46896065e-08,
       6.32066479e-08, 5.36940478e-08, 4.57682807e-08, 3.91304285e-08,
       3.35387424e-08, 2.88154056e-08, 2.47899911e-08, 2.13552166e-08,
       1.84143311e-08, 1.58851346e-08, 1.37028547e-08, 1.18145430e-08,
       1.01762614e-08, 8.75155691e-09, 7.51007848e-09, 6.42636412e-09,
       5.47914214e-09, 4.65043789e-09, 3.92508859e-09, 3.29027789e-09,
       2.73513246e-09, 2.25042671e-09, 1.82832952e-09, 1.46219772e-09,
       1.14640678e-09, 8.76211774e-10, 6.47633329e-10, 4.57364525e-10,
       3.02695289e-10, 1.81451729e-10, 9.19483370e-11, 3.29514785e-11,
       3.65298121e-12])

# %%
dft_fields_array = opt.sim.get_dft_array( dft_fields, mp.Ez, 0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 추가할 어레이


# 1) DFT 필드 (complex 1D array)
E = dft_fields_array
N = len(E)
dx = 1.0 / resolution    # 공간 샘플 간격
k0 = 2 * np.pi * fcen    # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

# 모드 인덱스 계산
mode = kx * (design_region_width / (2 * np.pi))

# 4) 세기 계산
I_k = np.abs(E_k)**2

fontlabel = 16

# 5) 모든 데이터 플롯
plt.figure(figsize=(6,6))
plt.plot(mode, reference_data, 'ro-', label='Reference Data')

plt.plot(mode, data_80, 'bo--', label='Symmetry(x) Iter - 80')
plt.plot(mode, I_k, 'go--', label='Symmetry(x) Iter - 240')
plt.xlabel('kx Mode index', fontsize=fontlabel)
plt.ylabel('Flux Intensity', fontsize=fontlabel)
plt.legend(
    loc='upper left',              # 범례 박스의 기준점을 플롯의 왼쪽 상단으로
    bbox_to_anchor=(1.02, 1.0),    # 기준점이 그림(ax)의 (1.02, 1.0) 위치로
    fontsize=fontlabel,
    borderaxespad=0.0
)
# plt.grid(True)
# plt.tight_layout()
plt.xlim(-10,10)
plt.xticks(fontsize=fontlabel)
plt.yticks(fontsize=fontlabel)
plt.show()

# %%
dft_fields_array = opt.sim.get_dft_array( dft_fields, mp.Ez, 0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) DFT 필드 (complex 1D array)
E  = dft_fields_array
N  = len(E)
dx = 1.0 / resolution      # 공간 샘플 간격
k0 = 2 * np.pi * fcen      # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

# 4) 스펙트럼 세기
I_k = np.abs(E_k)**2

# 5) 각도 변환 (클립 없이)
theta = np.arcsin(kx / k0)       # 라디안
theta_deg = np.degrees(theta)    # 도 단위

# 6) 전파 모드(실수 θ)만 골라내기
mask = np.isfinite(theta_deg)    # |kx|>k0 구간은 nan → False

# 7) 플롯
plt.figure(figsize=(6,4))
plt.plot(theta_deg[mask], I_k[mask], 'bo-')
plt.xlabel('Emission Angle θ (deg)', fontsize=16)
plt.ylabel('Spectral Intensity |E(kx)|²', fontsize=16)
plt.title('Angular Radiation Pattern', fontsize=16)
plt.xlim(-90,90)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2037/2535843175.py:20: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(kx / k0)       # 라디안

# %%
opt.sim.plot2D(fields=mp.Ez)
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
design_variables.weights
# Out:
# array([0.98033587, 0.97086509, 0.95658413, ..., 0.0109474 , 0.00993721,
#        0.00855179])

# %%
opt.plot2D(True, output_plane=mp.Volume(
        center=mp.Vector3(0, center_y_design, 0),
        size=mp.Vector3(design_region_width, design_region_height, 0),))
circ = Circle((2, 2), minimum_length / 2)

plt.axis("off")
plt.show()
# Out:
#      block, center = (0,-2.98,0)
#           size (2.4,0.5,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.73,0)
#           size (2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1025,2.1025,2.1025)
#      block, center = (0,1.77,0)
#           size (2.4,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.1,-0.73,0)
#           size (0.2,4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
84.753 / 17.081
# Out:
# 4.961828932732276

# %%
np.savetxt("No-Symmetry.txt", design_variables.weights)

# %%
np.array(evaluation_history[0]) / np.array(evaluation_history[79]) 
np.array(evaluation_history[0])
# Out:
# array([0.09519464])

# %%
np.array(evaluation_history[79])
# Out:
# array([0.74660827])

# %%
plt.figure()

fontlabel = 16

plt.figure(figsize = (6,6))
plt.plot(np.mean(evaluation_history, axis =1), "ob-", )
plt.grid(True)
plt.xlabel("Iteration", fontsize = fontlabel)
plt.ylabel("FOM", fontsize = fontlabel)
plt.xticks(fontsize = fontlabel)
plt.yticks(fontsize = fontlabel)
plt.show()

# %%
evaluation_history[0]
# Out:
# [0.09519464439557002]

# %%
plt.figure()

plt.plot(evaluation_history, "o-")
plt.grid(True)
plt.xlabel("Iteration")
plt.ylabel("FOM")
plt.show()
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dft_fields_array = sim.get_dft_array( dft_fields, mp.Ez, 0)
#
# NameError: name 'dft_fields' is not defined

# %%
# dft_fields_array: DFT 필드 데이터 (complex 1D array)
N = len(dft_fields_array)
dx = 1.0 / resolution        # 공간 샘플링 간격
k0 = 2 * np.pi * fcen        # 진공 파수

# 1) kx 배열 (rad/unit length)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 각도 계산 (mask 없이)
#    arcsin 안에서 ratio가 ±1을 벗어나면 nan이 되므로,
#    확인용으로는 clip을 사용해 두어도 좋습니다.
theta = np.arcsin(np.clip(kx / k0, -1, 1))  
theta_deg = np.degrees(theta)

# 4) 이론적 전반사 위치 계산
#    (예: 상부 매질 굴절률이 n2, 하부가 n1이라면 θ_crit = arcsin(n2/n1))
theta_c = np.arcsin(1 /2.6)            
kx_cr = k0 * np.sin(theta_c)

# 5) kx_cr 에 가장 가까운 인덱스
idx = np.argmin(np.abs(kx - kx_cr))

print(f"이론적 임계각 θ_crit = {np.degrees(theta_c):.3f}°")
print(f"계산된 θ(kx_cr) = {theta_deg[idx]:.3f}°")

# 6) 전체 패턴 플롯
plt.figure()
plt.plot(theta_deg, np.abs(E_k)**2, 'ro')
# plt.axvline(np.degrees(theta_c), color='k', linestyle='--', label='θ_crit')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.legend()
plt.show()
# Out:
# 이론적 임계각 θ_crit = 22.620°
# 계산된 θ(kx_cr) = 29.308°
# /tmp/ipykernel_64167/2184544693.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) DFT 필드 (complex 1D array)
E = dft_fields_array
N = len(E)
dx = 1.0 / resolution    # 공간 샘플 간격
k0 = 2 * np.pi * fcen    # 진공 파수

# 2) kx 벡터 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 3) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(E)) / N

# 4) 세기 계산
I_k = np.abs(E_k)**2

# 5) 모든 데이터 플롯
plt.figure(figsize=(6,4))
plt.plot(kx, I_k, '.-')
plt.xlabel('kx (rad / unit length)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Full k-spectrum (no masking)')
plt.grid(True)
plt.tight_layout()
plt.xlim(-40,40)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# dft_fields_array: 시뮬레이션에서 얻은 DFT 필드 (complex 1D array)
N  = len(dft_fields_array)
dx = 1.0 / resolution      # 공간 샘플링 간격
k0 = 2 * np.pi * fcen      # 진공 파수

# 1) kx 벡터 생성 (rad/unit 길이)
kx = 2 * np.pi * np.fft.fftshift(np.fft.fftfreq(N, d=dx))

# 2) 공간 FFT → E(kx)
E_k = np.fft.fftshift(np.fft.fft(dft_fields_array)) / N

# 3) 전파 모드(Propagating modes)만 골라내기 (임계각 이내)
mask = np.abs(kx) <= k0

# 4) 각도 변환
theta = np.arcsin(kx[mask] / k0)      # 라디안
theta_deg = np.degrees(theta)         # 도(deg)

# 5) 스펙트럼 세기 계산
I_theta = np.abs(E_k[mask])**2

# 6) 방사각 분포 플롯
plt.figure(figsize=(6,4))
plt.plot(theta_deg, I_theta, '-ro')
plt.xlabel('Emission Angle θ (deg)')
plt.ylabel('Spectral Intensity |E(kx)|²')
plt.title('Angular Radiation Pattern')
plt.grid(True)
# plt.xlim(-40, 40)
plt.tight_layout()
plt.show()
