# %%
import meep as mp
import matplotlib.pyplot as plt
import nlopt
import numpy as np
import pickle
from meep_material import lorentzfit
import os

# %%
import numpy as np
import meep as mp
import nlopt
from typing import Tuple

# lorentzfit 함수는 이미 정의되어 있어야 함 (여기선 너가 가지고 있다고 가정함)

def fit_material_from_csv(
    csv_path: str,
    wl_range_nm = [0.38, 0.72],
    eps_inf: float = 1.1,
    num_lorentzians: int = 3,
    num_repeat: int = 100,
    opt_tol: float = 1e-25,
    maxeval: int = 50000,
) -> mp.Medium:
    # --- 0) 피클 경로 설정 ---
    base, _ = os.path.splitext(csv_path)
    pickle_path = base + "_fit.pkl"

    # --- 1) 피클이 있으면 로드 후 반환 ---
    if os.path.exists(pickle_path):
        with open(pickle_path, "rb") as f:
            eps_inf, E_sus, freq_range = pickle.load(f)
        print(f"Loaded fit from pickle: {pickle_path}")
        return eps_inf, E_sus, freq_range
    
    # 데이터 불러오기
    mydata = np.genfromtxt(csv_path, delimiter=",")
    wl = mydata[:, 0]  # um
    n_complex = mydata[:, 1] + 1j * mydata[:, 2]
    eps_data = np.square(n_complex) - eps_inf  # 유전율에서 eps_inf 보정

    # 파장 범위 필터링
    wl_min, wl_max = wl_range_nm
    idx_start = np.where(wl > wl_min)[0][0]
    idx_end = np.where(wl < wl_max)[0][-1] + 1
    wl_reduced = wl[idx_start:idx_end]
    eps_reduced = eps_data[idx_start:idx_end]
    freqs_reduced = 1 / wl_reduced  # nm → 1/μm (Meep 단위)

    # 최적화 반복
    ps = np.zeros((num_repeat, 3 * num_lorentzians))
    mins = np.zeros(num_repeat)

    for m in range(num_repeat):
        p_rand = [10 ** (np.random.random()) for _ in range(3 * num_lorentzians)]
        ps[m, :], mins[m] = lorentzfit(
            p_rand, freqs_reduced, eps_reduced, nlopt.LD_MMA, opt_tol, maxeval
        )
        print(f"[{m:2d}] RMS error: {mins[m]:.6e} — params: {ps[m, :]}")

    # 최적 피팅 결과 선택
    idx_opt = np.argmin(mins)
    popt = ps[idx_opt, :]
    print(f"\n>> Best fit RMS error = {mins[idx_opt]:.6e}")
    print(f">> Optimal parameters = {popt}")

    # mp.Medium 구성
    E_sus = []

    for i in range(num_lorentzians):
        sigma = popt[3 * i + 0]
        freq = popt[3 * i + 1]
        gamma = popt[3 * i + 2]

        if freq == 0:
            # Drude 항
            E_sus.append(mp.DrudeSusceptibility(frequency=1.0, gamma=gamma, sigma=sigma))
        else:
            # Lorentz 항
            sigma_adj = sigma / freq**2
            E_sus.append(mp.LorentzianSusceptibility(frequency=freq, gamma=gamma, sigma=sigma_adj))

    # 유효 주파수 범위 설정
    freq_min = 1 / wl_max
    freq_max = 1 / wl_min
    freq_range = mp.FreqRange(min=freq_min, max=freq_max)

    # --- 6) 결과를 피클로 저장 ---
    with open(pickle_path, "wb") as f:
        pickle.dump((eps_inf, E_sus, freq_range), f)

    return eps_inf, E_sus, freq_range

sio2_data_path = "/home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/New fitting/Refractive Index data/Sio2/Material_merged.csv"
al_data_path   = "/home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/New fitting/Refractive Index data/Al/mat/Material_merged.csv"
andp_data_path = "/home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/New fitting/Refractive Index data/aNDP/Material_merged.csv"

# %%
eps_inf_sio2, suscept_sio2, freq_sio2 = fit_material_from_csv(csv_path=sio2_data_path, num_lorentzians=2,)#  wl_range_nm = [0.38, 0.72])
eps_inf_al, suscept_al, freq_al = fit_material_from_csv(csv_path=al_data_path, num_lorentzians=7)
eps_inf_andp, suscept_andp, freq_andp = fit_material_from_csv(csv_path=andp_data_path, num_lorentzians=5,)#  wl_range_nm = [0.4, 0.7])
# Out:
# Loaded fit from pickle: /home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/New fitting/Refractive Index data/Sio2/Material_merged_fit.pkl
# Loaded fit from pickle: /home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/New fitting/Refractive Index data/Al/mat/Material_merged_fit.pkl
# Loaded fit from pickle: /home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/New fitting/Refractive Index data/aNDP/Material_merged_fit.pkl

# %%
sio2 =  mp.Medium(epsilon = eps_inf_sio2,   E_susceptibilities = suscept_sio2, valid_freq_range=freq_sio2) # SiO2 ,
andp =  mp.Medium(epsilon = eps_inf_andp,   E_susceptibilities = suscept_andp, valid_freq_range=freq_andp) # aNDP ,
Al  =   mp.Medium(epsilon = eps_inf_al,     E_susceptibilities = suscept_al, valid_freq_range=freq_al)

# %%
resolution = 100
nfreq = 300
fcen = 1.75
df = 3.3

# %% [markdown]
# # Air simulation

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import csv

# === 설정 ===
cell_size = mp.Vector3(3, 3, 0)
resolution =100
nfreq = 300
fcen = 1.75
df = 3.3

field_component = mp.Ex

lambda_min = 0.4
lambda_max = 0.7
fmin = 1 / lambda_max
fmax = 1 / lambda_min
fcen_dft = 0.5 * (fmin + fmax)
df_dft = fmax - fmin

# 소스 설정
source_center = mp.Vector3(0, 0, 0)
sources = [
    mp.Source(
        src=mp.GaussianSource(frequency=fcen, fwidth=df),
        component=field_component,
        center=source_center,
        size=mp.Vector3(0, 0)
    )
]

air = mp.Medium(index = 1)

# PML 설정
pml_layers = [mp.PML(0.3)]

# 시뮬레이션 객체 생성
sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    # geometry=
    default_material=mp.Medium(index=1.0),
    sources=sources,
    resolution=resolution
)

# === LDOS 객체 생성 ===
freqs = np.linspace(fcen_dft - df_dft/2, fcen_dft + df_dft/2, nfreq)
ldos_obj = mp.Ldos(freqs)

decay_condition = mp.stop_when_fields_decayed(
    c=mp.Ex,                          # 모니터할 전기장 컴포넌트
    pt=mp.Vector3(0, 0, 0),           # 모니터 위치
    decay_by=1e-5,                    # auto shutoff min
    dt=100,                           # down sample time
)

# === 시뮬레이션 실행 ===
sim.run(
    mp.dft_ldos(ldos=ldos_obj),
    until_after_sources = decay_condition
)


# === 결과 얻기 ===
ldos_power = np.array(sim.ldos_data)  # (W) 단위 power
flux_freqs = np.array(mp.get_ldos_freqs(ldos_obj))  # (1/μm) 단위 주파수
wavelengths = 1 / flux_freqs  # (μm) 단위 파장

# === CSV 저장 ===
csv_filename = f"ldos_sourcepower_res{resolution}.csv"
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Wavelength (μm)", "LDOS Power (a.u.)"])
    for wl, power in zip(wavelengths, ldos_power):
        writer.writerow([wl, power])

print(f"CSV 파일 저장 완료: {csv_filename}")

# === 플롯 저장 ===
plt.figure(dpi=120)
plt.plot(wavelengths, ldos_power, label="LDOS Power", color='blue')
plt.xlabel("Wavelength (μm)", fontsize = 20)
plt.ylabel("Power (a.u.)", fontsize = 20)
plt.title(f"LDOS-based Source Power [] (Resolution={resolution})", fontsize = 20)
plt.grid(True)
plt.legend()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.
# ldos0:, 2.439082656473961, 1.2209600929907944
# ldos0:, 2.4426660296225515, 1.2229087725635472
# ldos0:, 2.4462494027711417, 1.2246720160626892
# ldos0:, 2.4498327759197327, 1.2263353746552137
# ldos0:, 2.453416149068323, 1.228234933156398
# ldos0:, 2.456999522216914, 1.2301212045863192
# ldos0:, 2.460582895365504, 1.2317748317016197
# ldos0:, 2.4641662685140946, 1.2335547554181778
# ldos0:, 2.467749641662685, 1.2355091300361374
# ldos0:, 2.4713330148112758, 1.2372510881862355
# ldos0:, 2.4749163879598663, 1.2389193924796236
# ldos0:, 2.4784997611084565, 1.2408386608537547
# ldos0:, 2.4820831342570475, 1.2427109381794588
# ldos0:, 2.4856665074056377, 1.2443517848905272
# ldos0:, 2.4892498805542287, 1.246152541075976
# ldos0:, 2.492833253702819, 1.2481103618083533
# ldos0:, 2.4964166268514094, 1.2498300062959669
# ldos0:, 2.5, 1.251506021935077
# run 0 finished at t = 200.005 (40001 timesteps)
# CSV 파일 저장 완료: ldos_sourcepower_res100.csv

# %%
plot_filename = f"ldos_sourcepower_res{resolution}.png"
plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
plt.close()

print(f"플롯 이미지 저장 완료: {plot_filename}")
# Out:
# 플롯 이미지 저장 완료: ldos_sourcepower_res100.png

# %%
### ----- Refractive index ----- ###,
Glass = sio2
aNDP = andp
Cathode = Al

# Cathode = mp.perfect_electric_conductor,
CoverLayer_index = 1.9
ITO_m_index = 1.8
Alq3_index = 1.68

CoverLayer = mp.Medium(index=CoverLayer_index) # SiN ,
ITO_m = mp.Medium(index=ITO_m_index) 
Alq3 = mp.Medium(index = Alq3_index) 
Air = mp.Medium(index=1.0) # 공기,

andp_replace = 0.075

Glass_layer = 2.37
Cover_layer = 0.07
ITO_layer = 0.15

Alq3_layer = 0.06
Cathode_layer = 1.3

PML_layer = 1.0

boundary_layers = [
    mp.PML(thickness=PML_layer, direction=mp.X, side=mp.Low),  # 좌측 PML,
    mp.PML(thickness=PML_layer, direction=mp.X, side=mp.High), # 우측 PML,
    mp.PML(thickness=PML_layer, direction=mp.Y, side=mp.High), # 상단 PML,
    mp.PML(thickness=PML_layer, direction=mp.Y, side=mp.Low), # 상단 PML,
]

Cathode_center = mp.Vector3(0, -1.35, 0)
Alq3_center = mp.Vector3(0, -0.67, 0)

aNDP_layer = 0.05  
aNDP_center = mp.Vector3(0, -0.615  , 0)
ITO_center = mp.Vector3(0, -0.515  , 0)
Cover_center = mp.Vector3(0, -0.405 , 0)
Glass_center = mp.Vector3(0, 0.815 , 0)

cell_size = mp.Vector3(31, 4, 0)

field_component = mp.Ex

lambda_min = 0.4
lambda_max = 0.7
fmin = 1 / lambda_max
fmax = 1 / lambda_min
fcen_dft = 0.5 * (fmin + fmax)
df_dft = fmax - fmin

geometry_fitting = [
        # Cathode (하단)
        mp.Block(
            center=Cathode_center,
            size=mp.Vector3(mp.inf, Cathode_layer, 1),
            material=Cathode
        ),
        # Alq3
        mp.Block(
            center=Alq3_center,
            size=mp.Vector3(mp.inf, Alq3_layer, 1),
            material=Alq3
        ),
        # aNDP
        mp.Block(
            center=aNDP_center,
            size=mp.Vector3(mp.inf, aNDP_layer, 1),
            material=aNDP
        ),
        # ITO
        mp.Block(
            center=ITO_center,
            size=mp.Vector3(mp.inf, ITO_layer, 1),
            material=ITO_m
        ),
        # Cover layer
        mp.Block(
            center=Cover_center,
            size=mp.Vector3(mp.inf, Cover_layer, 1),
            material=CoverLayer
        ),
        # Glass (상단; (0,0,0)은 이 Glass 내부에 위치함)
        mp.Block(
            center=Glass_center,
            size=mp.Vector3(mp.inf, Glass_layer, 1),
            material=Glass
        )
]

source_center = mp.Vector3(0,-0.67,0)

sources = [mp.Source(
        src=mp.GaussianSource(frequency=fcen, fwidth=df),
        component=mp.Ex,
        center=source_center,
        size=mp.Vector3(0,0,0),
        
        # amplitude = 0.1
)]

# === 시뮬레이션 설정 === #
sim_fitting = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=boundary_layers,
    geometry=geometry_fitting,
    default_material=mp.Medium(index = 1),
    sources=sources,
    resolution=resolution,
    eps_averaging=True,
    extra_materials=[Cathode, aNDP, Glass]
)

# %%
sim_fitting.plot2D()
# Out:
#      block, center = (0,-1.35,0)
#           size (1e+20,1.3,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
#      block, center = (0,-0.67,0)
#           size (1e+20,0.06,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (1e+20,0.05,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
#      block, center = (0,-0.515,0)
#           size (1e+20,0.15,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (1e+20,0.07,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.815,0)
#           size (1e+20,2.37,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
# <Axes: xlabel='X', ylabel='Y'>

# %%
offset = 0.01
flux_size = 0.02

# Dipole 위치
source_center = mp.Vector3(0, -0.67,0)

# === LDOS 객체 생성 ===
freqs = np.linspace(fcen_dft - df_dft/2, fcen_dft + df_dft/2, nfreq)
ldos_obj = mp.Ldos(freqs)

decay_condition = mp.stop_when_fields_decayed(
    c=mp.Ex,                          # 모니터할 전기장 컴포넌트
    pt=source_center,           # 모니터 위치
    decay_by=1e-5,                    # auto shutoff min
    dt=100,                           # down sample time
)

sim_fitting.run(
    mp.dft_ldos(ldos=ldos_obj),
    # until=50
    until_after_sources = decay_condition
)

net_power_fitting = mp.get_fluxes(sim_fitting)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000611067 s
# Working in 2D dimensions.
# Computational cell is 31 x 4 x 0 with resolution 100
#      block, center = (0,-1.35,0)
#           size (1e+20,1.3,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
#      block, center = (0,-0.67,0)
#           size (1e+20,0.06,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
#      block, center = (0,-0.615,0)
#           size (1e+20,0.05,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
#      block, center = (0,-0.515,0)
#           size (1e+20,0.15,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0,-0.405,0)
#           size (1e+20,0.07,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.61,3.61,3.61)
#      block, center = (0,0.815,0)
#           size (1e+20,2.37,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
# time for set_epsilon = 1.63169 s
# lorentzian susceptibility: frequency=10.1938, gamma=4.6625e-230
# lorentzian susceptibility: frequency=10.1936, gamma=0.00164383
# lorentzian susceptibility: frequency=5.05282, gamma=0
# lorentzian susceptibility: frequency=2.63601, gamma=0.275275
# lorentzian susceptibility: frequency=4.79442, gamma=2.39603e-06
# lorentzian susceptibility: frequency=4.87462, gamma=0
# lorentzian susceptibility: frequency=4.77321, gamma=0.0786669
# lorentzian susceptibility: frequency=11.9833, gamma=8.64311
# drude susceptibility: frequency=1, gamma=0.155547
# lorentzian susceptibility: frequency=1.47345, gamma=0.579822
# lorentzian susceptibility: frequency=0.258842, gamma=5.8094
# lorentzian susceptibility: frequency=1.9314, gamma=1.55603
# drude susceptibility: frequency=1, gamma=0.0125231
# lorentzian susceptibility: frequency=1.25246, gamma=0.301667
# -----------
# /home/min/miniconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py:1660: RuntimeWarning: Note: your sources include frequencies outside the range of validity of the material models. This is fine as long as you eventually only look at outputs (fluxes, resonant modes, etc.) at valid frequencies.
#   warnings.warn(warn_src, RuntimeWarning)
# on time step 84 (time=0.42), 0.0478648 s/step
# on time step 196 (time=0.98), 0.0359557 s/step
# on time step 284 (time=1.42), 0.04594 s/step
# on time step 376 (time=1.88), 0.0436262 s/step
# on time step 465 (time=2.325), 0.0452779 s/step
# on time step 552 (time=2.76), 0.0462859 s/step
# on time step 643 (time=3.215), 0.044413 s/step
# on time step 733 (time=3.665), 0.0444934 s/step
# on time step 820 (time=4.1), 0.0463294 s/step
# on time step 932 (time=4.66), 0.0357953 s/step
# on time step 1026 (time=5.13), 0.042971 s/step
# on time step 1114 (time=5.57), 0.0458634 s/step
# on time step 1206 (time=6.03), 0.0439093 s/step
# on time step 1297 (time=6.485), 0.044009 s/step
# on time step 1389 (time=6.945), 0.0438471 s/step
# on time step 1483 (time=7.415), 0.0428317 s/step
# on time step 1577 (time=7.885), 0.0426983 s/step
# on time step 1692 (time=8.46), 0.0348169 s/step
# on time step 1784 (time=8.92), 0.0435483 s/step
# on time step 1873 (time=9.365), 0.045125 s/step
# on time step 1964 (time=9.82), 0.0444596 s/step
# on time step 2052 (time=10.26), 0.045896 s/step
# on time step 2136 (time=10.68), 0.0478634 s/step
# on time step 2222 (time=11.11), 0.0470603 s/step
# on time step 2307 (time=11.535), 0.0472772 s/step
# on time step 2420 (time=12.1), 0.0356133 s/step
# on time step 2513 (time=12.565), 0.0432623 s/step
# on time step 2607 (time=13.035), 0.0429223 s/step
# on time step 2701 (time=13.505), 0.042788 s/step
# on time step 2794 (time=13.97), 0.0432376 s/step
# on time step 2885 (time=14.425), 0.0439583 s/step
# on time step 2978 (time=14.89), 0.0433151 s/step
# on time step 3069 (time=15.345), 0.0440163 s/step
# on time step 3185 (time=15.925), 0.0348019 s/step
# on time step 3276 (time=16.38), 0.0441845 s/step
# on time step 3370 (time=16.85), 0.0429865 s/step
# on time step 3456 (time=17.28), 0.0466428 s/step
# on time step 3541 (time=17.705), 0.047216 s/step
# on time step 3625 (time=18.125), 0.0481361 s/step
# on time step 3711 (time=18.555), 0.0467589 s/step
# on time step 3792 (time=18.96), 0.049664 s/step
# on time step 3898 (time=19.49), 0.0378275 s/step
# on time step 3980 (time=19.9), 0.0488697 s/step
# on time step 4070 (time=20.35), 0.0449121 s/step
# on time step 4163 (time=20.815), 0.0433274 s/step
# on time step 4247 (time=21.235), 0.047663 s/step
# on time step 4330 (time=21.65), 0.0485015 s/step
# on time step 4408 (time=22.04), 0.051578 s/step
# on time step 4521 (time=22.605), 0.0355054 s/step
# on time step 4605 (time=23.025), 0.0478182 s/step
# on time step 4688 (time=23.44), 0.0483691 s/step
# on time step 4775 (time=23.875), 0.0461727 s/step
# on time step 4862 (time=24.31), 0.0461758 s/step
# on time step 4949 (time=24.745), 0.0460931 s/step
# on time step 5042 (time=25.21), 0.0432446 s/step
# on time step 5133 (time=25.665), 0.0441139 s/step
# on time step 5236 (time=26.18), 0.0389755 s/step
# on time step 5324 (time=26.62), 0.0454754 s/step
# on time step 5411 (time=27.055), 0.0462067 s/step
# on time step 5499 (time=27.495), 0.0459152 s/step
# on time step 5583 (time=27.915), 0.0480078 s/step
# on time step 5673 (time=28.365), 0.0444549 s/step
# on time step 5765 (time=28.825), 0.0436318 s/step
# on time step 5854 (time=29.27), 0.0453756 s/step
# on time step 5960 (time=29.8), 0.0381241 s/step
# on time step 6050 (time=30.25), 0.044523 s/step
# on time step 6138 (time=30.69), 0.0456533 s/step
# on time step 6225 (time=31.125), 0.046444 s/step
# on time step 6311 (time=31.555), 0.046881 s/step
# on time step 6393 (time=31.965), 0.0492764 s/step
# on time step 6476 (time=32.38), 0.0483176 s/step
# on time step 6559 (time=32.795), 0.048611 s/step
# on time step 6670 (time=33.35), 0.0364732 s/step
# on time step 6756 (time=33.78), 0.0466797 s/step
# on time step 6846 (time=34.23), 0.0448188 s/step
# on time step 6938 (time=34.69), 0.0436728 s/step
# on time step 7031 (time=35.155), 0.0434703 s/step
# on time step 7124 (time=35.62), 0.0433277 s/step
# on time step 7219 (time=36.095), 0.0422139 s/step
# on time step 7312 (time=36.56), 0.0430568 s/step
# on time step 7424 (time=37.12), 0.0360653 s/step
# on time step 7517 (time=37.585), 0.0431536 s/step
# on time step 7608 (time=38.04), 0.0444205 s/step
# on time step 7694 (time=38.47), 0.0468658 s/step
# on time step 7777 (time=38.885), 0.0484453 s/step
# on time step 7866 (time=39.33), 0.0452903 s/step
# on time step 7957 (time=39.785), 0.044103 s/step
# on time step 8048 (time=40.24), 0.0441546 s/step
# on time step 8156 (time=40.78), 0.0370795 s/step
# on time step 8246 (time=41.23), 0.0447902 s/step
# on time step 8333 (time=41.665), 0.0464071 s/step
# on time step 8428 (time=42.14), 0.0424356 s/step
# on time step 8523 (time=42.615), 0.0424388 s/step
# on time step 8616 (time=43.08), 0.0430766 s/step
# on time step 8710 (time=43.55), 0.0428869 s/step
# on time step 8805 (time=44.025), 0.0424276 s/step
# on time step 8922 (time=44.61), 0.0343899 s/step
# on time step 9017 (time=45.085), 0.0424927 s/step
# on time step 9112 (time=45.56), 0.0422049 s/step
# on time step 9206 (time=46.03), 0.0428075 s/step
# on time step 9301 (time=46.505), 0.042381 s/step
# on time step 9396 (time=46.98), 0.0423284 s/step
# on time step 9491 (time=47.455), 0.0421754 s/step
# on time step 9608 (time=48.04), 0.0343416 s/step
# on time step 9704 (time=48.52), 0.0420932 s/step
# on time step 9800 (time=49), 0.0419883 s/step
# on time step 9892 (time=49.46), 0.0434853 s/step
# on time step 9985 (time=49.925), 0.0434577 s/step
# on time step 10077 (time=50.385), 0.043744 s/step
# on time step 10171 (time=50.855), 0.042594 s/step
# on time step 10264 (time=51.32), 0.0431248 s/step
# on time step 10381 (time=51.905), 0.034542 s/step
# on time step 10475 (time=52.375), 0.0428258 s/step
# on time step 10570 (time=52.85), 0.0425383 s/step
# on time step 10665 (time=53.325), 0.0423734 s/step
# on time step 10760 (time=53.8), 0.0425313 s/step
# on time step 10855 (time=54.275), 0.0422849 s/step
# on time step 10950 (time=54.75), 0.042532 s/step
# on time step 11045 (time=55.225), 0.0422178 s/step
# on time step 11162 (time=55.81), 0.0344411 s/step
# on time step 11257 (time=56.285), 0.0422071 s/step
# on time step 11349 (time=56.745), 0.043733 s/step
# on time step 11440 (time=57.2), 0.043968 s/step
# on time step 11526 (time=57.63), 0.0467596 s/step
# on time step 11614 (time=58.07), 0.0454882 s/step
# on time step 11704 (time=58.52), 0.0449614 s/step
# on time step 11793 (time=58.965), 0.0450829 s/step
# on time step 11903 (time=59.515), 0.0364414 s/step
# on time step 11994 (time=59.97), 0.0443718 s/step
# on time step 12087 (time=60.435), 0.0430416 s/step
# on time step 12180 (time=60.9), 0.0432785 s/step
# on time step 12273 (time=61.365), 0.043339 s/step
# on time step 12358 (time=61.79), 0.0470684 s/step
# on time step 12449 (time=62.245), 0.0441003 s/step
# on time step 12538 (time=62.69), 0.0453134 s/step
# on time step 12643 (time=63.215), 0.0385378 s/step
# on time step 12727 (time=63.635), 0.0477054 s/step
# on time step 12813 (time=64.065), 0.0468569 s/step
# on time step 12899 (time=64.495), 0.0467569 s/step
# on time step 12989 (time=64.945), 0.044733 s/step
# on time step 13079 (time=65.395), 0.0447493 s/step
# on time step 13168 (time=65.84), 0.0449742 s/step
# on time step 13254 (time=66.27), 0.0469324 s/step
# on time step 13364 (time=66.82), 0.0365659 s/step
# on time step 13453 (time=67.265), 0.0449572 s/step
# on time step 13542 (time=67.71), 0.0453421 s/step
# on time step 13628 (time=68.14), 0.0467091 s/step
# on time step 13712 (time=68.56), 0.0476992 s/step
# on time step 13802 (time=69.01), 0.0447083 s/step
# on time step 13892 (time=69.46), 0.044843 s/step
# on time step 14004 (time=70.02), 0.0357468 s/step
# on time step 14098 (time=70.49), 0.0429825 s/step
# on time step 14193 (time=70.965), 0.0424904 s/step
# on time step 14288 (time=71.44), 0.042196 s/step
# on time step 14383 (time=71.915), 0.042321 s/step
# on time step 14479 (time=72.395), 0.0420493 s/step
# on time step 14575 (time=72.875), 0.0419768 s/step
# on time step 14671 (time=73.355), 0.0419745 s/step
# on time step 14788 (time=73.94), 0.0342037 s/step
# on time step 14884 (time=74.42), 0.042017 s/step
# on time step 14979 (time=74.895), 0.0422705 s/step
# on time step 15074 (time=75.37), 0.0422537 s/step
# on time step 15170 (time=75.85), 0.04198 s/step
# on time step 15264 (time=76.32), 0.0425584 s/step
# on time step 15359 (time=76.795), 0.0425203 s/step
# on time step 15455 (time=77.275), 0.0420827 s/step
# on time step 15574 (time=77.87), 0.0337407 s/step
# on time step 15670 (time=78.35), 0.0418863 s/step
# on time step 15766 (time=78.83), 0.042034 s/step
# on time step 15861 (time=79.305), 0.0421431 s/step
# on time step 15956 (time=79.78), 0.0422778 s/step
# on time step 16048 (time=80.24), 0.0435157 s/step
# on time step 16144 (time=80.72), 0.0420425 s/step
# on time step 16240 (time=81.2), 0.0420315 s/step
# on time step 16358 (time=81.79), 0.0340889 s/step
# on time step 16453 (time=82.265), 0.0422369 s/step
# on time step 16549 (time=82.745), 0.0419133 s/step
# on time step 16644 (time=83.22), 0.0422029 s/step
# on time step 16740 (time=83.7), 0.0419205 s/step
# on time step 16836 (time=84.18), 0.0420117 s/step
# on time step 16931 (time=84.655), 0.0421098 s/step
# on time step 17025 (time=85.125), 0.042672 s/step
# on time step 17143 (time=85.715), 0.0340558 s/step
# on time step 17238 (time=86.19), 0.0421383 s/step
# on time step 17334 (time=86.67), 0.0420787 s/step
# on time step 17430 (time=87.15), 0.0420882 s/step
# on time step 17526 (time=87.63), 0.0419863 s/step
# on time step 17620 (time=88.1), 0.0428552 s/step
# on time step 17716 (time=88.58), 0.0418606 s/step
# on time step 17812 (time=89.06), 0.0420074 s/step
# on time step 17931 (time=89.655), 0.0337188 s/step
# on time step 18027 (time=90.135), 0.0420389 s/step
# on time step 18123 (time=90.615), 0.0418528 s/step
# on time step 18219 (time=91.095), 0.0421053 s/step
# on time step 18315 (time=91.575), 0.0420045 s/step
# on time step 18411 (time=92.055), 0.0418679 s/step
# on time step 18507 (time=92.535), 0.0418712 s/step
# on time step 18625 (time=93.125), 0.0340096 s/step
# on time step 18721 (time=93.605), 0.0420422 s/step
# on time step 18817 (time=94.085), 0.0420996 s/step
# on time step 18913 (time=94.565), 0.0419303 s/step
# on time step 19008 (time=95.04), 0.0422021 s/step
# on time step 19103 (time=95.515), 0.0421194 s/step
# on time step 19199 (time=95.995), 0.0418984 s/step
# on time step 19293 (time=96.465), 0.0426134 s/step
# on time step 19412 (time=97.06), 0.0339199 s/step
# on time step 19507 (time=97.535), 0.0423525 s/step
# on time step 19602 (time=98.01), 0.0423063 s/step
# on time step 19696 (time=98.48), 0.0426128 s/step
# on time step 19790 (time=98.95), 0.0425617 s/step
# on time step 19886 (time=99.43), 0.0420721 s/step
# on time step 19982 (time=99.91), 0.0419738 s/step
# field decay(t = 100.005): 2324.888883618151 / 2324.888883618151 = 1.0
# on time step 20078 (time=100.39), 0.0418508 s/step
# on time step 20197 (time=100.985), 0.033685 s/step
# on time step 20294 (time=101.47), 0.0415568 s/step
# on time step 20389 (time=101.945), 0.0424811 s/step
# on time step 20480 (time=102.4), 0.0441903 s/step
# on time step 20574 (time=102.87), 0.0428503 s/step
# on time step 20669 (time=103.345), 0.0422581 s/step
# on time step 20764 (time=103.82), 0.0422339 s/step
# on time step 20860 (time=104.3), 0.0417716 s/step
# on time step 20979 (time=104.895), 0.0336891 s/step
# on time step 21075 (time=105.375), 0.0418076 s/step
# on time step 21170 (time=105.85), 0.042302 s/step
# on time step 21265 (time=106.325), 0.0421182 s/step
# on time step 21361 (time=106.805), 0.0420195 s/step
# on time step 21457 (time=107.285), 0.0419603 s/step
# on time step 21553 (time=107.765), 0.0418032 s/step
# on time step 21648 (time=108.24), 0.0421365 s/step
# on time step 21766 (time=108.83), 0.0341506 s/step
# on time step 21862 (time=109.31), 0.0419975 s/step
# on time step 21958 (time=109.79), 0.0419726 s/step
# on time step 22053 (time=110.265), 0.0421424 s/step
# on time step 22149 (time=110.745), 0.0417519 s/step
# on time step 22244 (time=111.22), 0.0421921 s/step
# on time step 22340 (time=111.7), 0.0418824 s/step
# on time step 22435 (time=112.175), 0.0421698 s/step
# on time step 22552 (time=112.76), 0.0343196 s/step
# on time step 22637 (time=113.185), 0.0473933 s/step
# on time step 22725 (time=113.625), 0.0457446 s/step
# on time step 22817 (time=114.085), 0.0436876 s/step
# on time step 22911 (time=114.555), 0.0427099 s/step
# on time step 23006 (time=115.03), 0.0425667 s/step
# on time step 23100 (time=115.5), 0.0428072 s/step
# on time step 23217 (time=116.085), 0.0345254 s/step
# on time step 23312 (time=116.56), 0.0424737 s/step
# on time step 23406 (time=117.03), 0.0427616 s/step
# on time step 23502 (time=117.51), 0.042007 s/step
# on time step 23597 (time=117.985), 0.0423592 s/step
# on time step 23692 (time=118.46), 0.0425246 s/step
# on time step 23786 (time=118.93), 0.0428049 s/step
# on time step 23880 (time=119.4), 0.0426153 s/step
# on time step 23993 (time=119.965), 0.0354509 s/step
# on time step 24085 (time=120.425), 0.0436751 s/step
# on time step 24176 (time=120.88), 0.0440372 s/step
# on time step 24271 (time=121.355), 0.0425415 s/step
# on time step 24365 (time=121.825), 0.0428005 s/step
# on time step 24460 (time=122.3), 0.0422547 s/step
# on time step 24551 (time=122.755), 0.0439844 s/step
# on time step 24643 (time=123.215), 0.0438221 s/step
# on time step 24761 (time=123.805), 0.0341647 s/step
# on time step 24854 (time=124.27), 0.0434318 s/step
# on time step 24949 (time=124.745), 0.0421445 s/step
# on time step 25044 (time=125.22), 0.042314 s/step
# on time step 25140 (time=125.7), 0.0421005 s/step
# on time step 25235 (time=126.175), 0.0421876 s/step
# on time step 25327 (time=126.635), 0.0437912 s/step
# on time step 25417 (time=127.085), 0.0444867 s/step
# on time step 25532 (time=127.66), 0.0349946 s/step
# on time step 25626 (time=128.13), 0.0428779 s/step
# on time step 25718 (time=128.59), 0.0435099 s/step
# on time step 25809 (time=129.045), 0.0441219 s/step
# on time step 25900 (time=129.5), 0.0442254 s/step
# on time step 25993 (time=129.965), 0.0430505 s/step
# on time step 26087 (time=130.435), 0.0429796 s/step
# on time step 26181 (time=130.905), 0.0429386 s/step
# on time step 26298 (time=131.49), 0.0345164 s/step
# on time step 26393 (time=131.965), 0.0421552 s/step
# on time step 26487 (time=132.435), 0.0426662 s/step
# on time step 26581 (time=132.905), 0.042904 s/step
# on time step 26675 (time=133.375), 0.0429155 s/step
# on time step 26771 (time=133.855), 0.042059 s/step
# on time step 26866 (time=134.33), 0.042366 s/step
# on time step 26959 (time=134.795), 0.0431524 s/step
# on time step 27075 (time=135.375), 0.0346697 s/step
# on time step 27169 (time=135.845), 0.0429689 s/step
# on time step 27263 (time=136.315), 0.0427336 s/step
# on time step 27357 (time=136.785), 0.0427449 s/step
# on time step 27450 (time=137.25), 0.0431732 s/step
# on time step 27545 (time=137.725), 0.0422902 s/step
# on time step 27639 (time=138.195), 0.0428191 s/step
# on time step 27733 (time=138.665), 0.0426141 s/step
# on time step 27850 (time=139.25), 0.0342783 s/step
# on time step 27944 (time=139.72), 0.0426449 s/step
# on time step 28038 (time=140.19), 0.0426421 s/step
# on time step 28133 (time=140.665), 0.0423939 s/step
# on time step 28228 (time=141.14), 0.0423806 s/step
# on time step 28323 (time=141.615), 0.0423517 s/step
# on time step 28417 (time=142.085), 0.0425686 s/step
# on time step 28535 (time=142.675), 0.0341253 s/step
# on time step 28631 (time=143.155), 0.0419659 s/step
# on time step 28726 (time=143.63), 0.0423587 s/step
# on time step 28820 (time=144.1), 0.0425708 s/step
# on time step 28915 (time=144.575), 0.0424042 s/step
# on time step 29010 (time=145.05), 0.0424811 s/step
# on time step 29104 (time=145.52), 0.04299 s/step
# on time step 29199 (time=145.995), 0.0425398 s/step
# on time step 29317 (time=146.585), 0.0342595 s/step
# on time step 29412 (time=147.06), 0.0424939 s/step
# on time step 29506 (time=147.53), 0.0430418 s/step
# on time step 29600 (time=148), 0.0429274 s/step
# on time step 29695 (time=148.475), 0.0422293 s/step
# on time step 29789 (time=148.945), 0.0426191 s/step
# on time step 29882 (time=149.41), 0.0432713 s/step
# on time step 29977 (time=149.885), 0.0425069 s/step
# on time step 30096 (time=150.48), 0.0338934 s/step
# on time step 30187 (time=150.935), 0.0440606 s/step
# on time step 30278 (time=151.39), 0.0440701 s/step
# on time step 30368 (time=151.84), 0.0446025 s/step
# on time step 30463 (time=152.315), 0.0423736 s/step
# on time step 30558 (time=152.79), 0.0423325 s/step
# on time step 30648 (time=153.24), 0.0449079 s/step
# on time step 30740 (time=153.7), 0.0438655 s/step
# on time step 30855 (time=154.275), 0.0347944 s/step
# on time step 30940 (time=154.7), 0.0474394 s/step
# on time step 31031 (time=155.155), 0.0444003 s/step
# on time step 31121 (time=155.605), 0.0448199 s/step
# on time step 31211 (time=156.055), 0.0451155 s/step
# on time step 31299 (time=156.495), 0.045779 s/step
# on time step 31389 (time=156.945), 0.0447198 s/step
# on time step 31480 (time=157.4), 0.0442041 s/step
# on time step 31595 (time=157.975), 0.0349639 s/step
# on time step 31687 (time=158.435), 0.0434924 s/step
# on time step 31780 (time=158.9), 0.0431925 s/step
# on time step 31873 (time=159.365), 0.0430787 s/step
# on time step 31966 (time=159.83), 0.0434145 s/step
# on time step 32058 (time=160.29), 0.043629 s/step
# on time step 32151 (time=160.755), 0.0432627 s/step
# on time step 32244 (time=161.22), 0.043426 s/step
# on time step 32358 (time=161.79), 0.0350914 s/step
# on time step 32451 (time=162.255), 0.0433578 s/step
# on time step 32543 (time=162.715), 0.0436128 s/step
# on time step 32634 (time=163.17), 0.0440113 s/step
# on time step 32726 (time=163.63), 0.043552 s/step
# on time step 32820 (time=164.1), 0.0429927 s/step
# on time step 32913 (time=164.565), 0.0433485 s/step
# on time step 33028 (time=165.14), 0.0349508 s/step
# on time step 33122 (time=165.61), 0.0430025 s/step
# on time step 33215 (time=166.075), 0.0432309 s/step
# on time step 33308 (time=166.54), 0.0433354 s/step
# on time step 33400 (time=167), 0.043496 s/step
# on time step 33493 (time=167.465), 0.0431622 s/step
# on time step 33586 (time=167.93), 0.0433518 s/step
# on time step 33679 (time=168.395), 0.0430929 s/step
# on time step 33795 (time=168.975), 0.0347153 s/step
# on time step 33889 (time=169.445), 0.0429877 s/step
# on time step 33982 (time=169.91), 0.0433018 s/step
# on time step 34074 (time=170.37), 0.0436522 s/step
# on time step 34167 (time=170.835), 0.0431893 s/step
# on time step 34260 (time=171.3), 0.0432891 s/step
# on time step 34353 (time=171.765), 0.0433872 s/step
# on time step 34446 (time=172.23), 0.0433268 s/step
# on time step 34563 (time=172.815), 0.0345417 s/step
# on time step 34657 (time=173.285), 0.0429021 s/step
# on time step 34751 (time=173.755), 0.042962 s/step
# on time step 34843 (time=174.215), 0.0437538 s/step
# on time step 34935 (time=174.675), 0.0435744 s/step
# on time step 35028 (time=175.14), 0.0432201 s/step
# on time step 35121 (time=175.605), 0.0434265 s/step
# on time step 35214 (time=176.07), 0.043018 s/step
# on time step 35331 (time=176.655), 0.0345111 s/step
# on time step 35424 (time=177.12), 0.043127 s/step
# on time step 35517 (time=177.585), 0.043157 s/step
# on time step 35610 (time=178.05), 0.0433099 s/step
# on time step 35703 (time=178.515), 0.0432325 s/step
# on time step 35796 (time=178.98), 0.0434589 s/step
# on time step 35889 (time=179.445), 0.0432773 s/step
# on time step 35982 (time=179.91), 0.0431844 s/step
# on time step 36097 (time=180.485), 0.0348113 s/step
# on time step 36190 (time=180.95), 0.0432275 s/step
# on time step 36283 (time=181.415), 0.0432171 s/step
# on time step 36376 (time=181.88), 0.0430891 s/step
# on time step 36469 (time=182.345), 0.043209 s/step
# on time step 36562 (time=182.81), 0.0433442 s/step
# on time step 36655 (time=183.275), 0.0431348 s/step
# on time step 36748 (time=183.74), 0.0430746 s/step
# on time step 36864 (time=184.32), 0.0348055 s/step
# on time step 36957 (time=184.785), 0.043317 s/step
# on time step 37050 (time=185.25), 0.0431652 s/step
# on time step 37143 (time=185.715), 0.0431557 s/step
# on time step 37235 (time=186.175), 0.0435983 s/step
# on time step 37324 (time=186.62), 0.0453386 s/step
# on time step 37413 (time=187.065), 0.0454853 s/step
# on time step 37528 (time=187.64), 0.0349133 s/step
# on time step 37621 (time=188.105), 0.0431825 s/step
# on time step 37714 (time=188.57), 0.0430811 s/step
# on time step 37807 (time=189.035), 0.0433017 s/step
# on time step 37900 (time=189.5), 0.0430447 s/step
# on time step 37993 (time=189.965), 0.0432685 s/step
# on time step 38086 (time=190.43), 0.043121 s/step
# on time step 38179 (time=190.895), 0.0431343 s/step
# on time step 38295 (time=191.475), 0.0347647 s/step
# on time step 38388 (time=191.94), 0.0430973 s/step
# on time step 38481 (time=192.405), 0.0432448 s/step
# on time step 38573 (time=192.865), 0.0435276 s/step
# on time step 38665 (time=193.325), 0.0435025 s/step
# on time step 38757 (time=193.785), 0.0435626 s/step
# on time step 38849 (time=194.245), 0.0435266 s/step
# on time step 38942 (time=194.71), 0.0431729 s/step
# on time step 39058 (time=195.29), 0.0346105 s/step
# on time step 39151 (time=195.755), 0.0432317 s/step
# on time step 39243 (time=196.215), 0.0438719 s/step
# on time step 39336 (time=196.68), 0.0433382 s/step
# on time step 39429 (time=197.145), 0.0432708 s/step
# on time step 39521 (time=197.605), 0.043933 s/step
# on time step 39614 (time=198.07), 0.0432448 s/step
# on time step 39707 (time=198.535), 0.0431718 s/step
# on time step 39823 (time=199.115), 0.0345658 s/step
# on time step 39916 (time=199.58), 0.0430899 s/step
# field decay(t = 200.005): 4197736675358.062 / 4197736675358.062 = 1.0
# on time step 40009 (time=200.045), 0.0432622 s/step
# on time step 40102 (time=200.51), 0.0432441 s/step
# on time step 40195 (time=200.975), 0.0432088 s/step
# on time step 40288 (time=201.44), 0.0433504 s/step
# on time step 40381 (time=201.905), 0.0434314 s/step
# on time step 40474 (time=202.37), 0.0432819 s/step
# on time step 40590 (time=202.95), 0.0346005 s/step
# on time step 40683 (time=203.415), 0.0431554 s/step
# on time step 40776 (time=203.88), 0.0434003 s/step
# on time step 40869 (time=204.345), 0.0433349 s/step
# on time step 40962 (time=204.81), 0.0430612 s/step
# on time step 41055 (time=205.275), 0.0432861 s/step
# on time step 41148 (time=205.74), 0.0430452 s/step
# on time step 41241 (time=206.205), 0.0432086 s/step
# on time step 41357 (time=206.785), 0.0346183 s/step
# on time step 41449 (time=207.245), 0.0435894 s/step
# on time step 41542 (time=207.71), 0.0430868 s/step
# on time step 41634 (time=208.17), 0.0439048 s/step
# on time step 41725 (time=208.625), 0.0440259 s/step
# on time step 41817 (time=209.085), 0.0437779 s/step
# on time step 41909 (time=209.545), 0.0436277 s/step
# on time step 42024 (time=210.12), 0.0350855 s/step
# on time step 42116 (time=210.58), 0.0437704 s/step
# on time step 42208 (time=211.04), 0.0439098 s/step
# on time step 42300 (time=211.5), 0.043917 s/step
# on time step 42392 (time=211.96), 0.0435112 s/step
# on time step 42485 (time=212.425), 0.0434484 s/step
# on time step 42578 (time=212.89), 0.0432755 s/step
# on time step 42670 (time=213.35), 0.0434897 s/step
# on time step 42784 (time=213.92), 0.0351946 s/step
# on time step 42876 (time=214.38), 0.0436794 s/step
# on time step 42967 (time=214.835), 0.0440685 s/step
# on time step 43059 (time=215.295), 0.043588 s/step
# on time step 43152 (time=215.76), 0.0432464 s/step
# on time step 43245 (time=216.225), 0.0431773 s/step
# on time step 43338 (time=216.69), 0.0431379 s/step
# on time step 43431 (time=217.155), 0.0431713 s/step
# on time step 43547 (time=217.735), 0.0344959 s/step
# on time step 43640 (time=218.2), 0.0430639 s/step
# on time step 43733 (time=218.665), 0.0432684 s/step
# on time step 43826 (time=219.13), 0.0432167 s/step
# on time step 43918 (time=219.59), 0.0435411 s/step
# on time step 44011 (time=220.055), 0.0433443 s/step
# on time step 44103 (time=220.515), 0.0436748 s/step
# on time step 44196 (time=220.98), 0.0434559 s/step
# on time step 44312 (time=221.56), 0.0345401 s/step
# on time step 44406 (time=222.03), 0.042976 s/step
# on time step 44500 (time=222.5), 0.0429788 s/step
# on time step 44592 (time=222.96), 0.0436336 s/step
# on time step 44684 (time=223.42), 0.0437748 s/step
# on time step 44777 (time=223.885), 0.0433503 s/step
# on time step 44868 (time=224.34), 0.0441354 s/step
# on time step 44961 (time=224.805), 0.0431008 s/step
# on time step 45076 (time=225.38), 0.0350002 s/step
# on time step 45169 (time=225.845), 0.0430825 s/step
# on time step 45261 (time=226.305), 0.0439442 s/step
# on time step 45353 (time=226.765), 0.0436654 s/step
# on time step 45440 (time=227.2), 0.0461123 s/step
# on time step 45528 (time=227.64), 0.0458969 s/step
# on time step 45621 (time=228.105), 0.0432459 s/step
# on time step 45714 (time=228.57), 0.0434187 s/step
# on time step 45829 (time=229.145), 0.0349861 s/step
# on time step 45922 (time=229.61), 0.0434042 s/step
# on time step 46014 (time=230.07), 0.0438191 s/step
# on time step 46104 (time=230.52), 0.0448303 s/step
# on time step 46192 (time=230.96), 0.0456801 s/step
# on time step 46284 (time=231.42), 0.043606 s/step
# on time step 46376 (time=231.88), 0.0437955 s/step
# on time step 46492 (time=232.46), 0.0347709 s/step
# on time step 46585 (time=232.925), 0.043353 s/step
# on time step 46678 (time=233.39), 0.0433368 s/step
# on time step 46771 (time=233.855), 0.0432081 s/step
# on time step 46864 (time=234.32), 0.0432719 s/step
# on time step 46957 (time=234.785), 0.0433405 s/step
# on time step 47050 (time=235.25), 0.0431461 s/step
# on time step 47142 (time=235.71), 0.0435022 s/step
# on time step 47257 (time=236.285), 0.0351003 s/step
# on time step 47350 (time=236.75), 0.0432103 s/step
# on time step 47443 (time=237.215), 0.0433593 s/step
# on time step 47536 (time=237.68), 0.0432036 s/step
# on time step 47628 (time=238.14), 0.0439085 s/step
# on time step 47721 (time=238.605), 0.0431753 s/step
# on time step 47814 (time=239.07), 0.0432406 s/step
# on time step 47907 (time=239.535), 0.0432122 s/step
# on time step 48019 (time=240.095), 0.0360875 s/step
# on time step 48109 (time=240.545), 0.0446315 s/step
# on time step 48200 (time=241), 0.0440196 s/step
# on time step 48290 (time=241.45), 0.0446106 s/step
# on time step 48382 (time=241.91), 0.0435778 s/step
# on time step 48474 (time=242.37), 0.0435978 s/step
# on time step 48567 (time=242.835), 0.0434202 s/step
# on time step 48660 (time=243.3), 0.0433328 s/step
# on time step 48777 (time=243.885), 0.0344371 s/step
# on time step 48870 (time=244.35), 0.0433327 s/step
# on time step 48963 (time=244.815), 0.0434071 s/step
# on time step 49055 (time=245.275), 0.0437181 s/step
# on time step 49147 (time=245.735), 0.0436594 s/step
# on time step 49239 (time=246.195), 0.0435016 s/step
# on time step 49332 (time=246.66), 0.0433642 s/step
# on time step 49425 (time=247.125), 0.0433704 s/step
# on time step 49542 (time=247.71), 0.0343446 s/step
# on time step 49635 (time=248.175), 0.0433382 s/step
# on time step 49727 (time=248.635), 0.0438381 s/step
# on time step 49820 (time=249.1), 0.0434356 s/step
# on time step 49913 (time=249.565), 0.0433119 s/step
# on time step 50006 (time=250.03), 0.0433259 s/step
# on time step 50099 (time=250.495), 0.0433774 s/step
# on time step 50214 (time=251.07), 0.0348711 s/step
# on time step 50307 (time=251.535), 0.0434176 s/step
# on time step 50400 (time=252), 0.0431929 s/step
# on time step 50492 (time=252.46), 0.0436853 s/step
# on time step 50584 (time=252.92), 0.0437047 s/step
# on time step 50677 (time=253.385), 0.0432635 s/step
# on time step 50769 (time=253.845), 0.0435845 s/step
# on time step 50862 (time=254.31), 0.0434458 s/step
# on time step 50978 (time=254.89), 0.0345015 s/step
# on time step 51071 (time=255.355), 0.0432636 s/step
# on time step 51163 (time=255.815), 0.0435068 s/step
# on time step 51256 (time=256.28), 0.0434161 s/step
# on time step 51348 (time=256.74), 0.0436839 s/step
# on time step 51441 (time=257.205), 0.0434327 s/step
# on time step 51534 (time=257.67), 0.04344 s/step
# on time step 51627 (time=258.135), 0.0433823 s/step
# on time step 51742 (time=258.71), 0.0349188 s/step
# on time step 51835 (time=259.175), 0.0433674 s/step
# on time step 51927 (time=259.635), 0.0436321 s/step
# on time step 52019 (time=260.095), 0.0435479 s/step
# on time step 52112 (time=260.56), 0.0433299 s/step
# on time step 52204 (time=261.02), 0.0435098 s/step
# on time step 52296 (time=261.48), 0.0437071 s/step
# on time step 52389 (time=261.945), 0.0434655 s/step
# on time step 52504 (time=262.52), 0.0349152 s/step
# on time step 52597 (time=262.985), 0.0434356 s/step
# on time step 52689 (time=263.445), 0.0436711 s/step
# on time step 52780 (time=263.9), 0.0441096 s/step
# on time step 52871 (time=264.355), 0.0440565 s/step
# on time step 52963 (time=264.815), 0.0435339 s/step
# on time step 53056 (time=265.28), 0.043423 s/step
# on time step 53149 (time=265.745), 0.043209 s/step
# on time step 53265 (time=266.325), 0.034681 s/step
# on time step 53358 (time=266.79), 0.0436193 s/step
# on time step 53449 (time=267.245), 0.0443178 s/step
# on time step 53541 (time=267.705), 0.0436668 s/step
# on time step 53632 (time=268.16), 0.0439614 s/step
# on time step 53724 (time=268.62), 0.0435123 s/step
# on time step 53817 (time=269.085), 0.0434041 s/step
# on time step 53910 (time=269.55), 0.0434646 s/step
# on time step 54026 (time=270.13), 0.0345225 s/step
# on time step 54119 (time=270.595), 0.0433895 s/step
# on time step 54212 (time=271.06), 0.0435045 s/step
# on time step 54304 (time=271.52), 0.0437373 s/step
# on time step 54397 (time=271.985), 0.0433338 s/step
# on time step 54490 (time=272.45), 0.0434381 s/step
# on time step 54583 (time=272.915), 0.0432556 s/step
# on time step 54692 (time=273.46), 0.0367741 s/step
# on time step 54779 (time=273.895), 0.0460316 s/step
# on time step 54872 (time=274.36), 0.0432081 s/step
# on time step 54965 (time=274.825), 0.0433026 s/step
# on time step 55058 (time=275.29), 0.0431855 s/step
# on time step 55150 (time=275.75), 0.0436994 s/step
# on time step 55242 (time=276.21), 0.0436178 s/step
# on time step 55335 (time=276.675), 0.0432415 s/step
# on time step 55451 (time=277.255), 0.0346426 s/step
# on time step 55544 (time=277.72), 0.0434046 s/step
# on time step 55637 (time=278.185), 0.0431505 s/step
# on time step 55730 (time=278.65), 0.0432743 s/step
# on time step 55823 (time=279.115), 0.0432799 s/step
# on time step 55916 (time=279.58), 0.0433938 s/step
# on time step 56009 (time=280.045), 0.0432626 s/step
# on time step 56102 (time=280.51), 0.0432256 s/step
# on time step 56218 (time=281.09), 0.0345236 s/step
# on time step 56311 (time=281.555), 0.0430846 s/step
# on time step 56404 (time=282.02), 0.0432597 s/step
# on time step 56497 (time=282.485), 0.0433082 s/step
# on time step 56589 (time=282.945), 0.043644 s/step
# on time step 56682 (time=283.41), 0.0433503 s/step
# on time step 56775 (time=283.875), 0.043458 s/step
# on time step 56868 (time=284.34), 0.043117 s/step
# on time step 56984 (time=284.92), 0.0347776 s/step
# on time step 57077 (time=285.385), 0.0431425 s/step
# on time step 57170 (time=285.85), 0.0432956 s/step
# on time step 57263 (time=286.315), 0.043244 s/step
# on time step 57356 (time=286.78), 0.0432317 s/step
# on time step 57449 (time=287.245), 0.0431482 s/step
# on time step 57542 (time=287.71), 0.0431849 s/step
# on time step 57635 (time=288.175), 0.0431229 s/step
# on time step 57752 (time=288.76), 0.0344224 s/step
# on time step 57845 (time=289.225), 0.0432731 s/step
# on time step 57938 (time=289.69), 0.0434565 s/step
# on time step 58031 (time=290.155), 0.043296 s/step
# on time step 58124 (time=290.62), 0.0432375 s/step
# on time step 58217 (time=291.085), 0.043404 s/step
# on time step 58310 (time=291.55), 0.0433652 s/step
# on time step 58403 (time=292.015), 0.0433251 s/step
# on time step 58520 (time=292.6), 0.0343191 s/step
# on time step 58613 (time=293.065), 0.0431276 s/step
# on time step 58704 (time=293.52), 0.0443349 s/step
# on time step 58796 (time=293.98), 0.0437531 s/step
# on time step 58883 (time=294.415), 0.0462989 s/step
# on time step 58972 (time=294.86), 0.0449736 s/step
# on time step 59063 (time=295.315), 0.0440074 s/step
# on time step 59179 (time=295.895), 0.0346419 s/step
# on time step 59270 (time=296.35), 0.0440076 s/step
# on time step 59362 (time=296.81), 0.0436171 s/step
# on time step 59452 (time=297.26), 0.0444577 s/step
# on time step 59545 (time=297.725), 0.0434199 s/step
# on time step 59638 (time=298.19), 0.0433142 s/step
# on time step 59731 (time=298.655), 0.0432799 s/step
# on time step 59824 (time=299.12), 0.0432269 s/step
# on time step 59940 (time=299.7), 0.0345706 s/step
# field decay(t = 300.01): 2.5606313246203738e+78 / 2.5606313246203738e+78 = 1.0
# on time step 60033 (time=300.165), 0.0433009 s/step
# on time step 60126 (time=300.63), 0.0432799 s/step
# on time step 60219 (time=301.095), 0.0431217 s/step
# on time step 60312 (time=301.56), 0.0431728 s/step
# on time step 60405 (time=302.025), 0.0433742 s/step
# on time step 60498 (time=302.49), 0.0434537 s/step
# on time step 60590 (time=302.95), 0.0437923 s/step
# on time step 60706 (time=303.53), 0.034845 s/step
# on time step 60797 (time=303.985), 0.0441836 s/step
# on time step 60888 (time=304.44), 0.0440308 s/step
# on time step 60981 (time=304.905), 0.0432796 s/step
# on time step 61073 (time=305.365), 0.0436911 s/step
# on time step 61165 (time=305.825), 0.0437381 s/step
# on time step 61256 (time=306.28), 0.0442625 s/step
# on time step 61346 (time=306.73), 0.0444609 s/step
# on time step 61460 (time=307.3), 0.0351017 s/step
# on time step 61552 (time=307.76), 0.0435739 s/step
# on time step 61645 (time=308.225), 0.0432689 s/step
# on time step 61738 (time=308.69), 0.0431806 s/step
# on time step 61831 (time=309.155), 0.0431638 s/step
# on time step 61924 (time=309.62), 0.043353 s/step
# on time step 62017 (time=310.085), 0.0432519 s/step
# on time step 62110 (time=310.55), 0.043336 s/step
# on time step 62226 (time=311.13), 0.0347522 s/step
# on time step 62318 (time=311.59), 0.0435305 s/step
# on time step 62411 (time=312.055), 0.043431 s/step
# on time step 62504 (time=312.52), 0.0434699 s/step
# on time step 62596 (time=312.98), 0.0438773 s/step
# on time step 62689 (time=313.445), 0.0433583 s/step
# on time step 62782 (time=313.91), 0.0433246 s/step
# on time step 62875 (time=314.375), 0.0433313 s/step
# on time step 62991 (time=314.955), 0.0346748 s/step
# on time step 63083 (time=315.415), 0.0435711 s/step
# on time step 63176 (time=315.88), 0.0433557 s/step
# on time step 63268 (time=316.34), 0.0436004 s/step
# on time step 63360 (time=316.8), 0.043487 s/step
# on time step 63452 (time=317.26), 0.0435727 s/step
# on time step 63543 (time=317.715), 0.0440694 s/step
# on time step 63659 (time=318.295), 0.0347685 s/step
# on time step 63752 (time=318.76), 0.0433029 s/step
# on time step 63845 (time=319.225), 0.043266 s/step
# on time step 63937 (time=319.685), 0.0435928 s/step
# on time step 64030 (time=320.15), 0.0434607 s/step
# on time step 64123 (time=320.615), 0.0433972 s/step
# on time step 64216 (time=321.08), 0.0433564 s/step
# on time step 64308 (time=321.54), 0.0435126 s/step
# on time step 64425 (time=322.125), 0.0344107 s/step
# on time step 64518 (time=322.59), 0.0432789 s/step
# on time step 64611 (time=323.055), 0.043272 s/step
# on time step 64704 (time=323.52), 0.0433263 s/step
# on time step 64797 (time=323.985), 0.0433758 s/step
# on time step 64890 (time=324.45), 0.0431156 s/step
# on time step 64983 (time=324.915), 0.043318 s/step
# on time step 65076 (time=325.38), 0.0432465 s/step
# on time step 65188 (time=325.94), 0.0357164 s/step
# on time step 65278 (time=326.39), 0.0446178 s/step
# on time step 65371 (time=326.855), 0.0432623 s/step
# on time step 65464 (time=327.32), 0.043371 s/step
# on time step 65557 (time=327.785), 0.0432092 s/step
# on time step 65650 (time=328.25), 0.0432312 s/step
# on time step 65743 (time=328.715), 0.0433511 s/step
# on time step 65836 (time=329.18), 0.0431926 s/step
# on time step 65952 (time=329.76), 0.0347648 s/step
# on time step 66045 (time=330.225), 0.0432393 s/step
# on time step 66138 (time=330.69), 0.0432881 s/step
# on time step 66230 (time=331.15), 0.0434943 s/step
# on time step 66323 (time=331.615), 0.0432492 s/step
# on time step 66416 (time=332.08), 0.0433895 s/step
# on time step 66509 (time=332.545), 0.0432568 s/step
# on time step 66601 (time=333.005), 0.043822 s/step
# on time step 66710 (time=333.55), 0.0367498 s/step
# on time step 66799 (time=333.995), 0.0451471 s/step
# on time step 66886 (time=334.43), 0.0462792 s/step
# on time step 66974 (time=334.87), 0.0454878 s/step
# on time step 67060 (time=335.3), 0.0465365 s/step
# on time step 67148 (time=335.74), 0.0456792 s/step
# on time step 67239 (time=336.195), 0.0442307 s/step
# on time step 67330 (time=336.65), 0.0442947 s/step
# on time step 67443 (time=337.215), 0.0356786 s/step
# on time step 67533 (time=337.665), 0.044471 s/step
# on time step 67624 (time=338.12), 0.0443516 s/step
# on time step 67716 (time=338.58), 0.0438679 s/step
# on time step 67805 (time=339.025), 0.0449775 s/step
# on time step 67895 (time=339.475), 0.0444861 s/step
# on time step 67986 (time=339.93), 0.044396 s/step
# on time step 68101 (time=340.505), 0.0350952 s/step
# on time step 68193 (time=340.965), 0.0435235 s/step
# on time step 68285 (time=341.425), 0.0437073 s/step
# on time step 68375 (time=341.875), 0.0447245 s/step
# on time step 68461 (time=342.305), 0.0466461 s/step
# on time step 68545 (time=342.725), 0.0476934 s/step
# on time step 68630 (time=343.15), 0.0471843 s/step
# on time step 68715 (time=343.575), 0.047236 s/step
# on time step 68823 (time=344.115), 0.0374343 s/step
# on time step 68909 (time=344.545), 0.0469384 s/step
# on time step 68998 (time=344.99), 0.0454427 s/step
# on time step 69090 (time=345.45), 0.0436685 s/step
# on time step 69183 (time=345.915), 0.04345 s/step
# on time step 69275 (time=346.375), 0.0436351 s/step
# on time step 69368 (time=346.84), 0.043094 s/step
# on time step 69460 (time=347.3), 0.0436158 s/step
# on time step 69568 (time=347.84), 0.0371738 s/step
# on time step 69660 (time=348.3), 0.0436202 s/step
# on time step 69753 (time=348.765), 0.043267 s/step
# on time step 69846 (time=349.23), 0.0434131 s/step
# on time step 69939 (time=349.695), 0.0433265 s/step
# on time step 70032 (time=350.16), 0.0434804 s/step
# on time step 70125 (time=350.625), 0.0432955 s/step
# on time step 70217 (time=351.085), 0.0435778 s/step
# on time step 70333 (time=351.665), 0.0347155 s/step
# on time step 70426 (time=352.13), 0.0433544 s/step
# on time step 70519 (time=352.595), 0.0432751 s/step
# on time step 70612 (time=353.06), 0.0433229 s/step
# on time step 70705 (time=353.525), 0.0431941 s/step
# on time step 70798 (time=353.99), 0.0432277 s/step
# on time step 70891 (time=354.455), 0.0432778 s/step
# on time step 70984 (time=354.92), 0.0434222 s/step
# on time step 71100 (time=355.5), 0.0348079 s/step
# on time step 71193 (time=355.965), 0.0432464 s/step
# on time step 71286 (time=356.43), 0.0433943 s/step
# on time step 71378 (time=356.89), 0.0434988 s/step
# on time step 71471 (time=357.355), 0.0433411 s/step
# on time step 71564 (time=357.82), 0.0432318 s/step
# on time step 71657 (time=358.285), 0.0432888 s/step
# on time step 71773 (time=358.865), 0.0347011 s/step
# on time step 71866 (time=359.33), 0.0434321 s/step
# on time step 71959 (time=359.795), 0.0434538 s/step
# on time step 72052 (time=360.26), 0.0434666 s/step
# on time step 72145 (time=360.725), 0.0432274 s/step
# on time step 72238 (time=361.19), 0.0434913 s/step
# on time step 72331 (time=361.655), 0.0433035 s/step
# on time step 72423 (time=362.115), 0.0435571 s/step
# on time step 72540 (time=362.7), 0.0345277 s/step
# on time step 72632 (time=363.16), 0.0435129 s/step
# on time step 72725 (time=363.625), 0.0432662 s/step
# on time step 72817 (time=364.085), 0.0435549 s/step
# on time step 72909 (time=364.545), 0.0436121 s/step
# on time step 73002 (time=365.01), 0.0433396 s/step
# on time step 73095 (time=365.475), 0.0434059 s/step
# on time step 73188 (time=365.94), 0.0432313 s/step
# on time step 73305 (time=366.525), 0.0343287 s/step
# on time step 73397 (time=366.985), 0.0435126 s/step
# on time step 73489 (time=367.445), 0.0435714 s/step
# on time step 73582 (time=367.91), 0.04341 s/step
# on time step 73675 (time=368.375), 0.0433077 s/step
# on time step 73768 (time=368.84), 0.043362 s/step
# on time step 73861 (time=369.305), 0.0434088 s/step
# on time step 73954 (time=369.77), 0.0433665 s/step
# on time step 74071 (time=370.355), 0.0345233 s/step
# on time step 74164 (time=370.82), 0.0432455 s/step
# on time step 74257 (time=371.285), 0.0430469 s/step
# on time step 74350 (time=371.75), 0.0433483 s/step
# on time step 74441 (time=372.205), 0.0440271 s/step
# on time step 74534 (time=372.67), 0.0434537 s/step
# on time step 74626 (time=373.13), 0.0436512 s/step
# on time step 74718 (time=373.59), 0.0439152 s/step
# on time step 74835 (time=374.175), 0.0344564 s/step
# on time step 74927 (time=374.635), 0.0435831 s/step
# on time step 75020 (time=375.1), 0.0433003 s/step
# on time step 75113 (time=375.565), 0.043228 s/step
# on time step 75205 (time=376.025), 0.043561 s/step
# on time step 75296 (time=376.48), 0.0442021 s/step
# on time step 75385 (time=376.925), 0.0450652 s/step
# on time step 75478 (time=377.39), 0.0434487 s/step
# on time step 75594 (time=377.97), 0.0345575 s/step
# on time step 75687 (time=378.435), 0.0434138 s/step
# on time step 75780 (time=378.9), 0.0433564 s/step
# on time step 75872 (time=379.36), 0.0434816 s/step
# on time step 75965 (time=379.825), 0.0432344 s/step
# on time step 76057 (time=380.285), 0.04359 s/step
# on time step 76150 (time=380.75), 0.0434535 s/step
# on time step 76266 (time=381.33), 0.0348245 s/step
# on time step 76359 (time=381.795), 0.043084 s/step
# on time step 76452 (time=382.26), 0.0432674 s/step
# on time step 76545 (time=382.725), 0.0433099 s/step
# on time step 76637 (time=383.185), 0.0435123 s/step
# on time step 76730 (time=383.65), 0.0434316 s/step
# on time step 76823 (time=384.115), 0.0434569 s/step
# on time step 76916 (time=384.58), 0.0432134 s/step
# on time step 77033 (time=385.165), 0.0341961 s/step
# on time step 77126 (time=385.63), 0.0432517 s/step
# on time step 77219 (time=386.095), 0.0430964 s/step
# on time step 77312 (time=386.56), 0.043219 s/step
# on time step 77405 (time=387.025), 0.0432635 s/step
# on time step 77497 (time=387.485), 0.0436333 s/step
# on time step 77588 (time=387.94), 0.0443093 s/step
# on time step 77673 (time=388.365), 0.0470668 s/step
# on time step 77782 (time=388.91), 0.0367499 s/step
# on time step 77869 (time=389.345), 0.0462707 s/step
# on time step 77954 (time=389.77), 0.0474645 s/step
# on time step 78044 (time=390.22), 0.0445328 s/step
# on time step 78135 (time=390.675), 0.0441927 s/step
# on time step 78229 (time=391.145), 0.042837 s/step
# on time step 78323 (time=391.615), 0.0426811 s/step
# on time step 78417 (time=392.085), 0.0428176 s/step
# on time step 78531 (time=392.655), 0.0351613 s/step
# on time step 78625 (time=393.125), 0.0428297 s/step
# on time step 78718 (time=393.59), 0.0430336 s/step
# on time step 78812 (time=394.06), 0.0430474 s/step
# on time step 78905 (time=394.525), 0.0432436 s/step
# on time step 79000 (time=395), 0.0425172 s/step
# on time step 79094 (time=395.47), 0.0425827 s/step
# on time step 79189 (time=395.945), 0.0424911 s/step
# on time step 79308 (time=396.54), 0.0336749 s/step
# on time step 79403 (time=397.015), 0.0422969 s/step
# on time step 79495 (time=397.475), 0.0437058 s/step
# on time step 79588 (time=397.94), 0.0430934 s/step
# on time step 79682 (time=398.41), 0.0426036 s/step
# on time step 79775 (time=398.875), 0.0430147 s/step
# on time step 79869 (time=399.345), 0.0428544 s/step
# on time step 79982 (time=399.91), 0.0355843 s/step
# field decay(t = 400.015): 4.018401541924937e+143 / 4.018401541924937e+143 = 1.0
# on time step 80072 (time=400.36), 0.0449161 s/step
# on time step 80165 (time=400.825), 0.0433133 s/step
# on time step 80253 (time=401.265), 0.045476 s/step
# on time step 80345 (time=401.725), 0.0436024 s/step
# on time step 80439 (time=402.195), 0.0429769 s/step
# on time step 80533 (time=402.665), 0.0426599 s/step
# on time step 80626 (time=403.13), 0.0432189 s/step
# on time step 80745 (time=403.725), 0.0336296 s/step
# on time step 80840 (time=404.2), 0.0425155 s/step
# on time step 80935 (time=404.675), 0.0424869 s/step
# on time step 81030 (time=405.15), 0.0423665 s/step
# on time step 81125 (time=405.625), 0.0422613 s/step
# on time step 81220 (time=406.1), 0.0424649 s/step
# on time step 81315 (time=406.575), 0.0421416 s/step
# on time step 81411 (time=407.055), 0.0420732 s/step
# on time step 81526 (time=407.63), 0.0350763 s/step
# on time step 81616 (time=408.08), 0.0444658 s/step
# on time step 81711 (time=408.555), 0.04213 s/step
# on time step 81804 (time=409.02), 0.0435153 s/step
# on time step 81896 (time=409.48), 0.0439049 s/step
# on time step 81987 (time=409.935), 0.0442885 s/step
# on time step 82079 (time=410.395), 0.0436806 s/step
# on time step 82171 (time=410.855), 0.0438794 s/step
# on time step 82286 (time=411.43), 0.0351156 s/step
# on time step 82379 (time=411.895), 0.043216 s/step
# on time step 82474 (time=412.37), 0.0425044 s/step
# on time step 82569 (time=412.845), 0.0424063 s/step
# on time step 82663 (time=413.315), 0.0425651 s/step
# on time step 82758 (time=413.79), 0.0423828 s/step
# on time step 82853 (time=414.265), 0.042294 s/step
# on time step 82948 (time=414.74), 0.0423197 s/step
# on time step 83065 (time=415.325), 0.0344479 s/step
# on time step 83157 (time=415.785), 0.0437607 s/step
# on time step 83250 (time=416.25), 0.0431645 s/step
# on time step 83342 (time=416.71), 0.0436088 s/step
# on time step 83435 (time=417.175), 0.0433875 s/step
# on time step 83525 (time=417.625), 0.0445989 s/step
# on time step 83616 (time=418.08), 0.044399 s/step
# on time step 83704 (time=418.52), 0.0458271 s/step
# on time step 83814 (time=419.07), 0.0366552 s/step
# on time step 83901 (time=419.505), 0.0463913 s/step
# on time step 83993 (time=419.965), 0.0435102 s/step
# on time step 84088 (time=420.44), 0.0423449 s/step
# on time step 84179 (time=420.895), 0.0439903 s/step
# on time step 84269 (time=421.345), 0.0448117 s/step
# on time step 84363 (time=421.815), 0.0429724 s/step
# on time step 84483 (time=422.415), 0.0336775 s/step
# on time step 84578 (time=422.89), 0.0422064 s/step
# on time step 84673 (time=423.365), 0.0424215 s/step
# ...
# on time step 106325 (time=531.625), 0.0424414 s/step
# on time step 106414 (time=532.07), 0.0450826 s/step
# on time step 106507 (time=532.535), 0.0430279 s/step
# on time step 106626 (time=533.13), 0.0337524 s/step
# on time step 106718 (time=533.59), 0.0436171 s/step
# on time step 106811 (time=534.055), 0.0432965 s/step
# on time step 106904 (time=534.52), 0.0430838 s/step
# on time step 106998 (time=534.99), 0.0428743 s/step
# on time step 107092 (time=535.46), 0.042935 s/step
# on time step 107186 (time=535.93), 0.042841 s/step
# on time step 107279 (time=536.395), 0.04334 s/step
# on time step 107397 (time=536.985), 0.0339193 s/step
# on time step 107490 (time=537.45), 0.0431708 s/step
# on time step 107583 (time=537.915), 0.0434742 s/step
# on time step 107674 (time=538.37), 0.0439729 s/step
# on time step 107766 (time=538.83), 0.0436902 s/step
# on time step 107857 (time=539.285), 0.0439908 s/step
# on time step 107951 (time=539.755), 0.0430011 s/step
# on time step 108069 (time=540.345), 0.0342027 s/step
# on time step 108159 (time=540.795), 0.0444678 s/step
# on time step 108247 (time=541.235), 0.0456368 s/step
# on time step 108337 (time=541.685), 0.0446589 s/step
# on time step 108428 (time=542.14), 0.0442395 s/step
# on time step 108518 (time=542.59), 0.0447387 s/step
# on time step 108610 (time=543.05), 0.0437379 s/step
# on time step 108702 (time=543.51), 0.0437302 s/step
# on time step 108818 (time=544.09), 0.0346243 s/step
# on time step 108910 (time=544.55), 0.0439216 s/step
# on time step 109002 (time=545.01), 0.0436773 s/step
# on time step 109093 (time=545.465), 0.0443904 s/step
# on time step 109183 (time=545.915), 0.0449278 s/step
# on time step 109271 (time=546.355), 0.0457232 s/step
# on time step 109364 (time=546.82), 0.0432869 s/step
# on time step 109457 (time=547.285), 0.0433457 s/step
# on time step 109573 (time=547.865), 0.0345786 s/step
# on time step 109665 (time=548.325), 0.0438303 s/step
# on time step 109756 (time=548.78), 0.0440158 s/step
# on time step 109847 (time=549.235), 0.0443983 s/step
# on time step 109932 (time=549.66), 0.0471813 s/step
# on time step 110015 (time=550.075), 0.0484936 s/step
# on time step 110103 (time=550.515), 0.045655 s/step
# on time step 110196 (time=550.98), 0.0432621 s/step
# on time step 110310 (time=551.55), 0.0351665 s/step
# on time step 110398 (time=551.99), 0.0456564 s/step
# on time step 110488 (time=552.44), 0.0448854 s/step
# on time step 110582 (time=552.91), 0.0426359 s/step
# on time step 110677 (time=553.385), 0.0424697 s/step
# on time step 110771 (time=553.855), 0.0429686 s/step
# on time step 110864 (time=554.32), 0.0430453 s/step
# on time step 110956 (time=554.78), 0.043541 s/step
# on time step 111075 (time=555.375), 0.0337336 s/step
# on time step 111169 (time=555.845), 0.0428984 s/step
# on time step 111260 (time=556.3), 0.0444461 s/step
# on time step 111352 (time=556.76), 0.0437152 s/step
# on time step 111437 (time=557.185), 0.0472083 s/step
# on time step 111527 (time=557.635), 0.0444512 s/step
# on time step 111620 (time=558.1), 0.0433678 s/step
# on time step 111734 (time=558.67), 0.0351301 s/step
# on time step 111819 (time=559.095), 0.047503 s/step
# on time step 111909 (time=559.545), 0.0447664 s/step
# on time step 112001 (time=560.005), 0.0434919 s/step
# on time step 112090 (time=560.45), 0.0449778 s/step
# on time step 112181 (time=560.905), 0.0440165 s/step
# on time step 112268 (time=561.34), 0.0460858 s/step
# on time step 112359 (time=561.795), 0.0442686 s/step
# on time step 112475 (time=562.375), 0.0346412 s/step
# on time step 112569 (time=562.845), 0.0429802 s/step
# on time step 112662 (time=563.31), 0.0432305 s/step
# on time step 112756 (time=563.78), 0.0426137 s/step
# on time step 112850 (time=564.25), 0.0425719 s/step
# on time step 112944 (time=564.72), 0.0426186 s/step
# on time step 113038 (time=565.19), 0.0428296 s/step
# on time step 113132 (time=565.66), 0.0428377 s/step
# on time step 113249 (time=566.245), 0.0345084 s/step
# on time step 113342 (time=566.71), 0.0433031 s/step
# on time step 113436 (time=567.18), 0.0429793 s/step
# on time step 113529 (time=567.645), 0.0432367 s/step
# on time step 113621 (time=568.105), 0.0437665 s/step
# on time step 113711 (time=568.555), 0.0446231 s/step
# on time step 113805 (time=569.025), 0.0429007 s/step
# on time step 113898 (time=569.49), 0.0434064 s/step
# on time step 114018 (time=570.09), 0.0335796 s/step
# on time step 114112 (time=570.56), 0.0426718 s/step
# on time step 114206 (time=571.03), 0.0426218 s/step
# on time step 114299 (time=571.495), 0.0433147 s/step
# on time step 114391 (time=571.955), 0.0435304 s/step
# on time step 114484 (time=572.42), 0.0432884 s/step
# on time step 114573 (time=572.865), 0.0453974 s/step
# on time step 114659 (time=573.295), 0.0467585 s/step
# on time step 114774 (time=573.87), 0.0348629 s/step
# on time step 114862 (time=574.31), 0.0457483 s/step
# on time step 114952 (time=574.76), 0.0445552 s/step
# on time step 115041 (time=575.205), 0.0451275 s/step
# on time step 115131 (time=575.655), 0.0447876 s/step
# on time step 115219 (time=576.095), 0.0459376 s/step
# on time step 115305 (time=576.525), 0.0466061 s/step
# on time step 115393 (time=576.965), 0.0459322 s/step
# on time step 115512 (time=577.56), 0.0337043 s/step
# on time step 115607 (time=578.035), 0.0424903 s/step
# on time step 115701 (time=578.505), 0.0428566 s/step
# on time step 115795 (time=578.975), 0.0427014 s/step
# on time step 115889 (time=579.445), 0.0426681 s/step
# on time step 115983 (time=579.915), 0.0428467 s/step
# on time step 116077 (time=580.385), 0.0428112 s/step
# on time step 116197 (time=580.985), 0.0334146 s/step
# on time step 116291 (time=581.455), 0.0430129 s/step
# on time step 116385 (time=581.925), 0.04256 s/step
# on time step 116474 (time=582.37), 0.0453123 s/step
# on time step 116567 (time=582.835), 0.0433078 s/step
# on time step 116659 (time=583.295), 0.0435171 s/step
# on time step 116753 (time=583.765), 0.042949 s/step
# on time step 116848 (time=584.24), 0.0425135 s/step
# on time step 116967 (time=584.835), 0.0337773 s/step
# on time step 117061 (time=585.305), 0.0428077 s/step
# on time step 117155 (time=585.775), 0.0427536 s/step
# on time step 117247 (time=586.235), 0.0437186 s/step
# on time step 117340 (time=586.7), 0.0432861 s/step
# on time step 117434 (time=587.17), 0.0429364 s/step
# on time step 117524 (time=587.62), 0.0445124 s/step
# on time step 117611 (time=588.055), 0.0462487 s/step
# on time step 117728 (time=588.64), 0.0345084 s/step
# on time step 117817 (time=589.085), 0.0450472 s/step
# on time step 117911 (time=589.555), 0.0427147 s/step
# on time step 118003 (time=590.015), 0.0439413 s/step
# on time step 118091 (time=590.455), 0.0457863 s/step
# on time step 118181 (time=590.905), 0.0445809 s/step
# on time step 118269 (time=591.345), 0.0459373 s/step
# on time step 118360 (time=591.8), 0.0443929 s/step
# on time step 118477 (time=592.385), 0.0344871 s/step
# on time step 118570 (time=592.85), 0.0433121 s/step
# on time step 118664 (time=593.32), 0.0429888 s/step
# on time step 118758 (time=593.79), 0.0429163 s/step
# on time step 118851 (time=594.255), 0.0431697 s/step
# on time step 118944 (time=594.72), 0.0431345 s/step
# on time step 119037 (time=595.185), 0.0430208 s/step
# on time step 119131 (time=595.655), 0.0429038 s/step
# on time step 119250 (time=596.25), 0.0338068 s/step
# on time step 119343 (time=596.715), 0.0430294 s/step
# on time step 119436 (time=597.18), 0.0434562 s/step
# on time step 119527 (time=597.635), 0.0442703 s/step
# on time step 119618 (time=598.09), 0.0440133 s/step
# on time step 119708 (time=598.54), 0.0444492 s/step
# on time step 119796 (time=598.98), 0.0454799 s/step
# on time step 119912 (time=599.56), 0.0348458 s/step
# field decay(t = 600.02): 1.341115401573736e+274 / 1.341115401573736e+274 = 1.0
# on time step 120005 (time=600.025), 0.0430819 s/step
# on time step 120099 (time=600.495), 0.0427107 s/step
# on time step 120192 (time=600.96), 0.0430478 s/step
# on time step 120285 (time=601.425), 0.0434258 s/step
# on time step 120375 (time=601.875), 0.0449283 s/step
# on time step 120465 (time=602.325), 0.04459 s/step
# on time step 120550 (time=602.75), 0.0473624 s/step
# on time step 120665 (time=603.325), 0.0348285 s/step
# on time step 120759 (time=603.795), 0.0427429 s/step
# on time step 120851 (time=604.255), 0.0438858 s/step
# on time step 120945 (time=604.725), 0.0426466 s/step
# on time step 121034 (time=605.17), 0.0452083 s/step
# on time step 121122 (time=605.61), 0.0455418 s/step
# on time step 121209 (time=606.045), 0.0464743 s/step
# on time step 121298 (time=606.49), 0.0450748 s/step
# on time step 121414 (time=607.07), 0.0346021 s/step
# on time step 121500 (time=607.5), 0.0469591 s/step
# on time step 121590 (time=607.95), 0.0449009 s/step
# on time step 121673 (time=608.365), 0.0484183 s/step
# on time step 121758 (time=608.79), 0.0474382 s/step
# on time step 121841 (time=609.205), 0.0483389 s/step
# on time step 121927 (time=609.635), 0.0470752 s/step
# on time step 122006 (time=610.03), 0.0509068 s/step
# on time step 122110 (time=610.55), 0.0385373 s/step
# on time step 122193 (time=610.965), 0.0486093 s/step
# on time step 122280 (time=611.4), 0.0462347 s/step
# on time step 122363 (time=611.815), 0.0484447 s/step
# on time step 122446 (time=612.23), 0.0486374 s/step
# on time step 122530 (time=612.65), 0.0477116 s/step
# on time step 122612 (time=613.06), 0.0491815 s/step
# on time step 122697 (time=613.485), 0.047132 s/step
# on time step 122803 (time=614.015), 0.0377664 s/step
# on time step 122888 (time=614.44), 0.0475253 s/step
# on time step 122974 (time=614.87), 0.0469621 s/step
# on time step 123058 (time=615.29), 0.0478785 s/step
# on time step 123144 (time=615.72), 0.0468377 s/step
# on time step 123226 (time=616.13), 0.0490521 s/step
# on time step 123311 (time=616.555), 0.0470912 s/step
# on time step 123422 (time=617.11), 0.036378 s/step
# on time step 123509 (time=617.545), 0.046175 s/step
# on time step 123595 (time=617.975), 0.0469398 s/step
# on time step 123681 (time=618.405), 0.0466956 s/step
# on time step 123767 (time=618.835), 0.0466683 s/step
# on time step 123854 (time=619.27), 0.0461438 s/step
# on time step 123941 (time=619.705), 0.0463674 s/step
# on time step 124027 (time=620.135), 0.0467841 s/step
# on time step 124138 (time=620.69), 0.0364344 s/step
# on time step 124225 (time=621.125), 0.046332 s/step
# on time step 124312 (time=621.56), 0.0463351 s/step
# on time step 124399 (time=621.995), 0.0462329 s/step
# on time step 124485 (time=622.425), 0.0467579 s/step
# on time step 124573 (time=622.865), 0.0459303 s/step
# on time step 124660 (time=623.3), 0.0461585 s/step
# on time step 124746 (time=623.73), 0.0465731 s/step
# on time step 124857 (time=624.285), 0.0360995 s/step
# on time step 124943 (time=624.715), 0.0468444 s/step
# on time step 125028 (time=625.14), 0.0475358 s/step
# on time step 125112 (time=625.56), 0.0480329 s/step
# on time step 125197 (time=625.985), 0.0472415 s/step
# on time step 125284 (time=626.42), 0.0464617 s/step
# on time step 125370 (time=626.85), 0.0467065 s/step
# on time step 125457 (time=627.285), 0.0463074 s/step
# on time step 125566 (time=627.83), 0.0369027 s/step
# on time step 125651 (time=628.255), 0.0473562 s/step
# on time step 125736 (time=628.68), 0.0470705 s/step
# on time step 125823 (time=629.115), 0.0463713 s/step
# on time step 125904 (time=629.52), 0.0497239 s/step
# on time step 125986 (time=629.93), 0.0492009 s/step
# on time step 126072 (time=630.36), 0.0467459 s/step
# on time step 126158 (time=630.79), 0.0467299 s/step
# on time step 126265 (time=631.325), 0.0375424 s/step
# on time step 126351 (time=631.755), 0.0467424 s/step
# on time step 126436 (time=632.18), 0.0476657 s/step
# on time step 126520 (time=632.6), 0.047844 s/step
# on time step 126604 (time=633.02), 0.0481263 s/step
# on time step 126688 (time=633.44), 0.0477597 s/step
# on time step 126770 (time=633.85), 0.0488133 s/step
# on time step 126871 (time=634.355), 0.0397801 s/step
# on time step 126946 (time=634.73), 0.0539047 s/step
# on time step 127029 (time=635.145), 0.0485084 s/step
# on time step 127107 (time=635.535), 0.0518814 s/step
# on time step 127189 (time=635.945), 0.0490858 s/step
# on time step 127273 (time=636.365), 0.0478419 s/step
# on time step 127358 (time=636.79), 0.0472155 s/step
# on time step 127442 (time=637.21), 0.0479136 s/step
# on time step 127546 (time=637.73), 0.0385602 s/step
# on time step 127629 (time=638.145), 0.0484849 s/step
# on time step 127714 (time=638.57), 0.0474637 s/step
# on time step 127799 (time=638.995), 0.0472964 s/step
# on time step 127874 (time=639.37), 0.0536073 s/step
# on time step 127952 (time=639.76), 0.0517368 s/step
# on time step 128032 (time=640.16), 0.0501195 s/step
# on time step 128112 (time=640.56), 0.0504865 s/step
# on time step 128216 (time=641.08), 0.0387825 s/step
# on time step 128301 (time=641.505), 0.0471507 s/step
# on time step 128386 (time=641.93), 0.0474975 s/step
# on time step 128466 (time=642.33), 0.0500362 s/step
# on time step 128547 (time=642.735), 0.049386 s/step
# on time step 128632 (time=643.16), 0.0475794 s/step
# on time step 128713 (time=643.565), 0.0495895 s/step
# on time step 128795 (time=643.975), 0.0487832 s/step
# on time step 128905 (time=644.525), 0.0365342 s/step
# on time step 128983 (time=644.915), 0.0513454 s/step
# on time step 129062 (time=645.31), 0.0507932 s/step
# on time step 129145 (time=645.725), 0.0482483 s/step
# on time step 129229 (time=646.145), 0.0479166 s/step
# on time step 129311 (time=646.555), 0.0492894 s/step
# on time step 129395 (time=646.975), 0.0480499 s/step
# on time step 129480 (time=647.4), 0.047194 s/step
# on time step 129584 (time=647.92), 0.038531 s/step
# on time step 129657 (time=648.285), 0.0552036 s/step
# on time step 129741 (time=648.705), 0.0478143 s/step
# on time step 129827 (time=649.135), 0.0469987 s/step
# on time step 129914 (time=649.57), 0.0460582 s/step
# on time step 130000 (time=650), 0.0466889 s/step
# on time step 130086 (time=650.43), 0.0467588 s/step
# on time step 130195 (time=650.975), 0.0370755 s/step
# on time step 130282 (time=651.41), 0.046475 s/step
# on time step 130364 (time=651.82), 0.0487988 s/step
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 18
#       9 ldos_obj = mp.Ldos(freqs)
#      11 decay_condition = mp.stop_when_fields_decayed(
#      12     c=mp.Ex,                          # 모니터할 전기장 컴포넌트
#      13     pt=source_center,           # 모니터 위치
#      14     decay_by=1e-5,                    # auto shutoff min
#      15     dt=100,                           # down sample time
#      16 )
# ---> 18 sim_fitting.run(
#      19     mp.dft_ldos(ldos=ldos_obj),
#      20     # until=50
#      21     until_after_sources = decay_condition
#      22 )
#      24 net_power_fitting = mp.get_fluxes(sim_fitting)
#
# File ~/miniconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py:4536, in Simulation.run(self, *step_funcs, **kwargs)
#    4533     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4535 if until_after_sources is not None:
# -> 4536     self._run_sources_until(until_after_sources, step_funcs)
#    4537 elif until is not None:
#    4538     self._run_until(until, step_funcs)
#
# File ~/miniconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py:2876, in Simulation._run_sources_until(self, cond, step_funcs)
#    2872             return cond[i](sim) and sim.round_time() >= ts
#    2874         new_conds.append(f)
# -> 2876 self._run_until(new_conds, step_funcs)
#
# File ~/miniconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py:2834, in Simulation._run_until(self, cond, step_funcs)
#    2832     for func in step_funcs:
#    2833         _eval_step_func(self, func, "step")
# -> 2834     self.fields.step()
#    2836 # Translating the recursive scheme version of run-until into an iterative version
#    2837 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2838 # be the same as scheme.
#    2839 for func in step_funcs:
#
# File ~/miniconda3/envs/mp/lib/python3.9/site-packages/meep/__init__.py:3041, in fields.step(self)
#    3040 def step(self):
# -> 3041     return _meep.fields_step(self)
#
# RuntimeError: meep: simulation fields are NaN or Inf

# %%
k = net_power_fitting / ldos_power
plt.plot(wavelengths,k)

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import csv

sim.init_sim()

# === 설정 ===
resolution = 100  # ★ 함수 인자였던 것을 변수로 설정
cell_size = mp.Vector3(5, 5, 0)
fcen = 1.75
df = 3.3
nfreq = 300

field_component = mp.Ex

lambda_min = 0.4
lambda_max = 0.7
fmin = 1 / lambda_max
fmax = 1 / lambda_min
fcen_dft = 0.5 * (fmin + fmax)
df_dft = fmax - fmin

# 소스 설정
source_center = mp.Vector3(0, 0, 0)
sources = [
    mp.Source(
        src=mp.GaussianSource(frequency=fcen, fwidth=df),
        component=field_component,
        center=source_center,
        size=mp.Vector3(0, 0)
    )
]

sio2 =  mp.Medium(epsilon = 1,   E_susceptibilities = suscept_sio2, valid_freq_range=freq_sio2) # SiO2 ,
andp =  mp.Medium(epsilon = 1,   E_susceptibilities = suscept_andp, valid_freq_range=freq_andp) # aNDP ,
Al  =   mp.Medium(epsilon = 1,     E_susceptibilities = suscept_al, valid_freq_range=freq_al)

Glass = sio2
aNDP = andp
Cathode = Al

# Cathode = mp.perfect_electric_conductor,
CoverLayer_index = 1.9
ITO_m_index = 1.8
Alq3_index = 1.68

CoverLayer = mp.Medium(epsilon=CoverLayer_index**2) # SiN ,
ITO_m = mp.Medium(epsilon=ITO_m_index**2) 
Alq3 = mp.Medium(index = Alq3_index) 
Air = mp.Medium(index=1.0) # 공기,

Glass_layer = 1.37
Cover_layer = 0.07
ITO_layer = 0.15
aNDP_layer = 0.05
Alq3_layer = 0.06
Cathode_layer = 0.3

Cathode_center = mp.Vector3(0, -0.85, 0)
Alq3_center = mp.Vector3(0, -0.67, 0)
aNDP_center = mp.Vector3(0, -0.615, 0)
ITO_center = mp.Vector3(0, -0.515, 0)
Cover_center = mp.Vector3(0, -0.405, 0)
Glass_center = mp.Vector3(0, 0.315, 0)
# cell_size = mp.Vector3(31, 2, 0)

geometry_fitting = [
        # Cathode (하단)
        mp.Block(
            center=Cathode_center,
            size=mp.Vector3(mp.inf, Cathode_layer, 1),
            material=Cathode
        ),
        # Alq3
        mp.Block(
            center=Alq3_center,
            size=mp.Vector3(mp.inf, Alq3_layer, 1),
            material=Alq3
        ),
        # aNDP
        mp.Block(
            center=aNDP_center,
            size=mp.Vector3(mp.inf, aNDP_layer, 1),
            material=aNDP
        ),
        # ITO
        mp.Block(
            center=ITO_center,
            size=mp.Vector3(mp.inf, ITO_layer, 1),
            material=ITO_m
        ),
        # Cover layer
        mp.Block(
            center=Cover_center,
            size=mp.Vector3(mp.inf, Cover_layer, 1),
            material=CoverLayer
        ),
        # Glass (상단; (0,0,0)은 이 Glass 내부에 위치함)
        mp.Block(
            center=Glass_center,
            size=mp.Vector3(mp.inf, Glass_layer, 1),
            material=Glass
        )
]

# PML 설정
pml_layers = [mp.PML(1.5)]

# === 시뮬레이션 설정 === #
sim_fitting_st = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_fitting[1:2],
    default_material=Alq3,
    sources=sources,
    resolution=resolution,
    eps_averaging=True,
    extra_materials=[Cathode, aNDP, Glass]
)

# === LDOS 객체 생성 ===
freqs = np.linspace(fcen_dft - df_dft/2, fcen_dft + df_dft/2, nfreq)
ldos_obj = mp.Ldos(freqs)

decay_condition = mp.stop_when_fields_decayed(
    c=mp.Ex,                          # 모니터할 전기장 컴포넌트
    pt=mp.Vector3(0, 0, 0),           # 모니터 위치
    decay_by=1e-5,                    # auto shutoff min
    dt=100,                           # down sample time
)

# === 시뮬레이션 실행 ===
sim_fitting_st.run(
    mp.dft_ldos(ldos=ldos_obj),
    until = 50
)

# === 결과 얻기 ===
ldos_power_str = np.array(sim_fitting_st.ldos_data)  # (W) 단위 power
flux_freqs = np.array(mp.get_ldos_freqs(ldos_obj))  # (1/μm) 단위 주파수
wavelengths = 1 / flux_freqs  # (μm) 단위 파장

# === CSV 저장 ===
csv_filename = f"ldos_sourcepower_res{resolution} - structure.csv"
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Wavelength (μm)", "LDOS Power (a.u.)"])
    for wl, power in zip(wavelengths, ldos_power):
        writer.writerow([wl, power])

print(f"CSV 파일 저장 완료: {csv_filename}")

# === 플롯 저장 ===
plt.figure(dpi=120)
plt.plot(wavelengths, ldos_power_str, label="LDOS Power", color='blue')
plt.xlabel("Wavelength (μm)", fontsize = 20)
plt.ylabel("Power (a.u.)", fontsize = 20)
plt.title(f"LDOS-based Source Power - in structure [] (Resolution={resolution})", fontsize = 20)
plt.grid(True)
plt.legend()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000282049 s
# Working in 2D dimensions.
# Computational cell is 5 x 5 x 0 with resolution 100
#      block, center = (0,-0.67,0)
#           size (1e+20,0.06,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
# time for set_epsilon = 0.134841 s
# lorentzian susceptibility: frequency=10.5233, gamma=0
# lorentzian susceptibility: frequency=9.581, gamma=0.00361007
# drude susceptibility: frequency=1, gamma=9.97384
# lorentzian susceptibility: frequency=13.0238, gamma=0
# lorentzian susceptibility: frequency=2.66313, gamma=0.193333
# lorentzian susceptibility: frequency=12.9664, gamma=0
# lorentzian susceptibility: frequency=9.35736, gamma=0
# drude susceptibility: frequency=1, gamma=3.40764
# drude susceptibility: frequency=1, gamma=9.03162
# drude susceptibility: frequency=1, gamma=0
# lorentzian susceptibility: frequency=5.86464, gamma=1.37868
# drude susceptibility: frequency=1, gamma=8.44336
# lorentzian susceptibility: frequency=8.25227, gamma=0
# lorentzian susceptibility: frequency=3.73793, gamma=1.91772
# lorentzian susceptibility: frequency=2.12712, gamma=1.58925
# lorentzian susceptibility: frequency=1.25552, gamma=0.318803
# lorentzian susceptibility: frequency=1.52565, gamma=0.604333
# drude susceptibility: frequency=1, gamma=0.0399392
# lorentzian susceptibility: frequency=0.834389, gamma=0.132633
# drude susceptibility: frequency=1, gamma=0.218227
# -----------
# /home/min/miniconda3/envs/mp/lib/python3.9/site-packages/meep/simulation.py:1660: RuntimeWarning: Note: your sources include frequencies outside the range of validity of the material models. This is fine as long as you eventually only look at outputs (fluxes, resonant modes, etc.) at valid frequencies.
#   warnings.warn(warn_src, RuntimeWarning)
# Meep progress: 23.295/50.0 = 46.6% done in 4.0s, 4.6s to go
# on time step 4659 (time=23.295), 0.000858671 s/step
# Meep progress: 46.83/50.0 = 93.7% done in 8.0s, 0.5s to go
# on time step 9366 (time=46.83), 0.000849845 s/step
# ldos0:, 1.4285714285714288, 0.7151967424243069
# ldos0:, 1.4321548017200194, 0.7170284820695526
# ldos0:, 1.43573817486861, 0.7188776300591454
# ldos0:, 1.4393215480172004, 0.7206902493119257
# ldos0:, 1.442904921165791, 0.7224524336407024
# ldos0:, 1.4464882943143815, 0.7242044451492788
# ldos0:, 1.4500716674629721, 0.7259967381824716
# ldos0:, 1.4536550406115627, 0.7278358764020402
# ldos0:, 1.457238413760153, 0.7296782918894166
# ldos0:, 1.4608217869087436, 0.7314777118928506
# ldos0:, 1.4644051600573342, 0.7332346498583076
# ldos0:, 1.4679885332059248, 0.7349950505930215
# ldos0:, 1.4715719063545154, 0.7368004134587687
# ldos0:, 1.4751552795031058, 0.7386435169894291
# ldos0:, 1.4787386526516964, 0.7404769600554378
# ldos0:, 1.482322025800287, 0.7422645003116486
# ldos0:, 1.4859053989488775, 0.7440196080245812
# ldos0:, 1.4894887720974679, 0.7457902444976426
# ldos0:, 1.4930721452460585, 0.7476070236131162
# ldos0:, 1.496655518394649, 0.7494507660756992
# ldos0:, 1.5002388915432396, 0.7512738118167935
# ldos0:, 1.5038222646918302, 0.7530514369955875
# ldos0:, 1.5074056378404206, 0.754807924318419
# ldos0:, 1.5109890109890112, 0.7565898196861097
# ldos0:, 1.5145723841376018, 0.7584158058515001
# ldos0:, 1.5181557572861923, 0.7602571576995029
# ldos0:, 1.521739130434783, 0.7620692000367724
# ldos0:, 1.5253225035833733, 0.7638393370589796
# ldos0:, 1.5289058767319639, 0.7656000349905694
# ldos0:, 1.5324892498805545, 0.7673934092149555
# ldos0:, 1.536072623029145, 0.7692260256453451
# ldos0:, 1.5396559961777356, 0.771062407940323
# ldos0:, 1.543239369326326, 0.7728636169427529
# ldos0:, 1.5468227424749166, 0.7746289645456783
# ldos0:, 1.5504061156235072, 0.7763961912774071
# ldos0:, 1.5539894887720977, 0.7782005244936382
# ldos0:, 1.5575728619206881, 0.7800370169222067
# ldos0:, 2.399665551839465, 1.2043896838003214
# ldos0:, 2.4032489249880555, 1.2062331442150607
# ldos0:, 2.406832298136646, 1.2080698726691765
# ldos0:, 2.4104156712852367, 1.209873515507885
# ldos0:, 2.413999044433827, 1.2116533595049495
# ldos0:, 2.417582417582418, 1.2134446657301667
# ldos0:, 2.421165790731008, 1.2152707407353174
# ldos0:, 2.4247491638795986, 1.2171175342110636
# ldos0:, 2.428332537028189, 1.2189484402979327
# ldos0:, 2.4319159101767798, 1.2207437222690514
# ldos0:, 2.4354992833253704, 1.2225221098825045
# ldos0:, 2.439082656473961, 1.2243209467480909
# ldos0:, 2.4426660296225515, 1.2261559196069507
# ldos0:, 2.4462494027711417, 1.2280037867472329
# ldos0:, 2.4498327759197327, 1.2298271094732989
# ldos0:, 2.453416149068323, 1.2316146807873378
# ldos0:, 2.456999522216914, 1.233394004456505
# ldos0:, 2.460582895365504, 1.2352019464331667
# ldos0:, 2.4641662685140946, 1.237044864953624
# ldos0:, 2.467749641662685, 1.2388913271116473
# ldos0:, 2.4713330148112758, 1.2407057243053534
# ldos0:, 2.4749163879598663, 1.2424868483494909
# ldos0:, 2.4784997611084565, 1.2442696487892888
# ldos0:, 2.4820831342570475, 1.2460877872637728
# ldos0:, 2.4856665074056377, 1.247937097339558
# ldos0:, 2.4892498805542287, 1.249779602834844
# ldos0:, 2.492833253702819, 1.2515842740346592
# ldos0:, 2.4964166268514094, 1.2533607942950309
# ldos0:, 2.5, 1.255149604920134
# run 0 finished at t = 50.0 (10000 timesteps)
# CSV 파일 저장 완료: ldos_sourcepower_res100 - structure.csv

# %%
sim_fitting_st.plot2D()
# Out:
#      block, center = (0,-0.67,0)
#           size (1e+20,0.06,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.8224,2.8224,2.8224)
# <Axes: xlabel='X', ylabel='Y'>

# %%
# lumerical data import
import numpy as np
from pathlib import Path

csv_path_decaybox = Path("/home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/One layer check/Onelayer/alq3.txt")
csv_path_decay = Path("/home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/decayrate.txt")

# CSV 파일 불러오기
csv_decaybox = np.genfromtxt(csv_path_decaybox, delimiter=",", )
csv_decay = np.genfromtxt(csv_path_decay, delimiter=",", skip_header=1)

decaybox_data = csv_decaybox[:, 1]
decay_data = csv_decay[:, 1]

# %%
import numpy as np
from pathlib import Path

csv_path = Path("/home/min/EIDL/Tool/Meep/LGD/Meep code/OLED structure/Layer by Layer check/al100.txt")

# CSV 파일 불러오기
lumerical_data = np.genfromtxt(csv_path, delimiter=",")

lumerical = lumerical_data[:, 1]

# %%
norm = ldos_power_str**2 / ldos_power**2 
plt.plot(wavelengths, norm, label="LDOS Power", color='blue')
plt.plot(wavelengths, decaybox_data, label="Lumerical", color='red')
plt.show()

# %%
plot_filename = f"ldos_sourcepower_res{resolution} - in structure.png"
plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
plt.close()

print(f"플롯 이미지 저장 완료: {plot_filename}")
# Out:
# 플롯 이미지 저장 완료: ldos_sourcepower_res100 - in structure.png
